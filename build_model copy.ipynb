# %%
import os
import librosa
import torch
import random
import keras
import soundfile as sf
import numpy as np
import pandas as pd
import tensorflow as tf
from collections import Counter
from concurrent.futures import ThreadPoolExecutor
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelBinarizer
# Out:
# WARNING:tensorflow:From c:\Users\musah\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# if gpu is available, use it
if tf.config.list_physical_devices('GPU'):
    device = 'gpu'
else:
    device = 'cpu'
    
# if gpu is available, use it
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
OUTPUT_DIR: str = "output/"
CSV_FILE_PATH: str = "bio_metadata.csv"
NATIVE_FILE_PATH: str = "native_bio_metadata.csv"
NON_NATIVE_FILE_PATH: str = "non_native_bio_metadata.csv"
NATIVE_LANGUAGES: list[str] = ['uk', 'usa', 'canada']
NON_NATIVE_LANGUAGES: list[str] = [
    'australia',
    'new zealand',
    'ireland',    
    'singapore',  
    'south',     
    'africa',   
    'jamaica',    
    'scotland',   
    'islands',
]
DATASET_DIR: str = "data/"
NATIVE_DIR: str = "data/native/"
NATIVE_COMBINED_DIR: str = "data/native_combined/"
NON_NATIVE_DIR: str = "data/non_native/"
AUDIO_DATA_DIR: str = "data/audio/"
AUDIO_FILE_PATH: str = "data/audio/{}.wav"
SILENCE_THRESHOLD: float = .01
RATE: int = 2400
N_MFCC: int = 13
COL_SIZE: int = 30
EPOCHS: int = 150 #35 #50 #250
LEARNING_RATE = 0.001
WAIT: float = 1.2
DEBUG: bool = True

# %%
class XFeatureExtractor:
    """
        Extracts acoustic and prosodic features from audio files.
    """
    
    @staticmethod
    def extract_acoustic_features(file_path, features=('mfcc', 'chroma_stft', 'spectral_centroid')):
        try:
            y, sr = librosa.load(f'data/audio/{file_path}.wav')
            features_dict = {}
            for feature_name in features:
                if feature_name == 'mfcc':
                    features_dict['mfcc'] = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40)
                elif feature_name == 'chroma_stft':
                    features_dict['chroma_stft'] = librosa.feature.chroma_stft(y=y, sr=sr, n_chroma=12)
                elif feature_name == 'spectral_centroid':
                    features_dict['spectral_centroid'] = librosa.feature.spectral_centroid(y=y, sr=sr)
                elif feature_name == 'spectral_bandwidth':
                    features_dict['spectral_bandwidth'] = librosa.feature.spectral_bandwidth(y=y, sr=sr)
                elif feature_name == 'zero_crossing_rate':
                    features_dict['zero_crossing_rate'] = librosa.feature.zero_crossing_rate(
                        y=y, 
                        frame_length=2048,
                        hop_length=512
                    )
                elif feature_name == 'rmse':
                    features_dict['rmse'] = librosa.feature.rms(y=y)
                else:
                    raise ValueError(f"Unsupported feature: {feature_name}")

            return features_dict
        except Exception as e:
            print(f"Error loading file {file_path}: {e}")
            return None  # Or handle error differently

    @staticmethod
    def extract_prosodic_features(file_path, features=('pitch', 'intensity', 'duration')):
        try:
            y, sr = librosa.load(f'data/audio/{file_path}.wav')
            prosodic_features = {}
            for feature_name in features:
                if feature_name == 'pitch':
                    prosodic_features['pitch'] = librosa.yin(y=y, fmin=65, fmax=2093)
                elif feature_name == 'intensity':
                    prosodic_features['intensity'] = librosa.feature.rms(y=y)
                elif feature_name == 'duration':
                    prosodic_features['duration'] = len(y) / sr
                elif feature_name == 'formants':
                    # Implement formant extraction using librosa or a custom solution
                    prosodic_features['formants'] = None  # Placeholder for now
                else:
                    raise ValueError(f"Unsupported feature: {feature_name}")
            return prosodic_features
        except Exception as e:
            print(f"Error loading file {file_path}: {e}")
            return None  # Handle loading errors

    @staticmethod
    def extract_plp(file_path):
        y, sr = librosa.load(f'data/audio/{file_path}.wav')
        plp = librosa.beat.plp(y=y, sr=sr)
        return plp

# %%
class FeatureExtractorUtils:
    """
        Extracts acoustic features from audio files and preprocesses them for language identification.
    """

    def __init__(self):
        pass  # No initialization needed for now
    
    @staticmethod
    def to_categorical(y):
        '''
            Converts list of languages into a binary class matrix
            :param y (list): list of languages
            :return (numpy array): binary class matrix
        '''
        lang_dict = {}
        for index, language in enumerate(set(y)):
            lang_dict[language] = index
        y = list(map(lambda x: lang_dict[x],y))
        return keras.utils.to_categorical(y, len(lang_dict)), lang_dict

    @staticmethod
    def get_wav(filename):
        """
            Loads a wav file from disk and resamples to a target sample rate.

            Args:
                filename (str): Path to the wav file.

            Returns:
                numpy.ndarray: Down-sampled wav file (or None if an error occurs).
        """
        try:
            y, sr = librosa.load(f'./data/native_combined/{filename}.wav')
            return librosa.core.resample(y=y, orig_sr=sr, target_sr=RATE, scale=True)
        except Exception as e:
            print(f"Error loading wav: {filename} - {e}")
            return None  # Or handle error differently

    @staticmethod
    def to_mfcc(wav):
        """
            Converts a wav file to Mel Frequency Ceptral Coefficients (MFCCs).
            Args:
                wav (numpy array): The wav form data.
                sr (int, optional): The sample rate of the audio. Defaults to None (use from data if available).
                n_mfcc (int, optional): The number of MFCC coefficients to extract. Defaults to None (use librosa's default).
            Returns:
                numpy.ndarray: A 2D numpy array containing the MFCC features.
            Raises:
                Exception: If an error occurs during processing.
        """
        try:
            return librosa.feature.mfcc(y=wav, sr=RATE, n_mfcc=N_MFCC)
        except Exception as e:
            print(f"Error converting wav to MFCC: {e}")
            return None  # Or handle error differently

    @staticmethod
    def normalize_mfcc(mfcc):
        '''
            Normalize mfcc
            :param mfcc:
            :return:
        '''
        mms = MinMaxScaler()
        return(mms.fit_transform(np.abs(mfcc)))

    @staticmethod
    def remove_silence(wav, thresh=0.04, chunk=5000):
        '''
            Searches wav form for segments of silence. If wav form values are lower than 'thresh' for 'chunk' samples, the values will be removed
            :param wav (np array): Wav array to be filtered
            :return (np array): Wav array with silence removed
        '''

        tf_list = []
        for x in range(len(wav) / chunk):
            if (np.any(wav[chunk * x:chunk * (x + 1)] >= thresh) or np.any(wav[chunk * x:chunk * (x + 1)] <= -thresh)):
                tf_list.extend([True] * chunk)
            else:
                tf_list.extend([False] * chunk)

        tf_list.extend((len(wav) - len(tf_list)) * [False])
        return(wav[tf_list])

    @staticmethod
    def make_segments(mfccs,labels):
        '''
            Makes segments of mfccs and attaches them to the labels
            :param mfccs: list of mfccs
            :param labels: list of labels
            :return (tuple): Segments with labels
        '''
        segments = []
        seg_labels = []
        for mfcc,label in zip(mfccs,labels):
            for start in range(0, int(mfcc.shape[1] / COL_SIZE)):
                segments.append(mfcc[:, start * COL_SIZE:(start + 1) * COL_SIZE])
                seg_labels.append(label)
        return (segments, seg_labels)

    @staticmethod
    def segment_one(mfcc):
        '''
            Creates segments from on mfcc image. If last segments is not long enough to be length of columns divided by COL_SIZE
            :param mfcc (numpy array): MFCC array
            :return (numpy array): Segmented MFCC array
        '''
        segments = []
        for start in range(0, int(mfcc.shape[1] / COL_SIZE)):
            segments.append(mfcc[:, start * COL_SIZE:(start + 1) * COL_SIZE])
        return(np.array(segments))

    @staticmethod
    def create_segmented_mfccs(X_train):
        '''
            Creates segmented MFCCs from X_train
            :param X_train: list of MFCCs
            :return: segmented mfccs
        '''
        segmented_mfccs = []
        for mfcc in X_train:
            segmented_mfccs.append(FeatureExtractorUtils.segment_one(mfcc))
        return(segmented_mfccs)

    @staticmethod
    def extract_mfcc_lst(audio_segment, sr=22050, n_mfcc=13, mel_filter_bank=20):
        """
            Extracts MFCCs from a given audio segment.
            Args:
                :param audio_segment: A NumPy array of the audio data.
                :param sr: Sampling rate of the audio (default: 22050 Hz).
                :param n_mfcc: Number of MFCC coefficients to extract (default: 13).
                :param mel_filter_bank: Number of mel filters to use (default: 20).
            Returns:
                A NumPy array of MFCC features for the audio segment.
        """
        mel_spectrogram = librosa.feature.melspectrogram(
            audio_segment, sr=sr, n_mels=mel_filter_bank
        )
        mfcc_lst = librosa.feature.mfcc(
            S=librosa.power_to_db(mel_spectrogram), 
            n_mfccs=n_mfcc
        )
        return mfcc_lst.T  # Transpose to have features as columns

    @staticmethod
    def normalize_mfcc_lst(mfcc_lst: np.array, method: str = None) -> np.array:
        """
            Normalizes MFCC features.

            Args:
                :param mfcc_lst: A NumPy array of MFCC features.
                :param method: Normalization method (default: None) -> This will use the MinMaxScaler.
                        Supported methods: 'minmax', 'standard'

            Returns:
                :return: The normalized MFCC features.
        """
        if method == 'minmax':
            return (mfcc_lst - np.min(mfcc_lst)) / (np.max(mfcc_lst) - np.min(mfcc_lst))
        elif method == 'standard':
            return (mfcc_lst - np.mean(mfcc_lst)) / np.std(mfcc_lst)
        else:
            mms = MinMaxScaler()
            return mms.fit_transform(np.abs(mfcc_lst))

    @staticmethod
    def reduce_dimensionality(mfcc_lst: np.array, n_components: int = 10) -> np.array:
        """
            Reduces the dimensionality of MFCC features using PCA.
            The number of principal components to retain is specified by n_components.

            Args:
                :param mfcc_lst: A NumPy array of MFCC features.
                :param n_components: Number of principal components to retain (default: 10).

            Returns:
                :return: The reduced MFCC features.
        """
        pca = PCA(n_components=n_components)
        reduced_mfcc_lst = pca.fit_transform(mfcc_lst)
        return reduced_mfcc_lst

    @staticmethod
    def combine_segments(mfcc_segments: list, method='mean'):
        """
            Combines MFCC features from multiple segments.
            Args:
                :param mfcc_segments: A list of NumPy arrays of MFCC features, one for each segment.
                :param method: Method for combining features (default: 'mean').
                        Supported methods: 'mean', 'concatenate'
            Returns:
                :return: A NumPy array of combined MFCC features.
        """
        if method == 'mean':
            return np.mean(mfcc_segments, axis=0)
        elif method == 'concatenate':
            return np.concatenate(mfcc_segments, axis=1)
        else:
            raise ValueError(f"Invalid combination method: {method}")

    @staticmethod
    def filter_df(dataframe: pd.DataFrame) -> pd.DataFrame:
        """
            Function to filter audio files based on df columns
            df column options: [age,age_of_english_onset,age_sex,birth_place,english_learning_method,
            english_residence,length_of_english_residence,native_language,other_languages,sex]
            :return (DataFrame): Filtered DataFrame
        """

        # if the dataframe['native_language'] has arabic, mandarin, or english then
        arabic = dataframe[dataframe.native_language == 'arabic']
        mandarin = dataframe[dataframe.native_language == 'mandarin']
        english = dataframe[dataframe.native_language == 'english']
        mandarin = mandarin[mandarin.length_of_english_residence < 10]
        arabic = arabic[arabic.length_of_english_residence < 10]
        # use concat to add the dataframes together
        return pd.concat(
            [
                dataframe,
                mandarin,
                arabic,
                english,
            ],
            ignore_index=True
        )

    @staticmethod
    def split_people(dataframe: pd.DataFrame, test_size: float = 0.2, second_column: str = 'english_residence'):
        """
            Create train test split of DataFrame
            Args:
                :param dataframe: DataFrame to be split
                :param test_size: Percentage of total files to be split into test
            Return:
                :return X_train, X_test, y_train, y_test (tuple): Xs are list of
                df['language_num'] and Ys are df['english_residence']
        """
        x_train, x_test, y_train, y_test = train_test_split(
            dataframe['language_num'],
            dataframe[second_column],
            test_size=test_size,
            train_size= 1 - test_size,
            random_state=1234
        )
        return x_train, x_test, y_train, y_test

# %%
class AudioFeatureExtractor:
    def __init__(self, path:str) -> None:
        """
            Initializes the feature extractor with the directory containing audio files of native speakers.
            Args:
                path (str): Directory path containing audio files of the native English speakers.
        """
        self.native_speakers_dir = path
        self.native_speakers_data = self.load_native_speakers_files()

    def load_native_speakers_files(self):
        """
            Loads the file paths of all audio files in the native speakers directory.
            Returns:
                list: A list containing the file paths of the native English speakers' audio files.
        """
        # This will list every file in the directory
        file_paths = [file for file in os.listdir(self.native_speakers_dir) if file.endswith('.wav')]
        return file_paths

    
    def combine_native_speakers(self, file_path, num_samples=1):
        """
            Combines a 1-second voice sample from the specified file with another 1-second sample
            from a randomly selected native speaker's voice to create a 2-second sample.
            Args:
                file_path (str): Path to the primary audio file.
                num_samples (int): Number of 1-second samples to combine with, should be 1 for a 2-second sample.
            Returns:
                np.ndarray: The combined 2-second audio waveform.
        """
        # print(os.path.join(self.native_speakers_dir, file_path))
        try:
            # Load the primary audio file and take a 1-second sample
            primary_y, sr = librosa.load(os.path.join(self.native_speakers_dir, file_path), sr=None)
            # primary_one_second = librosa.util.fix_length(primary_y, sr)[:sr]
            primary_one_second = librosa.util.fix_length(primary_y, size=num_samples)

            # Randomly select another native speaker file and take a 1-second sample
            random_file_path = random.choice(self.native_speakers_data)
            random_y, _ = librosa.load(os.path.join(self.native_speakers_dir, random_file_path), sr=None)
            # random_one_second = librosa.util.fix_length(random_y, sr)[:sr]
            random_one_second = librosa.util.fix_length(random_y, size=num_samples)

            # Concatenate the two 1-second samples to create a 2-second sample
            combined_y = np.concatenate((primary_one_second, random_one_second))
            return combined_y, sr

        except Exception as e:
            print(f"Error combining native speaker samples for {file_path}: {e}")
            return None, None

# %%
# # audio feature extraction instance
# audio_feature_extractor = AudioFeatureExtractor(path=NATIVE_DIR)
# # load native speaker files
# native_speakers_data = audio_feature_extractor.load_native_speakers_files()

# %%
# # # # NB: Only run this cell once to combine all native speakers

# # load all native speakers
# # native_speakers = []
# # native_sr = []
# os.makedirs('./data/native_combined', exist_ok=True)
# for file in native_speakers_data:
#     combined_y, sr = audio_feature_extractor.combine_native_speakers(file_path = file, num_samples = 1)
#     # native_speakers.append(combined_y)
#     # native_sr.append(sr)
#     sf.write(f'./data/native_combined/{file}', combined_y, sr, subtype='PCM_24')
#     # librosa.output.write_wav(f'data/audio/combined/{file}', combined_y, sr)

# %%
# load the native_bio_metadata.csv
native_bio_metadata = pd.read_csv(NATIVE_FILE_PATH)
native_bio_metadata.head()
# Out:
#                                                 href language_num     sex  \
# 0  http://accent.gmu.edu/browse_language.php?func...    mandarin1  female
# 1  http://accent.gmu.edu/browse_language.php?func...    mandarin2  female
# 2  http://accent.gmu.edu/browse_language.php?func...    mandarin3    male
# 3  http://accent.gmu.edu/browse_language.php?func...    mandarin4  female
# 4  http://accent.gmu.edu/browse_language.php?func...    mandarin5  female
#
#               birth_place  native_language  \
# 0    ['shanxi,', 'china']  mandarin\n(cmn)
# 1   ['nanjing,', 'china']  mandarin\n(cmn)
# 2     ['jilin,', 'china']  mandarin\n(cmn)
# 3  ['shanghai,', 'china']  mandarin\n(cmn)
# 4   ['beijing,', 'china']  mandarin\n(cmn)
#
#                        other_languages                age_sex  \
# 0                             ['none']  ['26,', 'female', '']
# 1                     ['japanese', '']  ['38,', 'female', '']
# 2  ['italian', 'german', 'french', '']    ['43,', 'male', '']
# 3                     ['japanese', '']  ['24,', 'female', '']
# 4                             ['none']  ['31,', 'female', '']
#
#    age_of_english_onset english_learning_method english_residence  \
# 0                  13.0                academic               usa
# 1                  14.0                academic               usa
# 2                  10.0                academic               usa
# 3                   6.0                academic               usa
# 4                  12.0                academic               usa
#
#    length_of_english_residence   age
# 0                          2.0  26.0
# 1                          0.8  38.0
# 2                         14.0  43.0
# 3                          1.0  24.0
# 4                          2.0  31.0

# %%
featureExtractorUtils = FeatureExtractorUtils()
xFeatureExtractor = XFeatureExtractor()

# %%
# split the native_combined_df into train and test
X_train, X_test, y_train, y_test = featureExtractorUtils.split_people(native_bio_metadata, test_size=0.2)

# %%
print(X_test.shape, y_test.shape)
# Out:
# (245,) (245,)

# %%
print(X_train.shape, y_train.shape)
# Out:
# (979,) (979,)

# %%
y_test = y_test.apply(lambda x: x.split('\n')[0])
y_train = y_train.apply(lambda x: x.split('\n')[0])

# %%
# Get statistics
train_count = Counter(y_train)
test_count = Counter(y_test)


print(f"Train Count: {train_count}")
print(f"Test Count: {test_count}")
# Out:
# Train Count: Counter({'usa': 824, 'uk': 95, 'canada': 60})
# Test Count: Counter({'usa': 207, 'uk': 20, 'canada': 18})

# %%
# y_train_encoded = LabelEncoder().fit_transform(y_train)
# y_test_encoded = LabelEncoder().fit_transform(y_test)
# y_train_cat = to_categorical(y_train_encoded)
# y_test_cat = to_categorical(y_test_encoded)

y_train_cat, _ = featureExtractorUtils.to_categorical(y_train)
y_test_cat, lang_dict = featureExtractorUtils.to_categorical(y_test)

# %%
lang_dict
# Out:
# {'uk': 0, 'canada': 1, 'usa': 2}

# %% [markdown]
# # Extract Prosodic, Accoustic and PLP features from audio files

# %%
with ThreadPoolExecutor() as pool:
    X_prosodic = pool.map(xFeatureExtractor.extract_prosodic_features, X_train)
    X_acoustic = pool.map(xFeatureExtractor.extract_acoustic_features, X_train)
    X_plp = pool.map(xFeatureExtractor.extract_plp, X_train)

# %%
with ThreadPoolExecutor() as pool:
    X_test_prosodic = pool.map(xFeatureExtractor.extract_prosodic_features, X_test)
    X_test_acoustic = pool.map(xFeatureExtractor.extract_acoustic_features, X_test)
    X_test_plp = pool.map(xFeatureExtractor.extract_plp, X_test)

# %% [markdown]
# # Train on SHARED Features

# %%
X_acoustic_list = list(X_acoustic)
X_prosodic_list = list(X_prosodic)
X_plp_list = list(X_plp)

print("Type of X_acoustic:", type(X_acoustic))
print("Length of X_acoustic:", len(X_acoustic_list))
# Out:
# Type of X_acoustic: <class 'generator'>
# Length of X_acoustic: 979

# %%
X_acoustic_test_list = list(X_test_acoustic)
X_prosodic_test_list = list(X_test_prosodic)
X_plp_test_list = list(X_test_plp)

# %%
def create_feature_model(X_train_np:np.array):
    # Separate Input Channels approach
    input_shape = X_train_np.shape[1:]  # Use the shape of the MFCC arrays
    mfcc_in = keras.layers.Input(shape=input_shape)
    mfcc_x = keras.layers.Conv1D(filters=16, kernel_size=3, activation='relu')(mfcc_in)
    merged = keras.layers.concatenate([mfcc_x])
    # merged = mfcc_in

    # Rest of the model definition (common for both approaches)
    x = keras.layers.MaxPooling1D(pool_size=2)(merged)
    x = keras.layers.Conv1D(filters=8, kernel_size=3, activation='relu')(x)
    x = keras.layers.MaxPooling1D(pool_size=2)(x)
    x = keras.layers.Flatten()(x)
    x = keras.layers.Dense(units=16, activation='relu')(x)
    outputs = keras.layers.Dense(3, activation='softmax')(x)  # 3 for usa, uk, canada classes

    model = keras.Model(
        inputs=[mfcc_in], outputs=outputs
    )
    model.compile(
        loss='categorical_crossentropy', 
        optimizer='adam', 
        metrics=['accuracy']
    )
    return model


def create_multi_feature_model(
    X_mfcc_np:np.array, 
    X_chroma_stft_np:np.array = None,
    X_spectral_centroid_np:np.array = None,
    use_separate_channels:bool = False
):
    if use_separate_channels and ((X_chroma_stft_np is not None) and (X_spectral_centroid_np is not None)):
        # Separate Input Channels approach
        input_shape_mfcc = X_mfcc_np.shape[1:]
        input_shape_chroma_stft = X_chroma_stft_np.shape[1:]
        input_shape_spectral_centroid = X_spectral_centroid_np.shape[1:]

        mfcc_in = keras.layers.Input(shape=input_shape_mfcc)
        chroma_stft_in = keras.layers.Input(shape=input_shape_chroma_stft)
        spectral_centroid_in = keras.layers.Input(shape=input_shape_spectral_centroid)

        mfcc_x = keras.layers.Conv1D(filters=32, kernel_size=3, activation='relu', padding='same')(mfcc_in)
        chroma_stft_x = keras.layers.Conv1D(filters=16, kernel_size=3, activation='relu', padding='same')(chroma_stft_in)
        spectral_centroid_x = keras.layers.Conv1D(filters=8, kernel_size=3, activation='relu', padding='same')(spectral_centroid_in)
        
        # mfcc_x = keras.layers.GlobalAveragePooling1D()(mfcc_x)
        # chroma_stft_x = keras.layers.GlobalAveragePooling1D()(chroma_stft_x)
        # spectral_centroid_x = keras.layers.GlobalAveragePooling1D()(spectral_centroid_x)
        
        merged = keras.layers.concatenate([mfcc_x, chroma_stft_x, spectral_centroid_x])
        
    elif use_separate_channels and (X_chroma_stft_np is not None):
        # Separate Input Channels approach
        input_shape_mfcc = X_mfcc_np.shape[1:]
        input_shape_chroma_stft = X_chroma_stft_np.shape[1:]

        mfcc_in = keras.layers.Input(shape=input_shape_mfcc)
        chroma_stft_in = keras.layers.Input(shape=input_shape_chroma_stft)

        mfcc_x = keras.layers.Conv1D(filters=16, kernel_size=3, activation='relu', padding='same')(mfcc_in)
        chroma_stft_x = keras.layers.Conv1D(filters=8, kernel_size=3, activation='relu', padding='same')(chroma_stft_in)
        
        # Apply global average pooling to reduce the dimensionality
        # mfcc_x = keras.layers.GlobalAveragePooling1D()(mfcc_x)
        # chroma_stft_x = keras.layers.GlobalAveragePooling1D()(chroma_stft_x)
        
        merged = keras.layers.concatenate([mfcc_x, chroma_stft_x])
        
    elif use_separate_channels and (X_spectral_centroid_np is not None):
        # Separate Input Channels approach
        input_shape_mfcc = X_mfcc_np.shape[1:]
        input_shape_spectral_centroid = X_spectral_centroid_np.shape[1:]

        mfcc_in = keras.layers.Input(shape=input_shape_mfcc)
        spectral_centroid_in = keras.layers.Input(shape=input_shape_spectral_centroid)

        mfcc_x = keras.layers.Conv1D(filters=16, kernel_size=3, activation='relu', padding='same')(mfcc_in)
        spectral_centroid_x = keras.layers.Conv1D(filters=8, kernel_size=3, activation='relu', padding='same')(spectral_centroid_in)
        
        # mfcc_x = keras.layers.GlobalAveragePooling1D()(mfcc_x)
        # chroma_stft_x = keras.layers.GlobalAveragePooling1D()(chroma_stft_x)

        merged = keras.layers.concatenate([mfcc_x, spectral_centroid_x])
    else:
        # Concatenation approach (assuming all features have same time-frequency dimensions)
        input_shape = X_mfcc_np.shape[1:]
        mfcc_in = keras.layers.Input(shape=input_shape)
        merged = mfcc_in

    # Rest of the model definition (common for both approaches)
    x = keras.layers.MaxPooling1D(pool_size=2)(merged)
    x = keras.layers.Conv1D(filters=32, kernel_size=3, activation='relu')(x)
    x = keras.layers.MaxPooling1D(pool_size=2)(x)
    x = keras.layers.Flatten()(x)
    x = keras.layers.Dense(units=64, activation='relu')(x)
    outputs = keras.layers.Dense(3, activation='softmax')(x)  # 3 for usa, uk, canada classes

    if use_separate_channels and ((X_chroma_stft_np is not None) and (X_spectral_centroid_np is not None)):
        model = keras.Model(inputs=[mfcc_in, chroma_stft_in, spectral_centroid_in], outputs=outputs)
    elif use_separate_channels and (X_chroma_stft_np is not None):
        model = keras.Model(inputs=[mfcc_in, chroma_stft_in], outputs=outputs)
    elif use_separate_channels and(X_spectral_centroid_np is not None):
        model = keras.Model(inputs=[mfcc_in, spectral_centroid_in], outputs=outputs)
    else:
        model = keras.Model(inputs=mfcc_in, outputs=outputs)

    model.compile(
        loss='categorical_crossentropy',
        optimizer='adam',
        metrics=['accuracy']
    )
    return model

def create_hybrid_model(
    X_mfcc_np:np.array, 
    X_chroma_stft_np:np.array = None,
    X_spectral_centroid_np:np.array = None,
    use_separate_channels:bool = False
) -> any:
    if use_separate_channels and ((X_chroma_stft_np is not None) and (X_spectral_centroid_np is not None)):
        # Separate Input Channels approach
        input_shape_mfcc = X_mfcc_np.shape[1:]
        input_shape_chroma_stft = X_chroma_stft_np.shape[1:]
        input_shape_spectral_centroid = X_spectral_centroid_np.shape[1:]

        mfcc_in = keras.layers.Input(shape=input_shape_mfcc)
        chroma_stft_in = keras.layers.Input(shape=input_shape_chroma_stft)
        spectral_centroid_in = keras.layers.Input(shape=input_shape_spectral_centroid)

        mfcc_x = keras.layers.Conv1D(filters=32, kernel_size=3, activation='relu', padding='same')(mfcc_in)
        chroma_stft_x = keras.layers.Conv1D(filters=16, kernel_size=3, activation='relu', padding='same')(chroma_stft_in)
        spectral_centroid_x = keras.layers.Conv1D(filters=8, kernel_size=3, activation='relu', padding='same')(spectral_centroid_in)
        
        # mfcc_x = keras.layers.GlobalAveragePooling1D()(mfcc_x)
        # chroma_stft_x = keras.layers.GlobalAveragePooling1D()(chroma_stft_x)
        # spectral_centroid_x = keras.layers.GlobalAveragePooling1D()(spectral_centroid_x)
        
        merged = keras.layers.concatenate([mfcc_x, chroma_stft_x, spectral_centroid_x])
        
    elif use_separate_channels and (X_chroma_stft_np is not None):
        # Separate Input Channels approach
        input_shape_mfcc = X_mfcc_np.shape[1:]
        input_shape_chroma_stft = X_chroma_stft_np.shape[1:]

        mfcc_in = keras.layers.Input(shape=input_shape_mfcc)
        chroma_stft_in = keras.layers.Input(shape=input_shape_chroma_stft)

        mfcc_x = keras.layers.Conv1D(filters=16, kernel_size=3, activation='relu', padding='same')(mfcc_in)
        chroma_stft_x = keras.layers.Conv1D(filters=8, kernel_size=3, activation='relu', padding='same')(chroma_stft_in)
        
        # Apply global average pooling to reduce the dimensionality
        # mfcc_x = keras.layers.GlobalAveragePooling1D()(mfcc_x)
        # chroma_stft_x = keras.layers.GlobalAveragePooling1D()(chroma_stft_x)
        
        merged = keras.layers.concatenate([mfcc_x, chroma_stft_x])
        
    elif use_separate_channels and (X_spectral_centroid_np is not None):
        # Separate Input Channels approach
        input_shape_mfcc = X_mfcc_np.shape[1:]
        input_shape_spectral_centroid = X_spectral_centroid_np.shape[1:]

        mfcc_in = keras.layers.Input(shape=input_shape_mfcc)
        spectral_centroid_in = keras.layers.Input(shape=input_shape_spectral_centroid)

        mfcc_x = keras.layers.Conv1D(filters=16, kernel_size=3, activation='relu', padding='same')(mfcc_in)
        spectral_centroid_x = keras.layers.Conv1D(filters=8, kernel_size=3, activation='relu', padding='same')(spectral_centroid_in)
        
        # mfcc_x = keras.layers.GlobalAveragePooling1D()(mfcc_x)
        # chroma_stft_x = keras.layers.GlobalAveragePooling1D()(chroma_stft_x)

        merged = keras.layers.concatenate([mfcc_x, spectral_centroid_x])
    else:
        # Concatenation approach (assuming all features have same time-frequency dimensions)
        input_shape = X_mfcc_np.shape[1:]
        mfcc_in = keras.layers.Input(shape=input_shape)
        merged = mfcc_in

    # Rest of the model definition (common for both approaches)
    x = keras.layers.MaxPooling1D(pool_size=2)(merged)
    x = keras.layers.Conv1D(filters=128, kernel_size=3, activation='relu')(x)
    x = keras.layers.MaxPooling1D(pool_size=2)(x)
    # x = keras.layers.Flatten()(x)
    x = keras.layers.LSTM(128, return_sequences=True)(x)
    x = keras.layers.LSTM(128)(x)
    # x = keras.layers.LSTM(128)(x)
    x = keras.layers.Dense(units=64, activation='relu')(x)
    outputs = keras.layers.Dense(3, activation='softmax')(x)  # 3 for usa, uk, canada classes

    if use_separate_channels and ((X_chroma_stft_np is not None) and (X_spectral_centroid_np is not None)):
        model = keras.Model(inputs=[mfcc_in, chroma_stft_in, spectral_centroid_in], outputs=outputs)
    elif use_separate_channels and (X_chroma_stft_np is not None):
        model = keras.Model(inputs=[mfcc_in, chroma_stft_in], outputs=outputs)
    elif use_separate_channels and(X_spectral_centroid_np is not None):
        model = keras.Model(inputs=[mfcc_in, spectral_centroid_in], outputs=outputs)
    else:
        model = keras.Model(inputs=mfcc_in, outputs=outputs)

    model.compile(
        loss='categorical_crossentropy',
        optimizer='adam',
        metrics=['accuracy']
    )
    
    return model

# %% [markdown]
# # for multi-feature model use below cells

# %%
max_length = 2000
chroma_stft_list = []
spectral_centroid_list = []
mfcc_list = []

for sample in X_acoustic_list:
    mfcc_array = np.array(sample['mfcc'])
    chroma_stft_array = np.array(sample['chroma_stft'])
    spectral_centroid_array = np.array(sample['spectral_centroid'])
    
    if mfcc_array.shape[1] < max_length:
        padded_mfcc_array = np.pad(mfcc_array, ((0, 0), (0, max_length - mfcc_array.shape[1])), mode='constant')
    else:
        padded_mfcc_array = mfcc_array[:, :max_length]

    # Pad or truncate arrays to max_length if needed
    if chroma_stft_array.shape[1] < max_length:
        padded_chroma_stft_array = np.pad(chroma_stft_array, ((0, 0), (0, max_length - chroma_stft_array.shape[1])), mode='constant')
    else:
        padded_chroma_stft_array = chroma_stft_array[:, :max_length]

    if spectral_centroid_array.shape[1] < max_length:
        padded_spectral_centroid_array = np.pad(spectral_centroid_array, ((0, 0), (0, max_length - spectral_centroid_array.shape[1])), mode='constant')
    else:
        padded_spectral_centroid_array = spectral_centroid_array[:, :max_length]

    mfcc_list.append(padded_mfcc_array)
    chroma_stft_list.append(padded_chroma_stft_array)
    spectral_centroid_list.append(padded_spectral_centroid_array)

# Convert the lists of processed features into numpy arrays
X_mfcc_stft_np = np.array(mfcc_list)
X_chroma_stft_np = np.array(chroma_stft_list)
X_spectral_centroid_np = np.array(spectral_centroid_list)

# %%
# # # Test values

max_length = 2000
mfcc_test_list = []
chroma_test_stft_list = []
spectral_test_centroid_list = []

for sample in X_acoustic_test_list:
    mfcc_test_array = np.array(sample['mfcc'])
    chroma_test_stft_array = np.array(sample['chroma_stft'])
    spectral_test_centroid_array = np.array(sample['spectral_centroid'])
    
    if mfcc_test_array.shape[1] < max_length:
        padded_mfcc_test_array = np.pad(mfcc_test_array, ((0, 0), (0, max_length - mfcc_test_array.shape[1])), mode='constant')
    else:
        padded_mfcc_test_array = mfcc_test_array[:, :max_length]

    # Pad or truncate arrays to max_length if needed
    if chroma_test_stft_array.shape[1] < max_length:
        padded_chroma_test_stft_array = np.pad(chroma_test_stft_array, ((0, 0), (0, max_length - chroma_test_stft_array.shape[1])), mode='constant')
    else:
        padded_chroma_test_stft_array = chroma_test_stft_array[:, :max_length]

    if spectral_test_centroid_array.shape[1] < max_length:
        padded_spectral_test_centroid_array = np.pad(spectral_test_centroid_array, ((0, 0), (0, max_length - spectral_test_centroid_array.shape[1])), mode='constant')
    else:
        padded_spectral_test_centroid_array = spectral_test_centroid_array[:, :max_length]

    mfcc_test_list.append(padded_mfcc_test_array)
    chroma_test_stft_list.append(padded_chroma_test_stft_array)
    spectral_test_centroid_list.append(padded_spectral_test_centroid_array)

# Convert the lists of processed features into numpy arrays
X_mfcc_stft_test_np = np.array(mfcc_test_list)
X_chroma_stft_test_np = np.array(chroma_test_stft_list)
X_spectral_centroid_test_np = np.array(spectral_test_centroid_list)

# %%
# Pad or truncate the arrays to ensure they have the same shape along the concatenation axis
max_length = max(X_mfcc_stft_np.shape[1], X_chroma_stft_np.shape[1])
X_mfcc_np_padded = np.pad(
    X_mfcc_stft_np, 
    ((0, 0), (0, max_length - X_mfcc_stft_np.shape[1]), (0, 0)), 
    mode='constant'
)
X_chroma_stft_np_padded = np.pad(
    X_chroma_stft_np, 
    ((0, 0), (0, max_length - X_chroma_stft_np.shape[1]), (0, 0)), 
    mode='constant'
)

# %%
# Pad or truncate the arrays to ensure they have the same shape along the concatenation axis
max_length_test = max(X_mfcc_stft_test_np.shape[1], X_chroma_stft_test_np.shape[1])
X_mfcc_test_np_padded = np.pad(X_mfcc_stft_test_np, ((0, 0), (0, max_length_test - X_mfcc_stft_test_np.shape[1]), (0, 0)), mode='constant')
X_chroma_test_stft_np_padded = np.pad(X_chroma_stft_test_np, ((0, 0), (0, max_length_test - X_chroma_stft_test_np.shape[1]), (0, 0)), mode='constant')

# %%
# Choose the approach (concatenation or separate channels)
use_separate_channels = True

# Create CNN architecture
multi_model = create_multi_feature_model(
    X_mfcc_np=X_mfcc_np_padded,
    X_chroma_stft_np=X_chroma_stft_np_padded,
    # X_spectral_centroid_np=X_spectral_centroid_np,
    use_separate_channels=use_separate_channels
)
# Out:
# WARNING:tensorflow:From c:\Users\musah\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\Users\musah\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:6642: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From c:\Users\musah\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# model summary
multi_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 40, 2000)]           0         []
#
#  input_2 (InputLayer)        [(None, 40, 2000)]           0         []
#
#  conv1d (Conv1D)             (None, 40, 16)               96016     ['input_1[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 40, 8)                48008     ['input_2[0][0]']
#
#  concatenate (Concatenate)   (None, 40, 24)               0         ['conv1d[0][0]',
#                                                                      'conv1d_1[0][0]']
#
#  max_pooling1d (MaxPooling1  (None, 20, 24)               0         ['concatenate[0][0]']
#  D)
#
#  conv1d_2 (Conv1D)           (None, 18, 32)               2336      ['max_pooling1d[0][0]']
#
#  max_pooling1d_1 (MaxPoolin  (None, 9, 32)                0         ['conv1d_2[0][0]']
#  g1D)
#
#  flatten (Flatten)           (None, 288)                  0         ['max_pooling1d_1[0][0]']
#
#  dense (Dense)               (None, 64)                   18496     ['flatten[0][0]']
#
#  dense_1 (Dense)             (None, 3)                    195       ['dense[0][0]']
#
# ==================================================================================================
# Total params: 165051 (644.73 KB)
# Trainable params: 165051 (644.73 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
os.makedirs("files", exist_ok=True)

# %%
# plot the model
keras.utils.plot_model(multi_model, to_file='files/multi_feature_model.png', show_shapes=False)

# %%
history = multi_model.fit(
    [X_mfcc_np_padded, X_chroma_stft_np_padded], 
    y_train_cat,
    epochs=EPOCHS,
    validation_data=([X_mfcc_test_np_padded, X_chroma_test_stft_np_padded], y_test_cat)
)
# Out:
# Epoch 1/150
# WARNING:tensorflow:From c:\Users\musah\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\musah\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 31/31 [==============================] - 4s 32ms/step - loss: 13.2606 - accuracy: 0.7252 - val_loss: 9.3379 - val_accuracy: 0.8327
# Epoch 2/150
# 31/31 [==============================] - 1s 18ms/step - loss: 5.3431 - accuracy: 0.7640 - val_loss: 4.0725 - val_accuracy: 0.6776
# Epoch 3/150
# 31/31 [==============================] - 1s 19ms/step - loss: 2.7312 - accuracy: 0.8008 - val_loss: 3.6330 - val_accuracy: 0.7755
# Epoch 4/150
# 31/31 [==============================] - 1s 19ms/step - loss: 1.8296 - accuracy: 0.8366 - val_loss: 3.9661 - val_accuracy: 0.6980
# Epoch 5/150
# 31/31 [==============================] - 1s 19ms/step - loss: 3.9423 - accuracy: 0.8090 - val_loss: 4.0607 - val_accuracy: 0.7102
# Epoch 6/150
# 31/31 [==============================] - 1s 18ms/step - loss: 2.2567 - accuracy: 0.8407 - val_loss: 4.7349 - val_accuracy: 0.6816
# Epoch 7/150
# 31/31 [==============================] - 1s 17ms/step - loss: 1.0344 - accuracy: 0.8764 - val_loss: 3.6579 - val_accuracy: 0.8082
# Epoch 8/150
# 31/31 [==============================] - 1s 18ms/step - loss: 0.8684 - accuracy: 0.9101 - val_loss: 3.0802 - val_accuracy: 0.7388
# Epoch 9/150
# 31/31 [==============================] - 1s 17ms/step - loss: 0.6596 - accuracy: 0.9030 - val_loss: 2.8961 - val_accuracy: 0.7837
# Epoch 10/150
# 31/31 [==============================] - 1s 17ms/step - loss: 0.6315 - accuracy: 0.9316 - val_loss: 4.0574 - val_accuracy: 0.6531
# Epoch 11/150
# 31/31 [==============================] - 1s 17ms/step - loss: 0.6677 - accuracy: 0.9173 - val_loss: 3.2774 - val_accuracy: 0.6082
# Epoch 12/150
# 31/31 [==============================] - 1s 18ms/step - loss: 0.8706 - accuracy: 0.8999 - val_loss: 2.8864 - val_accuracy: 0.7265
# Epoch 13/150
# 31/31 [==============================] - 1s 17ms/step - loss: 0.7874 - accuracy: 0.9193 - val_loss: 4.3127 - val_accuracy: 0.6286
# Epoch 14/150
# 31/31 [==============================] - 1s 17ms/step - loss: 1.0212 - accuracy: 0.8958 - val_loss: 6.0881 - val_accuracy: 0.6735
# Epoch 15/150
# 31/31 [==============================] - 1s 17ms/step - loss: 1.1465 - accuracy: 0.8927 - val_loss: 4.1614 - val_accuracy: 0.8245
# Epoch 16/150
# 31/31 [==============================] - 1s 17ms/step - loss: 0.7125 - accuracy: 0.9183 - val_loss: 2.9260 - val_accuracy: 0.7306
# Epoch 17/150
# 31/31 [==============================] - 1s 19ms/step - loss: 0.6704 - accuracy: 0.9193 - val_loss: 3.2508 - val_accuracy: 0.7347
# Epoch 18/150
# 31/31 [==============================] - 1s 21ms/step - loss: 0.7013 - accuracy: 0.9224 - val_loss: 2.9430 - val_accuracy: 0.7306
# Epoch 19/150
# 31/31 [==============================] - 1s 21ms/step - loss: 0.6963 - accuracy: 0.9326 - val_loss: 2.9883 - val_accuracy: 0.7918
# Epoch 20/150
# 31/31 [==============================] - 1s 17ms/step - loss: 0.5592 - accuracy: 0.9326 - val_loss: 3.4692 - val_accuracy: 0.7755
# Epoch 21/150
# 31/31 [==============================] - 1s 18ms/step - loss: 0.6870 - accuracy: 0.9152 - val_loss: 2.8578 - val_accuracy: 0.7755
# Epoch 22/150
# 31/31 [==============================] - 1s 18ms/step - loss: 0.4614 - accuracy: 0.9326 - val_loss: 2.5546 - val_accuracy: 0.7020
# Epoch 23/150
# 31/31 [==============================] - 1s 19ms/step - loss: 0.7111 - accuracy: 0.9254 - val_loss: 3.5873 - val_accuracy: 0.7347
# Epoch 24/150
# 31/31 [==============================] - 1s 16ms/step - loss: 0.7094 - accuracy: 0.8958 - val_loss: 2.9552 - val_accuracy: 0.8041
# Epoch 25/150
# 31/31 [==============================] - 1s 19ms/step - loss: 0.7045 - accuracy: 0.9060 - val_loss: 2.7831 - val_accuracy: 0.7918
# Epoch 26/150
# 31/31 [==============================] - 1s 19ms/step - loss: 0.6551 - accuracy: 0.9234 - val_loss: 2.4165 - val_accuracy: 0.7184
# Epoch 27/150
# 31/31 [==============================] - 1s 17ms/step - loss: 0.4223 - accuracy: 0.9356 - val_loss: 2.5436 - val_accuracy: 0.7143
# Epoch 28/150
# 31/31 [==============================] - 0s 16ms/step - loss: 0.4836 - accuracy: 0.9336 - val_loss: 2.7261 - val_accuracy: 0.7633
# Epoch 29/150
# 31/31 [==============================] - 0s 16ms/step - loss: 0.5215 - accuracy: 0.9285 - val_loss: 3.1185 - val_accuracy: 0.6816
# Epoch 30/150
# 31/31 [==============================] - 1s 17ms/step - loss: 0.6936 - accuracy: 0.9173 - val_loss: 1.8538 - val_accuracy: 0.7143
# Epoch 31/150
# 31/31 [==============================] - 1s 17ms/step - loss: 0.4413 - accuracy: 0.9275 - val_loss: 2.3866 - val_accuracy: 0.8122
# Epoch 32/150
# 31/31 [==============================] - 1s 17ms/step - loss: 0.5093 - accuracy: 0.9244 - val_loss: 2.1637 - val_accuracy: 0.7224
# Epoch 33/150
# 31/31 [==============================] - 1s 18ms/step - loss: 0.5379 - accuracy: 0.9101 - val_loss: 1.9844 - val_accuracy: 0.7551
# Epoch 34/150
# 31/31 [==============================] - 1s 18ms/step - loss: 0.4223 - accuracy: 0.9275 - val_loss: 2.3177 - val_accuracy: 0.7224
# Epoch 35/150
# 31/31 [==============================] - 1s 19ms/step - loss: 0.4879 - accuracy: 0.9305 - val_loss: 2.4758 - val_accuracy: 0.7837
# Epoch 36/150
# 31/31 [==============================] - 1s 17ms/step - loss: 0.5125 - accuracy: 0.9213 - val_loss: 3.1363 - val_accuracy: 0.8163
# Epoch 37/150
# 31/31 [==============================] - 1s 16ms/step - loss: 0.5129 - accuracy: 0.9183 - val_loss: 2.7959 - val_accuracy: 0.8286
# Epoch 38/150
# 31/31 [==============================] - 1s 22ms/step - loss: 0.4065 - accuracy: 0.9305 - val_loss: 2.0864 - val_accuracy: 0.7633
# Epoch 39/150
# 31/31 [==============================] - 0s 16ms/step - loss: 0.4735 - accuracy: 0.9193 - val_loss: 1.8510 - val_accuracy: 0.8000
# Epoch 40/150
# 31/31 [==============================] - 1s 16ms/step - loss: 0.3090 - accuracy: 0.9459 - val_loss: 2.2669 - val_accuracy: 0.8041
# Epoch 41/150
# 31/31 [==============================] - 1s 19ms/step - loss: 0.3554 - accuracy: 0.9336 - val_loss: 1.9719 - val_accuracy: 0.6612
# Epoch 42/150
# 31/31 [==============================] - 0s 16ms/step - loss: 0.3751 - accuracy: 0.9346 - val_loss: 2.1570 - val_accuracy: 0.7551
# Epoch 43/150
# 31/31 [==============================] - 1s 20ms/step - loss: 0.2822 - accuracy: 0.9418 - val_loss: 1.6762 - val_accuracy: 0.7551
# Epoch 44/150
# 31/31 [==============================] - 1s 17ms/step - loss: 0.2897 - accuracy: 0.9408 - val_loss: 1.8516 - val_accuracy: 0.8000
# Epoch 45/150
# 31/31 [==============================] - 1s 18ms/step - loss: 0.3863 - accuracy: 0.9408 - val_loss: 2.1136 - val_accuracy: 0.6245
# Epoch 46/150
# 31/31 [==============================] - 1s 19ms/step - loss: 0.4549 - accuracy: 0.9101 - val_loss: 2.0160 - val_accuracy: 0.8122
# Epoch 47/150
# 31/31 [==============================] - 1s 18ms/step - loss: 0.3622 - accuracy: 0.9418 - val_loss: 2.0897 - val_accuracy: 0.7143
# Epoch 48/150
# 31/31 [==============================] - 0s 16ms/step - loss: 0.3803 - accuracy: 0.9346 - val_loss: 3.1705 - val_accuracy: 0.8204
# Epoch 49/150
# 31/31 [==============================] - 0s 15ms/step - loss: 0.3997 - accuracy: 0.9295 - val_loss: 2.1533 - val_accuracy: 0.8082
# Epoch 50/150
# 31/31 [==============================] - 1s 17ms/step - loss: 0.2972 - accuracy: 0.9397 - val_loss: 1.7393 - val_accuracy: 0.7714
# Epoch 51/150
# 31/31 [==============================] - 1s 17ms/step - loss: 0.3827 - accuracy: 0.9305 - val_loss: 2.2342 - val_accuracy: 0.8082
# Epoch 52/150
# 31/31 [==============================] - 0s 15ms/step - loss: 0.3576 - accuracy: 0.9336 - val_loss: 1.9357 - val_accuracy: 0.7837
# Epoch 53/150
# 31/31 [==============================] - 1s 19ms/step - loss: 0.3449 - accuracy: 0.9305 - val_loss: 1.8680 - val_accuracy: 0.6776
# Epoch 54/150
# 31/31 [==============================] - 1s 18ms/step - loss: 0.3834 - accuracy: 0.9326 - val_loss: 2.5673 - val_accuracy: 0.8286
# Epoch 55/150
# 31/31 [==============================] - 1s 18ms/step - loss: 0.3393 - accuracy: 0.9295 - val_loss: 1.9130 - val_accuracy: 0.8000
# Epoch 56/150
# 31/31 [==============================] - 1s 19ms/step - loss: 0.3475 - accuracy: 0.9408 - val_loss: 2.7239 - val_accuracy: 0.8245
# Epoch 57/150
# 31/31 [==============================] - 1s 18ms/step - loss: 0.2797 - accuracy: 0.9397 - val_loss: 1.7982 - val_accuracy: 0.7755
# Epoch 58/150
# 31/31 [==============================] - 1s 19ms/step - loss: 0.2486 - accuracy: 0.9356 - val_loss: 1.7465 - val_accuracy: 0.7959
# Epoch 59/150
# 31/31 [==============================] - 1s 22ms/step - loss: 0.2416 - accuracy: 0.9408 - val_loss: 1.5289 - val_accuracy: 0.7755
# Epoch 60/150
# 31/31 [==============================] - 1s 21ms/step - loss: 0.3036 - accuracy: 0.9326 - val_loss: 1.3884 - val_accuracy: 0.7510
# Epoch 61/150
# 31/31 [==============================] - 1s 19ms/step - loss: 0.2270 - accuracy: 0.9387 - val_loss: 2.0569 - val_accuracy: 0.6490
# Epoch 62/150
# 31/31 [==============================] - 1s 21ms/step - loss: 0.2220 - accuracy: 0.9408 - val_loss: 1.5206 - val_accuracy: 0.7755
# Epoch 63/150
# 31/31 [==============================] - 1s 21ms/step - loss: 0.2121 - accuracy: 0.9408 - val_loss: 1.5441 - val_accuracy: 0.7633
# Epoch 64/150
# 31/31 [==============================] - 1s 22ms/step - loss: 0.2605 - accuracy: 0.9336 - val_loss: 1.8086 - val_accuracy: 0.8082
# Epoch 65/150
# 31/31 [==============================] - 1s 23ms/step - loss: 0.2688 - accuracy: 0.9397 - val_loss: 1.4038 - val_accuracy: 0.7918
# Epoch 66/150
# 31/31 [==============================] - 1s 21ms/step - loss: 0.2442 - accuracy: 0.9397 - val_loss: 1.5096 - val_accuracy: 0.7837
# Epoch 67/150
# 31/31 [==============================] - 1s 18ms/step - loss: 0.2313 - accuracy: 0.9408 - val_loss: 1.5864 - val_accuracy: 0.7918
# Epoch 68/150
# 31/31 [==============================] - 1s 17ms/step - loss: 0.3217 - accuracy: 0.9408 - val_loss: 1.5848 - val_accuracy: 0.6776
# Epoch 69/150
# 31/31 [==============================] - 1s 16ms/step - loss: 0.2011 - accuracy: 0.9408 - val_loss: 1.2906 - val_accuracy: 0.7918
# Epoch 70/150
# 31/31 [==============================] - 0s 16ms/step - loss: 0.2483 - accuracy: 0.9367 - val_loss: 1.4996 - val_accuracy: 0.8082
# Epoch 71/150
# 31/31 [==============================] - 0s 16ms/step - loss: 0.2141 - accuracy: 0.9367 - val_loss: 1.7132 - val_accuracy: 0.7592
# Epoch 72/150
# 31/31 [==============================] - 1s 18ms/step - loss: 0.2245 - accuracy: 0.9377 - val_loss: 1.5415 - val_accuracy: 0.7796
# Epoch 73/150
# 31/31 [==============================] - 1s 17ms/step - loss: 0.1958 - accuracy: 0.9377 - val_loss: 1.2805 - val_accuracy: 0.7347
# Epoch 74/150
# 31/31 [==============================] - 1s 17ms/step - loss: 0.1769 - accuracy: 0.9418 - val_loss: 1.4640 - val_accuracy: 0.8163
# Epoch 75/150
# 31/31 [==============================] - 1s 17ms/step - loss: 0.1890 - accuracy: 0.9438 - val_loss: 1.3314 - val_accuracy: 0.7633
# Epoch 76/150
# 31/31 [==============================] - 1s 19ms/step - loss: 0.1362 - accuracy: 0.9489 - val_loss: 1.4162 - val_accuracy: 0.8000
# Epoch 77/150
# 31/31 [==============================] - 1s 18ms/step - loss: 0.1495 - accuracy: 0.9408 - val_loss: 1.3672 - val_accuracy: 0.8000
# Epoch 78/150
# 31/31 [==============================] - 0s 16ms/step - loss: 0.1770 - accuracy: 0.9377 - val_loss: 1.1781 - val_accuracy: 0.7551
# Epoch 79/150
# 31/31 [==============================] - 1s 17ms/step - loss: 0.1570 - accuracy: 0.9418 - val_loss: 1.0501 - val_accuracy: 0.7388
# Epoch 80/150
# 31/31 [==============================] - 1s 17ms/step - loss: 0.1518 - accuracy: 0.9448 - val_loss: 1.1789 - val_accuracy: 0.7673
# Epoch 81/150
# 31/31 [==============================] - 1s 21ms/step - loss: 0.1892 - accuracy: 0.9326 - val_loss: 1.0953 - val_accuracy: 0.7918
# Epoch 82/150
# 31/31 [==============================] - 1s 17ms/step - loss: 0.1545 - accuracy: 0.9459 - val_loss: 1.1779 - val_accuracy: 0.7959
# Epoch 83/150
# 31/31 [==============================] - 1s 20ms/step - loss: 0.1363 - accuracy: 0.9459 - val_loss: 1.1296 - val_accuracy: 0.7959
# Epoch 84/150
# 31/31 [==============================] - 1s 18ms/step - loss: 0.1382 - accuracy: 0.9438 - val_loss: 1.1459 - val_accuracy: 0.7918
# Epoch 85/150
# 31/31 [==============================] - 1s 19ms/step - loss: 0.1336 - accuracy: 0.9408 - val_loss: 1.0737 - val_accuracy: 0.7837
# Epoch 86/150
# 31/31 [==============================] - 1s 17ms/step - loss: 0.1373 - accuracy: 0.9489 - val_loss: 1.1091 - val_accuracy: 0.7959
# Epoch 87/150
# 31/31 [==============================] - 1s 18ms/step - loss: 0.1410 - accuracy: 0.9479 - val_loss: 1.2033 - val_accuracy: 0.8082
# Epoch 88/150
# 31/31 [==============================] - 1s 17ms/step - loss: 0.1433 - accuracy: 0.9438 - val_loss: 1.1299 - val_accuracy: 0.7755
# Epoch 89/150
# 31/31 [==============================] - 1s 17ms/step - loss: 0.1350 - accuracy: 0.9438 - val_loss: 1.0974 - val_accuracy: 0.7755
# Epoch 90/150
# 31/31 [==============================] - 1s 18ms/step - loss: 0.1258 - accuracy: 0.9367 - val_loss: 1.0960 - val_accuracy: 0.8204
# Epoch 91/150
# 31/31 [==============================] - 1s 17ms/step - loss: 0.1176 - accuracy: 0.9428 - val_loss: 1.2361 - val_accuracy: 0.8204
# Epoch 92/150
# 31/31 [==============================] - 0s 16ms/step - loss: 0.1241 - accuracy: 0.9520 - val_loss: 1.0048 - val_accuracy: 0.8286
# Epoch 93/150
# 31/31 [==============================] - 1s 17ms/step - loss: 0.1484 - accuracy: 0.9428 - val_loss: 1.0550 - val_accuracy: 0.8245
# Epoch 94/150
# 31/31 [==============================] - 0s 16ms/step - loss: 0.1111 - accuracy: 0.9418 - val_loss: 1.1513 - val_accuracy: 0.8122
# Epoch 95/150
# 31/31 [==============================] - 0s 16ms/step - loss: 0.1274 - accuracy: 0.9448 - val_loss: 0.9911 - val_accuracy: 0.8041
# Epoch 96/150
# 31/31 [==============================] - 0s 16ms/step - loss: 0.1183 - accuracy: 0.9469 - val_loss: 1.1942 - val_accuracy: 0.8163
# Epoch 97/150
# 31/31 [==============================] - 0s 15ms/step - loss: 0.1141 - accuracy: 0.9479 - val_loss: 0.9504 - val_accuracy: 0.8163
# Epoch 98/150
# 31/31 [==============================] - 1s 18ms/step - loss: 0.1320 - accuracy: 0.9367 - val_loss: 0.9671 - val_accuracy: 0.8122
# Epoch 99/150
# 31/31 [==============================] - 1s 17ms/step - loss: 0.1150 - accuracy: 0.9377 - val_loss: 1.1525 - val_accuracy: 0.8245
# Epoch 100/150
# 31/31 [==============================] - 1s 18ms/step - loss: 0.1241 - accuracy: 0.9346 - val_loss: 1.0102 - val_accuracy: 0.8122
# Epoch 101/150
# 31/31 [==============================] - 1s 18ms/step - loss: 0.1258 - accuracy: 0.9448 - val_loss: 1.0105 - val_accuracy: 0.8245
# Epoch 102/150
# 31/31 [==============================] - 1s 19ms/step - loss: 0.1190 - accuracy: 0.9428 - val_loss: 0.9327 - val_accuracy: 0.8245
# Epoch 103/150
# 31/31 [==============================] - 1s 18ms/step - loss: 0.1402 - accuracy: 0.9377 - val_loss: 1.4727 - val_accuracy: 0.8204
# Epoch 104/150
# 31/31 [==============================] - 1s 18ms/step - loss: 0.1522 - accuracy: 0.9346 - val_loss: 1.1614 - val_accuracy: 0.7918
# Epoch 105/150
# 31/31 [==============================] - 1s 19ms/step - loss: 0.1329 - accuracy: 0.9459 - val_loss: 0.9902 - val_accuracy: 0.7633
# Epoch 106/150
# 31/31 [==============================] - 1s 17ms/step - loss: 0.1373 - accuracy: 0.9397 - val_loss: 1.0398 - val_accuracy: 0.8245
# Epoch 107/150
# 31/31 [==============================] - 1s 19ms/step - loss: 0.1491 - accuracy: 0.9428 - val_loss: 0.9618 - val_accuracy: 0.7673
# Epoch 108/150
# 31/31 [==============================] - 1s 20ms/step - loss: 0.1692 - accuracy: 0.9377 - val_loss: 1.2540 - val_accuracy: 0.8122
# Epoch 109/150
# 31/31 [==============================] - 1s 20ms/step - loss: 0.1279 - accuracy: 0.9469 - val_loss: 1.1465 - val_accuracy: 0.7918
# Epoch 110/150
# 31/31 [==============================] - 1s 22ms/step - loss: 0.1319 - accuracy: 0.9397 - val_loss: 1.0125 - val_accuracy: 0.7388
# Epoch 111/150
# 31/31 [==============================] - 1s 22ms/step - loss: 0.1265 - accuracy: 0.9469 - val_loss: 1.0798 - val_accuracy: 0.8000
# Epoch 112/150
# 31/31 [==============================] - 1s 22ms/step - loss: 0.1282 - accuracy: 0.9459 - val_loss: 1.2032 - val_accuracy: 0.8204
# Epoch 113/150
# 31/31 [==============================] - 1s 21ms/step - loss: 0.1155 - accuracy: 0.9387 - val_loss: 1.1344 - val_accuracy: 0.8163
# Epoch 114/150
# 31/31 [==============================] - 1s 19ms/step - loss: 0.1303 - accuracy: 0.9377 - val_loss: 1.2523 - val_accuracy: 0.8204
# Epoch 115/150
# 31/31 [==============================] - 1s 18ms/step - loss: 0.1256 - accuracy: 0.9377 - val_loss: 1.0552 - val_accuracy: 0.8204
# Epoch 116/150
# 31/31 [==============================] - 1s 17ms/step - loss: 0.1098 - accuracy: 0.9356 - val_loss: 1.1833 - val_accuracy: 0.8204
# Epoch 117/150
# 31/31 [==============================] - 0s 15ms/step - loss: 0.1072 - accuracy: 0.9510 - val_loss: 1.0672 - val_accuracy: 0.8041
# Epoch 118/150
# 31/31 [==============================] - 1s 17ms/step - loss: 0.1116 - accuracy: 0.9418 - val_loss: 0.9639 - val_accuracy: 0.8204
# Epoch 119/150
# 31/31 [==============================] - 1s 18ms/step - loss: 0.1019 - accuracy: 0.9438 - val_loss: 1.1200 - val_accuracy: 0.8041
# Epoch 120/150
# 31/31 [==============================] - 1s 21ms/step - loss: 0.1104 - accuracy: 0.9397 - val_loss: 1.0811 - val_accuracy: 0.7918
# Epoch 121/150
# 31/31 [==============================] - 1s 23ms/step - loss: 0.1143 - accuracy: 0.9459 - val_loss: 1.2084 - val_accuracy: 0.8204
# Epoch 122/150
# 31/31 [==============================] - 1s 24ms/step - loss: 0.1017 - accuracy: 0.9387 - val_loss: 0.9904 - val_accuracy: 0.8041
# Epoch 123/150
# 31/31 [==============================] - 1s 21ms/step - loss: 0.1145 - accuracy: 0.9428 - val_loss: 1.3309 - val_accuracy: 0.8122
# Epoch 124/150
# 31/31 [==============================] - 1s 18ms/step - loss: 0.1146 - accuracy: 0.9336 - val_loss: 1.1699 - val_accuracy: 0.8204
# Epoch 125/150
# 31/31 [==============================] - 1s 18ms/step - loss: 0.0985 - accuracy: 0.9510 - val_loss: 1.1315 - val_accuracy: 0.7959
# Epoch 126/150
# 31/31 [==============================] - 1s 18ms/step - loss: 0.1566 - accuracy: 0.9397 - val_loss: 1.0508 - val_accuracy: 0.8041
# Epoch 127/150
# 31/31 [==============================] - 1s 19ms/step - loss: 0.1394 - accuracy: 0.9438 - val_loss: 1.0873 - val_accuracy: 0.8082
# Epoch 128/150
# 31/31 [==============================] - 1s 19ms/step - loss: 0.1240 - accuracy: 0.9448 - val_loss: 1.1397 - val_accuracy: 0.8122
# Epoch 129/150
# 31/31 [==============================] - 1s 19ms/step - loss: 0.1261 - accuracy: 0.9448 - val_loss: 1.2260 - val_accuracy: 0.8163
# Epoch 130/150
# 31/31 [==============================] - 1s 22ms/step - loss: 0.1278 - accuracy: 0.9397 - val_loss: 1.0580 - val_accuracy: 0.8163
# Epoch 131/150
# 31/31 [==============================] - 1s 19ms/step - loss: 0.1338 - accuracy: 0.9418 - val_loss: 1.2205 - val_accuracy: 0.8122
# Epoch 132/150
# 31/31 [==============================] - 1s 20ms/step - loss: 0.1129 - accuracy: 0.9438 - val_loss: 1.1047 - val_accuracy: 0.8122
# Epoch 133/150
# 31/31 [==============================] - 1s 22ms/step - loss: 0.1022 - accuracy: 0.9448 - val_loss: 0.9892 - val_accuracy: 0.7755
# Epoch 134/150
# 31/31 [==============================] - 1s 20ms/step - loss: 0.1100 - accuracy: 0.9428 - val_loss: 1.0250 - val_accuracy: 0.8245
# Epoch 135/150
# 31/31 [==============================] - 1s 19ms/step - loss: 0.1062 - accuracy: 0.9418 - val_loss: 1.1251 - val_accuracy: 0.8204
# Epoch 136/150
# 31/31 [==============================] - 1s 19ms/step - loss: 0.1047 - accuracy: 0.9408 - val_loss: 1.2332 - val_accuracy: 0.8000
# Epoch 137/150
# 31/31 [==============================] - 1s 19ms/step - loss: 0.0991 - accuracy: 0.9448 - val_loss: 1.0598 - val_accuracy: 0.8082
# Epoch 138/150
# 31/31 [==============================] - 1s 22ms/step - loss: 0.1092 - accuracy: 0.9438 - val_loss: 1.1874 - val_accuracy: 0.8204
# Epoch 139/150
# 31/31 [==============================] - 1s 23ms/step - loss: 0.1178 - accuracy: 0.9397 - val_loss: 1.0317 - val_accuracy: 0.8245
# Epoch 140/150
# 31/31 [==============================] - 1s 20ms/step - loss: 0.1048 - accuracy: 0.9428 - val_loss: 1.3256 - val_accuracy: 0.8122
# Epoch 141/150
# 31/31 [==============================] - 1s 22ms/step - loss: 0.1294 - accuracy: 0.9367 - val_loss: 1.2225 - val_accuracy: 0.8122
# Epoch 142/150
# 31/31 [==============================] - 1s 20ms/step - loss: 0.1236 - accuracy: 0.9346 - val_loss: 1.0729 - val_accuracy: 0.8082
# Epoch 143/150
# 31/31 [==============================] - 1s 22ms/step - loss: 0.1244 - accuracy: 0.9438 - val_loss: 1.1304 - val_accuracy: 0.8163
# Epoch 144/150
# 31/31 [==============================] - 1s 23ms/step - loss: 0.1081 - accuracy: 0.9408 - val_loss: 1.1201 - val_accuracy: 0.8122
# Epoch 145/150
# 31/31 [==============================] - 1s 19ms/step - loss: 0.0999 - accuracy: 0.9418 - val_loss: 1.1146 - val_accuracy: 0.8163
# Epoch 146/150
# 31/31 [==============================] - 1s 20ms/step - loss: 0.1069 - accuracy: 0.9408 - val_loss: 1.0775 - val_accuracy: 0.8163
# Epoch 147/150
# 31/31 [==============================] - 1s 19ms/step - loss: 0.0980 - accuracy: 0.9438 - val_loss: 1.3744 - val_accuracy: 0.8163
# Epoch 148/150
# 31/31 [==============================] - 1s 22ms/step - loss: 0.1539 - accuracy: 0.9418 - val_loss: 1.6174 - val_accuracy: 0.7592
# Epoch 149/150
# 31/31 [==============================] - 1s 22ms/step - loss: 0.2166 - accuracy: 0.9367 - val_loss: 1.3159 - val_accuracy: 0.7755
# Epoch 150/150
# 31/31 [==============================] - 1s 21ms/step - loss: 0.2398 - accuracy: 0.9285 - val_loss: 1.1385 - val_accuracy: 0.7959

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# save the model
multi_model.save('./files/multi_feature_model.keras')

# %%
# Evaluate model
loss, accuracy = multi_model.evaluate([
        X_mfcc_test_np_padded, 
        X_chroma_test_stft_np_padded
    ],
    y_test_cat
)
print("Test Loss:", loss, "Test Accuracy:", accuracy)
# Out:
# 8/8 [==============================] - 0s 6ms/step - loss: 1.1385 - accuracy: 0.7959
# Test Loss: 1.1385222673416138 Test Accuracy: 0.795918345451355

# %%
# Make predictions on new data
multi_predictions = multi_model.predict([
    X_mfcc_test_np_padded, 
    X_chroma_test_stft_np_padded
])

# The predictions will be probabilities for each class
# You can convert these probabilities to class labels
multi_predicted_labels = np.argmax(multi_predictions, axis=1)

# Example of using the predicted labels
print(multi_predicted_labels)
# Out:
# 8/8 [==============================] - 0s 5ms/step
# [2 2 2 2 2 2 2 0 2 2 2 2 2 2 2 2 2 0 1 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2
#  2 0 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 1 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2
#  2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 1 2 2 2 2 2 2 2 2 2 2 2 2 0 2 2 2 2 2 2 2 2
#  2 1 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 0 2 2 2 2 2 2 2 1 1 2 2 2
#  2 2 2 2 2 2 0 2 1 2 2 2 2 2 2 2 0 2 0 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2
#  0 0 2 2 2 2 2 2 2 2 2 2 1 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 1 2 2 2 2 2
#  2 2 2 0 0 2 2 2 2 2 2 2 0 2 2 2 2 2 2 2 2 1 2]

# %%
lang_dict
# Out:
# {'uk': 0, 'canada': 1, 'usa': 2}

# %%
kyes = list(lang_dict.keys())
values = list(lang_dict.values())

# create index to label with the language_dict values and keys
class_index_to_label = {values[i]: kyes[i] for i in range(len(kyes))}
class_index_to_label
# Out:
# {0: 'uk', 1: 'canada', 2: 'usa'}

# %%
# Convert numeric predictions to label names
predicted_labels_names = [class_index_to_label[idx] for idx in np.argmax(multi_predictions, axis=1)]

predicted_labels_names
# Out:
# ['usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'uk',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'uk',
#  'canada',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'uk',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'canada',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'canada',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'uk',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'canada',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'uk',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'canada',
#  'canada',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'uk',
#  'usa',
#  'canada',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'uk',
#  'usa',
#  'uk',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'uk',
#  'uk',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'canada',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'canada',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'uk',
#  'uk',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'uk',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'canada',
#  'usa']

# %%
# Convert predicted class indices to one-hot encoded format
label_binarizer = LabelBinarizer()
predicted_labels_one_hot = label_binarizer.fit_transform(multi_predicted_labels)

# Calculate confusion matrix
cm = confusion_matrix(y_test_cat.argmax(axis=1), predicted_labels_one_hot.argmax(axis=1))

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(
    cm, 
    annot=True, 
    cmap='Blues', 
    fmt='g', 
    xticklabels=class_index_to_label.values(), 
    yticklabels=class_index_to_label.values()
)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.savefig('./files/multi_feature_confusion_matrix.png')
plt.show()

# %% [markdown]
# # for single feature model - use below cells

# %%
# X_train_acoustic is a list of dictionaries with 'mfcc' as one of the features
max_length = 2000  # Define the maximum length you want to pad/truncate to
X_train_acoustic_processed = []
for sample in X_acoustic_list:
    mfcc_array = np.array(sample['mfcc'])
    current_length = mfcc_array.shape[1]
    # Pad or truncate the array to max_length
    if current_length < max_length:
        padded_mfcc_array = np.pad(mfcc_array, ((0, 0), (0, max_length - current_length)), mode='constant')
    else:
        padded_mfcc_array = mfcc_array[:, :max_length]
    X_train_acoustic_processed.append(padded_mfcc_array)

# Convert the list of processed features into a numpy array
X_train_np = np.array(X_train_acoustic_processed)

# %%
# Assuming X_train_acoustic is a list of dictionaries with 'mfcc' as one of the features
max_length = 2000  # Define the maximum length you want to pad/truncate to
X_test_acoustic_processed = []
for sample in X_acoustic_test_list:
    mfcc_array = np.array(sample['mfcc'])
    current_length = mfcc_array.shape[1]
    # Pad or truncate the array to max_length
    if current_length < max_length:
        padded_mfcc_array = np.pad(mfcc_array, ((0, 0), (0, max_length - current_length)), mode='constant')
    else:
        padded_mfcc_array = mfcc_array[:, :max_length]
    X_test_acoustic_processed.append(padded_mfcc_array)

# Convert the list of processed features into a numpy array
X_test_np = np.array(X_test_acoustic_processed)

# %%
single_model = create_feature_model(X_train_np)

# %%
# model summary
single_model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 40, 2000)]        0
#
#  conv1d_3 (Conv1D)           (None, 38, 16)            96016
#
#  concatenate_1 (Concatenate  (None, 38, 16)            0
#  )
#
#  max_pooling1d_2 (MaxPoolin  (None, 19, 16)            0
#  g1D)
#
#  conv1d_4 (Conv1D)           (None, 17, 8)             392
#
#  max_pooling1d_3 (MaxPoolin  (None, 8, 8)              0
#  g1D)
#
#  flatten_1 (Flatten)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 16)                1040
#
#  dense_3 (Dense)             (None, 3)                 51
#
# =================================================================
# Total params: 97499 (380.86 KB)
# Trainable params: 97499 (380.86 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
os.makedirs("files", exist_ok=True)

# %%
# plot the model
keras.utils.plot_model(single_model, to_file='files/feature_model.png', show_shapes=False)

# %%
# X_train_np

# %%
# train the model
single_history = single_model.fit(
    X_train_np, 
    y_train_cat, 
    epochs=EPOCHS, 
    validation_data=(X_test_np, y_test_cat)
)
# Out:
# Epoch 1/150
# 31/31 [==============================] - 8s 28ms/step - loss: 8.7487 - accuracy: 0.7375 - val_loss: 5.1255 - val_accuracy: 0.6245
# Epoch 2/150
# 31/31 [==============================] - 0s 13ms/step - loss: 4.2577 - accuracy: 0.7620 - val_loss: 4.4584 - val_accuracy: 0.7714
# Epoch 3/150
# 31/31 [==============================] - 0s 11ms/step - loss: 1.8477 - accuracy: 0.8212 - val_loss: 3.5287 - val_accuracy: 0.7388
# Epoch 4/150
# 31/31 [==============================] - 0s 14ms/step - loss: 0.9972 - accuracy: 0.8733 - val_loss: 3.4704 - val_accuracy: 0.7388
# Epoch 5/150
# 31/31 [==============================] - 0s 15ms/step - loss: 0.8315 - accuracy: 0.8815 - val_loss: 3.5158 - val_accuracy: 0.7592
# Epoch 6/150
# 31/31 [==============================] - 0s 15ms/step - loss: 0.5827 - accuracy: 0.9070 - val_loss: 4.0242 - val_accuracy: 0.7510
# Epoch 7/150
# 31/31 [==============================] - 0s 12ms/step - loss: 0.6973 - accuracy: 0.9101 - val_loss: 3.5418 - val_accuracy: 0.7020
# Epoch 8/150
# 31/31 [==============================] - 0s 12ms/step - loss: 0.7018 - accuracy: 0.9019 - val_loss: 3.6767 - val_accuracy: 0.7184
# Epoch 9/150
# 31/31 [==============================] - 0s 12ms/step - loss: 0.4272 - accuracy: 0.9377 - val_loss: 3.2606 - val_accuracy: 0.7184
# Epoch 10/150
# 31/31 [==============================] - 0s 14ms/step - loss: 0.6557 - accuracy: 0.9316 - val_loss: 3.5685 - val_accuracy: 0.7878
# Epoch 11/150
# 31/31 [==============================] - 0s 15ms/step - loss: 0.5419 - accuracy: 0.9213 - val_loss: 3.3829 - val_accuracy: 0.7755
# Epoch 12/150
# 31/31 [==============================] - 0s 13ms/step - loss: 0.4509 - accuracy: 0.9295 - val_loss: 2.9558 - val_accuracy: 0.7265
# Epoch 13/150
# 31/31 [==============================] - 1s 17ms/step - loss: 0.4687 - accuracy: 0.9305 - val_loss: 2.9429 - val_accuracy: 0.7837
# Epoch 14/150
# 31/31 [==============================] - 1s 17ms/step - loss: 0.5026 - accuracy: 0.9356 - val_loss: 3.2062 - val_accuracy: 0.7469
# Epoch 15/150
# 31/31 [==============================] - 1s 16ms/step - loss: 0.5310 - accuracy: 0.9265 - val_loss: 3.5901 - val_accuracy: 0.7592
# Epoch 16/150
# 31/31 [==============================] - 0s 12ms/step - loss: 0.5156 - accuracy: 0.9316 - val_loss: 3.2994 - val_accuracy: 0.7510
# Epoch 17/150
# 31/31 [==============================] - 0s 12ms/step - loss: 0.4145 - accuracy: 0.9367 - val_loss: 3.3526 - val_accuracy: 0.7469
# Epoch 18/150
# 31/31 [==============================] - 0s 11ms/step - loss: 0.5098 - accuracy: 0.9203 - val_loss: 2.7479 - val_accuracy: 0.7673
# Epoch 19/150
# 31/31 [==============================] - 0s 12ms/step - loss: 0.3965 - accuracy: 0.9326 - val_loss: 3.3751 - val_accuracy: 0.7796
# Epoch 20/150
# 31/31 [==============================] - 0s 11ms/step - loss: 0.4053 - accuracy: 0.9356 - val_loss: 2.9442 - val_accuracy: 0.7633
# Epoch 21/150
# 31/31 [==============================] - 0s 12ms/step - loss: 0.3618 - accuracy: 0.9377 - val_loss: 2.7780 - val_accuracy: 0.7469
# Epoch 22/150
# 31/31 [==============================] - 0s 12ms/step - loss: 0.3801 - accuracy: 0.9326 - val_loss: 2.7830 - val_accuracy: 0.7551
# Epoch 23/150
# 31/31 [==============================] - 0s 12ms/step - loss: 0.3072 - accuracy: 0.9387 - val_loss: 2.8455 - val_accuracy: 0.7673
# Epoch 24/150
# 31/31 [==============================] - 0s 12ms/step - loss: 0.3391 - accuracy: 0.9336 - val_loss: 2.7344 - val_accuracy: 0.7347
# Epoch 25/150
# 31/31 [==============================] - 0s 12ms/step - loss: 0.3013 - accuracy: 0.9387 - val_loss: 2.6478 - val_accuracy: 0.7306
# Epoch 26/150
# 31/31 [==============================] - 0s 14ms/step - loss: 0.2975 - accuracy: 0.9418 - val_loss: 2.5079 - val_accuracy: 0.7510
# Epoch 27/150
# 31/31 [==============================] - 0s 15ms/step - loss: 0.2688 - accuracy: 0.9438 - val_loss: 2.3616 - val_accuracy: 0.7878
# Epoch 28/150
# 31/31 [==============================] - 0s 15ms/step - loss: 0.2735 - accuracy: 0.9377 - val_loss: 2.4288 - val_accuracy: 0.7673
# Epoch 29/150
# 31/31 [==============================] - 0s 14ms/step - loss: 0.2520 - accuracy: 0.9397 - val_loss: 2.4382 - val_accuracy: 0.7755
# Epoch 30/150
# 31/31 [==============================] - 0s 12ms/step - loss: 0.2731 - accuracy: 0.9397 - val_loss: 2.5264 - val_accuracy: 0.7673
# Epoch 31/150
# 31/31 [==============================] - 0s 13ms/step - loss: 0.2816 - accuracy: 0.9367 - val_loss: 2.2919 - val_accuracy: 0.7673
# Epoch 32/150
# 31/31 [==============================] - 0s 12ms/step - loss: 0.2660 - accuracy: 0.9336 - val_loss: 2.2350 - val_accuracy: 0.7878
# Epoch 33/150
# 31/31 [==============================] - 0s 13ms/step - loss: 0.3551 - accuracy: 0.9346 - val_loss: 2.1890 - val_accuracy: 0.7714
# Epoch 34/150
# 31/31 [==============================] - 0s 13ms/step - loss: 0.2168 - accuracy: 0.9418 - val_loss: 1.8766 - val_accuracy: 0.7796
# Epoch 35/150
# 31/31 [==============================] - 0s 14ms/step - loss: 0.2307 - accuracy: 0.9326 - val_loss: 1.8987 - val_accuracy: 0.7306
# Epoch 36/150
# 31/31 [==============================] - 0s 13ms/step - loss: 0.2497 - accuracy: 0.9387 - val_loss: 2.3173 - val_accuracy: 0.7429
# Epoch 37/150
# 31/31 [==============================] - 0s 14ms/step - loss: 0.2140 - accuracy: 0.9408 - val_loss: 1.8990 - val_accuracy: 0.7837
# Epoch 38/150
# 31/31 [==============================] - 0s 14ms/step - loss: 0.2538 - accuracy: 0.9397 - val_loss: 1.8794 - val_accuracy: 0.7388
# Epoch 39/150
# 31/31 [==============================] - 0s 13ms/step - loss: 0.2414 - accuracy: 0.9387 - val_loss: 2.1071 - val_accuracy: 0.7224
# Epoch 40/150
# 31/31 [==============================] - 0s 14ms/step - loss: 0.2573 - accuracy: 0.9387 - val_loss: 2.2212 - val_accuracy: 0.7878
# Epoch 41/150
# 31/31 [==============================] - 0s 14ms/step - loss: 0.2198 - accuracy: 0.9428 - val_loss: 2.0322 - val_accuracy: 0.8000
# Epoch 42/150
# 31/31 [==============================] - 0s 13ms/step - loss: 0.2067 - accuracy: 0.9499 - val_loss: 2.2072 - val_accuracy: 0.7959
# Epoch 43/150
# 31/31 [==============================] - 0s 12ms/step - loss: 0.2003 - accuracy: 0.9418 - val_loss: 1.9485 - val_accuracy: 0.7714
# Epoch 44/150
# 31/31 [==============================] - 0s 13ms/step - loss: 0.1820 - accuracy: 0.9428 - val_loss: 1.5350 - val_accuracy: 0.7796
# Epoch 45/150
# 31/31 [==============================] - 0s 15ms/step - loss: 0.2029 - accuracy: 0.9479 - val_loss: 1.8810 - val_accuracy: 0.8082
# Epoch 46/150
# 31/31 [==============================] - 0s 16ms/step - loss: 0.2260 - accuracy: 0.9336 - val_loss: 1.7561 - val_accuracy: 0.7796
# Epoch 47/150
# 31/31 [==============================] - 1s 17ms/step - loss: 0.1947 - accuracy: 0.9438 - val_loss: 1.6229 - val_accuracy: 0.7184
# Epoch 48/150
# 31/31 [==============================] - 1s 18ms/step - loss: 0.2381 - accuracy: 0.9448 - val_loss: 1.8999 - val_accuracy: 0.7796
# Epoch 49/150
# 31/31 [==============================] - 1s 17ms/step - loss: 0.2969 - accuracy: 0.9346 - val_loss: 1.8500 - val_accuracy: 0.7510
# Epoch 50/150
# 31/31 [==============================] - 1s 19ms/step - loss: 0.2862 - accuracy: 0.9438 - val_loss: 1.6700 - val_accuracy: 0.7959
# Epoch 51/150
# 31/31 [==============================] - 1s 17ms/step - loss: 0.2476 - accuracy: 0.9305 - val_loss: 1.9419 - val_accuracy: 0.7224
# Epoch 52/150
# 31/31 [==============================] - 1s 17ms/step - loss: 0.2108 - accuracy: 0.9448 - val_loss: 1.7006 - val_accuracy: 0.7918
# Epoch 53/150
# 31/31 [==============================] - 0s 15ms/step - loss: 0.1577 - accuracy: 0.9387 - val_loss: 1.8269 - val_accuracy: 0.8041
# Epoch 54/150
# 31/31 [==============================] - 0s 16ms/step - loss: 0.1723 - accuracy: 0.9418 - val_loss: 1.7633 - val_accuracy: 0.7673
# Epoch 55/150
# 31/31 [==============================] - 1s 16ms/step - loss: 0.1840 - accuracy: 0.9418 - val_loss: 1.8307 - val_accuracy: 0.7878
# Epoch 56/150
# 31/31 [==============================] - 0s 14ms/step - loss: 0.1731 - accuracy: 0.9540 - val_loss: 1.6181 - val_accuracy: 0.7714
# Epoch 57/150
# 31/31 [==============================] - 0s 16ms/step - loss: 0.1880 - accuracy: 0.9520 - val_loss: 1.8146 - val_accuracy: 0.7673
# Epoch 58/150
# 31/31 [==============================] - 0s 15ms/step - loss: 0.2021 - accuracy: 0.9428 - val_loss: 1.7377 - val_accuracy: 0.8000
# Epoch 59/150
# 31/31 [==============================] - 0s 13ms/step - loss: 0.1805 - accuracy: 0.9448 - val_loss: 1.6965 - val_accuracy: 0.7265
# Epoch 60/150
# 31/31 [==============================] - 0s 12ms/step - loss: 0.1708 - accuracy: 0.9428 - val_loss: 1.6681 - val_accuracy: 0.8082
# Epoch 61/150
# 31/31 [==============================] - 0s 12ms/step - loss: 0.1435 - accuracy: 0.9408 - val_loss: 1.5358 - val_accuracy: 0.7510
# Epoch 62/150
# 31/31 [==============================] - 0s 13ms/step - loss: 0.1394 - accuracy: 0.9459 - val_loss: 1.6007 - val_accuracy: 0.8041
# Epoch 63/150
# 31/31 [==============================] - 0s 13ms/step - loss: 0.1395 - accuracy: 0.9520 - val_loss: 1.5462 - val_accuracy: 0.7714
# Epoch 64/150
# 31/31 [==============================] - 0s 13ms/step - loss: 0.1395 - accuracy: 0.9418 - val_loss: 1.4364 - val_accuracy: 0.7592
# Epoch 65/150
# 31/31 [==============================] - 0s 13ms/step - loss: 0.1454 - accuracy: 0.9387 - val_loss: 1.5658 - val_accuracy: 0.7878
# Epoch 66/150
# 31/31 [==============================] - 0s 12ms/step - loss: 0.1733 - accuracy: 0.9408 - val_loss: 1.5026 - val_accuracy: 0.7592
# Epoch 67/150
# 31/31 [==============================] - 0s 16ms/step - loss: 0.1380 - accuracy: 0.9438 - val_loss: 1.6701 - val_accuracy: 0.7837
# Epoch 68/150
# 31/31 [==============================] - 1s 17ms/step - loss: 0.1617 - accuracy: 0.9469 - val_loss: 1.6191 - val_accuracy: 0.8082
# Epoch 69/150
# 31/31 [==============================] - 1s 20ms/step - loss: 0.1353 - accuracy: 0.9377 - val_loss: 1.5451 - val_accuracy: 0.8000
# Epoch 70/150
# 31/31 [==============================] - 1s 18ms/step - loss: 0.1335 - accuracy: 0.9459 - val_loss: 1.4308 - val_accuracy: 0.8082
# Epoch 71/150
# 31/31 [==============================] - 1s 19ms/step - loss: 0.1485 - accuracy: 0.9489 - val_loss: 1.4440 - val_accuracy: 0.7510
# Epoch 72/150
# 31/31 [==============================] - 1s 19ms/step - loss: 0.1588 - accuracy: 0.9438 - val_loss: 1.9368 - val_accuracy: 0.7796
# Epoch 73/150
# 31/31 [==============================] - 1s 24ms/step - loss: 0.8714 - accuracy: 0.8733 - val_loss: 2.5421 - val_accuracy: 0.5347
# Epoch 74/150
# 31/31 [==============================] - 1s 23ms/step - loss: 0.5817 - accuracy: 0.8652 - val_loss: 2.5639 - val_accuracy: 0.7020
# Epoch 75/150
# 31/31 [==============================] - 1s 17ms/step - loss: 0.3460 - accuracy: 0.9091 - val_loss: 1.9868 - val_accuracy: 0.7633
# Epoch 76/150
# 31/31 [==============================] - 1s 20ms/step - loss: 0.3116 - accuracy: 0.9203 - val_loss: 2.0830 - val_accuracy: 0.7959
# Epoch 77/150
# 31/31 [==============================] - 1s 18ms/step - loss: 0.2853 - accuracy: 0.9295 - val_loss: 1.8884 - val_accuracy: 0.7265
# Epoch 78/150
# 31/31 [==============================] - 1s 18ms/step - loss: 0.2145 - accuracy: 0.9397 - val_loss: 1.5934 - val_accuracy: 0.7673
# Epoch 79/150
# 31/31 [==============================] - 1s 16ms/step - loss: 0.1632 - accuracy: 0.9428 - val_loss: 1.8342 - val_accuracy: 0.7837
# Epoch 80/150
# 31/31 [==============================] - 1s 18ms/step - loss: 0.1422 - accuracy: 0.9418 - val_loss: 1.5257 - val_accuracy: 0.7878
# Epoch 81/150
# 31/31 [==============================] - 1s 18ms/step - loss: 0.1665 - accuracy: 0.9418 - val_loss: 1.7312 - val_accuracy: 0.7959
# Epoch 82/150
# 31/31 [==============================] - 0s 15ms/step - loss: 0.1886 - accuracy: 0.9428 - val_loss: 1.5618 - val_accuracy: 0.7755
# Epoch 83/150
# 31/31 [==============================] - 0s 15ms/step - loss: 0.1429 - accuracy: 0.9438 - val_loss: 1.6476 - val_accuracy: 0.7837
# Epoch 84/150
# 31/31 [==============================] - 0s 15ms/step - loss: 0.1265 - accuracy: 0.9479 - val_loss: 1.6987 - val_accuracy: 0.8000
# Epoch 85/150
# 31/31 [==============================] - 0s 15ms/step - loss: 0.1363 - accuracy: 0.9479 - val_loss: 1.6224 - val_accuracy: 0.7837
# Epoch 86/150
# 31/31 [==============================] - 1s 22ms/step - loss: 0.1033 - accuracy: 0.9469 - val_loss: 1.4780 - val_accuracy: 0.7796
# Epoch 87/150
# 31/31 [==============================] - 1s 20ms/step - loss: 0.1278 - accuracy: 0.9428 - val_loss: 1.5596 - val_accuracy: 0.8000
# Epoch 88/150
# 31/31 [==============================] - 1s 19ms/step - loss: 0.1094 - accuracy: 0.9418 - val_loss: 1.5492 - val_accuracy: 0.7959
# Epoch 89/150
# 31/31 [==============================] - 1s 21ms/step - loss: 0.1058 - accuracy: 0.9408 - val_loss: 1.5122 - val_accuracy: 0.7796
# Epoch 90/150
# 31/31 [==============================] - 0s 16ms/step - loss: 0.1039 - accuracy: 0.9377 - val_loss: 1.6645 - val_accuracy: 0.8000
# Epoch 91/150
# 31/31 [==============================] - 0s 13ms/step - loss: 0.1037 - accuracy: 0.9510 - val_loss: 1.4412 - val_accuracy: 0.8000
# Epoch 92/150
# 31/31 [==============================] - 0s 13ms/step - loss: 0.1068 - accuracy: 0.9418 - val_loss: 1.5811 - val_accuracy: 0.7959
# Epoch 93/150
# 31/31 [==============================] - 0s 14ms/step - loss: 0.1029 - accuracy: 0.9428 - val_loss: 1.5123 - val_accuracy: 0.7837
# Epoch 94/150
# 31/31 [==============================] - 0s 15ms/step - loss: 0.1017 - accuracy: 0.9479 - val_loss: 1.3903 - val_accuracy: 0.7837
# Epoch 95/150
# 31/31 [==============================] - 0s 15ms/step - loss: 0.1011 - accuracy: 0.9438 - val_loss: 1.4560 - val_accuracy: 0.7673
# Epoch 96/150
# 31/31 [==============================] - 0s 15ms/step - loss: 0.1125 - accuracy: 0.9428 - val_loss: 1.5167 - val_accuracy: 0.8082
# Epoch 97/150
# 31/31 [==============================] - 1s 28ms/step - loss: 0.1083 - accuracy: 0.9418 - val_loss: 1.3867 - val_accuracy: 0.7633
# Epoch 98/150
# 31/31 [==============================] - 1s 29ms/step - loss: 0.1022 - accuracy: 0.9448 - val_loss: 1.5241 - val_accuracy: 0.7918
# Epoch 99/150
# 31/31 [==============================] - 1s 22ms/step - loss: 0.0957 - accuracy: 0.9469 - val_loss: 1.4694 - val_accuracy: 0.8000
# Epoch 100/150
# 31/31 [==============================] - 1s 19ms/step - loss: 0.1023 - accuracy: 0.9428 - val_loss: 1.5122 - val_accuracy: 0.7755
# Epoch 101/150
# 31/31 [==============================] - 1s 19ms/step - loss: 0.1047 - accuracy: 0.9438 - val_loss: 1.3746 - val_accuracy: 0.7633
# Epoch 102/150
# 31/31 [==============================] - 1s 19ms/step - loss: 0.1063 - accuracy: 0.9408 - val_loss: 1.4922 - val_accuracy: 0.7837
# Epoch 103/150
# 31/31 [==============================] - 0s 15ms/step - loss: 0.1185 - accuracy: 0.9530 - val_loss: 1.3772 - val_accuracy: 0.7837
# Epoch 104/150
# 31/31 [==============================] - 1s 17ms/step - loss: 0.1717 - accuracy: 0.9408 - val_loss: 1.6805 - val_accuracy: 0.7469
# Epoch 105/150
# 31/31 [==============================] - 1s 17ms/step - loss: 0.1853 - accuracy: 0.9397 - val_loss: 1.4328 - val_accuracy: 0.8041
# Epoch 106/150
# 31/31 [==============================] - 0s 14ms/step - loss: 0.1440 - accuracy: 0.9397 - val_loss: 1.5558 - val_accuracy: 0.8000
# Epoch 107/150
# 31/31 [==============================] - 1s 21ms/step - loss: 0.1194 - accuracy: 0.9387 - val_loss: 1.3970 - val_accuracy: 0.7592
# Epoch 108/150
# 31/31 [==============================] - 1s 19ms/step - loss: 0.1294 - accuracy: 0.9438 - val_loss: 1.4287 - val_accuracy: 0.7878
# Epoch 109/150
# 31/31 [==============================] - 1s 18ms/step - loss: 0.1096 - accuracy: 0.9520 - val_loss: 1.6134 - val_accuracy: 0.7959
# Epoch 110/150
# 31/31 [==============================] - 0s 16ms/step - loss: 0.1383 - accuracy: 0.9448 - val_loss: 1.3980 - val_accuracy: 0.7755
# Epoch 111/150
# 31/31 [==============================] - 1s 24ms/step - loss: 0.1277 - accuracy: 0.9336 - val_loss: 1.3712 - val_accuracy: 0.7918
# Epoch 112/150
# 31/31 [==============================] - 1s 22ms/step - loss: 0.1212 - accuracy: 0.9448 - val_loss: 1.6334 - val_accuracy: 0.8122
# Epoch 113/150
# 31/31 [==============================] - 1s 21ms/step - loss: 0.1119 - accuracy: 0.9459 - val_loss: 1.4373 - val_accuracy: 0.7918
# Epoch 114/150
# 31/31 [==============================] - 1s 19ms/step - loss: 0.1119 - accuracy: 0.9459 - val_loss: 1.5357 - val_accuracy: 0.8041
# Epoch 115/150
# 31/31 [==============================] - 0s 16ms/step - loss: 0.1145 - accuracy: 0.9408 - val_loss: 1.4727 - val_accuracy: 0.7959
# Epoch 116/150
# 31/31 [==============================] - 1s 16ms/step - loss: 0.0870 - accuracy: 0.9581 - val_loss: 1.5547 - val_accuracy: 0.7796
# Epoch 117/150
# 31/31 [==============================] - 0s 15ms/step - loss: 0.1070 - accuracy: 0.9448 - val_loss: 1.4874 - val_accuracy: 0.8000
# Epoch 118/150
# 31/31 [==============================] - 0s 14ms/step - loss: 0.1129 - accuracy: 0.9448 - val_loss: 1.4458 - val_accuracy: 0.7796
# Epoch 119/150
# 31/31 [==============================] - 1s 21ms/step - loss: 0.1057 - accuracy: 0.9459 - val_loss: 1.3794 - val_accuracy: 0.7918
# Epoch 120/150
# 31/31 [==============================] - 1s 24ms/step - loss: 0.1066 - accuracy: 0.9469 - val_loss: 1.3132 - val_accuracy: 0.7796
# Epoch 121/150
# 31/31 [==============================] - 1s 19ms/step - loss: 0.1015 - accuracy: 0.9540 - val_loss: 1.4880 - val_accuracy: 0.7755
# Epoch 122/150
# 31/31 [==============================] - 1s 21ms/step - loss: 0.0966 - accuracy: 0.9469 - val_loss: 1.4357 - val_accuracy: 0.7837
# Epoch 123/150
# 31/31 [==============================] - 1s 20ms/step - loss: 0.0993 - accuracy: 0.9520 - val_loss: 1.3604 - val_accuracy: 0.7633
# Epoch 124/150
# 31/31 [==============================] - 1s 16ms/step - loss: 0.0982 - accuracy: 0.9448 - val_loss: 1.3449 - val_accuracy: 0.7878
# Epoch 125/150
# 31/31 [==============================] - 1s 21ms/step - loss: 0.0925 - accuracy: 0.9459 - val_loss: 1.3622 - val_accuracy: 0.8082
# Epoch 126/150
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0920 - accuracy: 0.9418 - val_loss: 1.2891 - val_accuracy: 0.7918
# Epoch 127/150
# 31/31 [==============================] - 0s 15ms/step - loss: 0.0882 - accuracy: 0.9489 - val_loss: 1.3041 - val_accuracy: 0.7837
# Epoch 128/150
# 31/31 [==============================] - 0s 15ms/step - loss: 0.0995 - accuracy: 0.9438 - val_loss: 1.3795 - val_accuracy: 0.7837
# Epoch 129/150
# 31/31 [==============================] - 0s 15ms/step - loss: 0.0987 - accuracy: 0.9448 - val_loss: 1.4140 - val_accuracy: 0.8122
# Epoch 130/150
# 31/31 [==============================] - 0s 15ms/step - loss: 0.0910 - accuracy: 0.9438 - val_loss: 1.3527 - val_accuracy: 0.8000
# Epoch 131/150
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0959 - accuracy: 0.9428 - val_loss: 1.5114 - val_accuracy: 0.7959
# Epoch 132/150
# 31/31 [==============================] - 0s 16ms/step - loss: 0.1074 - accuracy: 0.9428 - val_loss: 1.4753 - val_accuracy: 0.7796
# Epoch 133/150
# 31/31 [==============================] - 1s 18ms/step - loss: 0.1254 - accuracy: 0.9377 - val_loss: 1.4280 - val_accuracy: 0.8000
# Epoch 134/150
# 31/31 [==============================] - 1s 22ms/step - loss: 0.1569 - accuracy: 0.9428 - val_loss: 1.3376 - val_accuracy: 0.8000
# Epoch 135/150
# 31/31 [==============================] - 1s 28ms/step - loss: 0.2425 - accuracy: 0.9326 - val_loss: 1.7625 - val_accuracy: 0.7429
# Epoch 136/150
# 31/31 [==============================] - 1s 30ms/step - loss: 0.2622 - accuracy: 0.9213 - val_loss: 1.4597 - val_accuracy: 0.7102
# Epoch 137/150
# 31/31 [==============================] - 1s 26ms/step - loss: 0.1843 - accuracy: 0.9418 - val_loss: 1.9008 - val_accuracy: 0.7714
# Epoch 138/150
# 31/31 [==============================] - 1s 21ms/step - loss: 0.1523 - accuracy: 0.9387 - val_loss: 1.7372 - val_accuracy: 0.8041
# Epoch 139/150
# 31/31 [==============================] - 1s 28ms/step - loss: 0.1572 - accuracy: 0.9367 - val_loss: 1.4053 - val_accuracy: 0.7837
# Epoch 140/150
# 31/31 [==============================] - 1s 22ms/step - loss: 0.1531 - accuracy: 0.9367 - val_loss: 1.4225 - val_accuracy: 0.7837
# Epoch 141/150
# 31/31 [==============================] - 0s 14ms/step - loss: 0.1095 - accuracy: 0.9469 - val_loss: 1.4044 - val_accuracy: 0.7429
# Epoch 142/150
# 31/31 [==============================] - 0s 13ms/step - loss: 0.1034 - accuracy: 0.9499 - val_loss: 1.5500 - val_accuracy: 0.8000
# Epoch 143/150
# 31/31 [==============================] - 0s 13ms/step - loss: 0.1137 - accuracy: 0.9520 - val_loss: 1.4140 - val_accuracy: 0.7878
# Epoch 144/150
# 31/31 [==============================] - 0s 12ms/step - loss: 0.1167 - accuracy: 0.9520 - val_loss: 1.4230 - val_accuracy: 0.7796
# Epoch 145/150
# 31/31 [==============================] - 0s 12ms/step - loss: 0.1411 - accuracy: 0.9438 - val_loss: 1.8863 - val_accuracy: 0.7510
# Epoch 146/150
# 31/31 [==============================] - 0s 11ms/step - loss: 0.1800 - accuracy: 0.9305 - val_loss: 1.4855 - val_accuracy: 0.8000
# Epoch 147/150
# 31/31 [==============================] - 0s 13ms/step - loss: 0.1221 - accuracy: 0.9520 - val_loss: 1.4245 - val_accuracy: 0.8000
# Epoch 148/150
# 31/31 [==============================] - 0s 13ms/step - loss: 0.1284 - accuracy: 0.9551 - val_loss: 1.4804 - val_accuracy: 0.8000
# Epoch 149/150
# 31/31 [==============================] - 0s 12ms/step - loss: 0.1456 - accuracy: 0.9479 - val_loss: 1.6924 - val_accuracy: 0.7510
# Epoch 150/150
# 31/31 [==============================] - 0s 13ms/step - loss: 0.1584 - accuracy: 0.9397 - val_loss: 1.4719 - val_accuracy: 0.8122

# %%
# Plot training & validation accuracy values
plt.plot(single_history.history['accuracy'])
plt.plot(single_history.history['val_accuracy'])
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# Plot training & validation loss values
plt.plot(single_history.history['loss'])
plt.plot(single_history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# save the model
single_model.save('./files/feature_model.keras')

# %%
# Evaluate model
loss, accuracy = single_model.evaluate(X_test_np, y_test_cat)
print("Test Loss:", loss, "Test Accuracy:", accuracy)
# Out:
# 8/8 [==============================] - 0s 5ms/step - loss: 1.4719 - accuracy: 0.8122
# Test Loss: 1.471887230873108 Test Accuracy: 0.8122448921203613

# %%
# # Make predictions on new data
predictions = single_model.predict(X_test_np)

# The predictions will be probabilities for each class
# You can convert these probabilities to class labels
predicted_labels = np.argmax(predictions, axis=1)

# Example of using the predicted labels
print(predicted_labels)
# Out:
# 8/8 [==============================] - 0s 4ms/step
# [2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2
#  2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2
#  2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2
#  2 2 2 2 2 2 2 2 2 2 1 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2
#  1 2 2 2 2 2 0 2 2 2 2 2 2 2 2 2 2 2 0 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2
#  0 0 2 2 2 1 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2
#  2 2 2 2 0 2 2 2 2 2 2 2 0 2 2 2 2 2 2 2 2 1 2]

# %%
# Convert numeric predictions to label names
predicted_labels_names = [class_index_to_label[idx] for idx in np.argmax(multi_predictions, axis=1)]

predicted_labels_names
# Out:
# ['usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'uk',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'uk',
#  'canada',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'uk',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'canada',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'canada',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'uk',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'canada',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'uk',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'canada',
#  'canada',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'uk',
#  'usa',
#  'canada',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'uk',
#  'usa',
#  'uk',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'uk',
#  'uk',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'canada',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'canada',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'uk',
#  'uk',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'uk',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'canada',
#  'usa']

# %%
# Convert predicted class indices to one-hot encoded format
label_binarizer = LabelBinarizer()
labels_one_hot = label_binarizer.fit_transform(predicted_labels)

# Calculate confusion matrix
cm = confusion_matrix(y_test_cat.argmax(axis=1), labels_one_hot.argmax(axis=1))

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(
    cm, 
    annot=True, 
    cmap='Blues', 
    fmt='g', 
    xticklabels=class_index_to_label.values(), 
    yticklabels=class_index_to_label.values()
)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.savefig('./files/feature_confusion_matrix.png')
plt.show()

# %% [markdown]
# # For Hybrid CNN-LSTM Model

# %% [markdown]
# # Choose the approach (concatenation or separate channels)

# %%
use_separate_channels = True

# Create CNN-LSTM architecture
hybrid_model = create_hybrid_model(
    X_mfcc_np=X_mfcc_np_padded,
    X_chroma_stft_np=X_chroma_stft_np_padded,
    # X_spectral_centroid_np=X_spectral_centroid_np,
    use_separate_channels=use_separate_channels
)

# %%
# model summary
hybrid_model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_4 (InputLayer)        [(None, 40, 2000)]           0         []
#
#  input_5 (InputLayer)        [(None, 40, 2000)]           0         []
#
#  conv1d_5 (Conv1D)           (None, 40, 16)               96016     ['input_4[0][0]']
#
#  conv1d_6 (Conv1D)           (None, 40, 8)                48008     ['input_5[0][0]']
#
#  concatenate_2 (Concatenate  (None, 40, 24)               0         ['conv1d_5[0][0]',
#  )                                                                   'conv1d_6[0][0]']
#
#  max_pooling1d_4 (MaxPoolin  (None, 20, 24)               0         ['concatenate_2[0][0]']
#  g1D)
#
#  conv1d_7 (Conv1D)           (None, 18, 128)              9344      ['max_pooling1d_4[0][0]']
#
#  max_pooling1d_5 (MaxPoolin  (None, 9, 128)               0         ['conv1d_7[0][0]']
#  g1D)
#
#  lstm (LSTM)                 (None, 9, 128)               131584    ['max_pooling1d_5[0][0]']
#
#  lstm_1 (LSTM)               (None, 128)                  131584    ['lstm[0][0]']
#
#  dense_4 (Dense)             (None, 64)                   8256      ['lstm_1[0][0]']
#
#  dense_5 (Dense)             (None, 3)                    195       ['dense_4[0][0]']
#
# ==================================================================================================
# Total params: 424987 (1.62 MB)
# Trainable params: 424987 (1.62 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
# plot model
keras.utils.plot_model(hybrid_model, to_file='files/hybrid_feature_model.png', show_shapes=False)

# %%
history = hybrid_model.fit(
    [X_mfcc_np_padded, X_chroma_stft_np_padded],
    y_train_cat,
    epochs=10, # EPOCHS
    validation_data=([X_mfcc_test_np_padded, X_chroma_test_stft_np_padded], y_test_cat)
)
# Out:
# Epoch 1/10
# 31/31 [==============================] - 9s 88ms/step - loss: 0.5685 - accuracy: 0.8212 - val_loss: 0.5372 - val_accuracy: 0.8449
# Epoch 2/10
# 31/31 [==============================] - 1s 31ms/step - loss: 0.5094 - accuracy: 0.8417 - val_loss: 0.5234 - val_accuracy: 0.8449
# Epoch 3/10
# 31/31 [==============================] - 1s 31ms/step - loss: 0.4963 - accuracy: 0.8417 - val_loss: 0.5247 - val_accuracy: 0.8449
# Epoch 4/10
# 31/31 [==============================] - 1s 30ms/step - loss: 0.4844 - accuracy: 0.8407 - val_loss: 0.5654 - val_accuracy: 0.8449
# Epoch 5/10
# 31/31 [==============================] - 1s 29ms/step - loss: 0.4374 - accuracy: 0.8468 - val_loss: 0.5688 - val_accuracy: 0.8449
# Epoch 6/10
# 31/31 [==============================] - 1s 33ms/step - loss: 0.4049 - accuracy: 0.8590 - val_loss: 0.6282 - val_accuracy: 0.8163
# Epoch 7/10
# 31/31 [==============================] - 1s 31ms/step - loss: 0.3714 - accuracy: 0.8641 - val_loss: 0.6853 - val_accuracy: 0.7837
# Epoch 8/10
# 31/31 [==============================] - 1s 36ms/step - loss: 0.3166 - accuracy: 0.8774 - val_loss: 0.7809 - val_accuracy: 0.8327
# Epoch 9/10
# 31/31 [==============================] - 1s 34ms/step - loss: 0.2974 - accuracy: 0.8805 - val_loss: 0.8645 - val_accuracy: 0.8041
# Epoch 10/10
# 31/31 [==============================] - 1s 35ms/step - loss: 0.2397 - accuracy: 0.9101 - val_loss: 0.7892 - val_accuracy: 0.7959

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# save the model
hybrid_model.save('./files/hybrid_feature_model.keras')

# %%
# Evaluate model
loss, accuracy = hybrid_model.evaluate([
        X_mfcc_test_np_padded, 
        X_chroma_test_stft_np_padded
    ],
    y_test_cat
)
print("Test Loss:", loss, "Test Accuracy:", accuracy)
# Out:
# 8/8 [==============================] - 0s 12ms/step - loss: 0.7892 - accuracy: 0.7959
# Test Loss: 0.7892286777496338 Test Accuracy: 0.795918345451355

# %%
# Make predictions on new data
hybrid_predictions = hybrid_model.predict([
    X_mfcc_test_np_padded, 
    X_chroma_test_stft_np_padded
])

# The predictions will be probabilities for each class
# You can convert these probabilities to class labels
hybrid_predicted_labels = np.argmax(hybrid_predictions, axis=1)

# Example of using the predicted labels
print(multi_predicted_labels)
# Out:
# 8/8 [==============================] - 1s 13ms/step
# [2 2 2 2 2 2 2 0 2 2 2 2 2 2 2 2 2 0 1 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2
#  2 0 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 1 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2
#  2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 1 2 2 2 2 2 2 2 2 2 2 2 2 0 2 2 2 2 2 2 2 2
#  2 1 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 0 2 2 2 2 2 2 2 1 1 2 2 2
#  2 2 2 2 2 2 0 2 1 2 2 2 2 2 2 2 0 2 0 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2
#  0 0 2 2 2 2 2 2 2 2 2 2 1 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 1 2 2 2 2 2
#  2 2 2 0 0 2 2 2 2 2 2 2 0 2 2 2 2 2 2 2 2 1 2]

# %%
# Convert numeric predictions to label names
predicted_labels_names = [class_index_to_label[idx] for idx in np.argmax(hybrid_predictions, axis=1)]

predicted_labels_names
# Out:
# ['usa',
#  'usa',
#  'usa',
#  'usa',
#  'canada',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'canada',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'canada',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'canada',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'canada',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'uk',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'canada',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'uk',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'uk',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'canada',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'canada',
#  'uk',
#  'usa',
#  'uk',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'uk',
#  'canada',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'canada',
#  'usa']

# %%
# Convert predicted class indices to one-hot encoded format
label_binarizer = LabelBinarizer()
predicted_labels_one_hot = label_binarizer.fit_transform(hybrid_predicted_labels)

# Calculate confusion matrix
cm = confusion_matrix(y_test_cat.argmax(axis=1), predicted_labels_one_hot.argmax(axis=1))

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(
    cm, 
    annot=True, 
    cmap='Blues', 
    fmt='g', 
    xticklabels=class_index_to_label.values(), 
    yticklabels=class_index_to_label.values()
)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.savefig('./files/hybrid_feature_confusion_matrix.png')
plt.show()
