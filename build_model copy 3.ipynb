# %%
import os
import librosa
import torch
import random
import keras
import soundfile as sf
import numpy as np
import pandas as pd
import tensorflow as tf
from collections import Counter
from concurrent.futures import ThreadPoolExecutor
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelBinarizer
# Out:
# WARNING:tensorflow:From c:\Users\musah\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# if gpu is available, use it
if tf.config.list_physical_devices('GPU'):
    device = 'gpu'
else:
    device = 'cpu'
    
# if gpu is available, use it
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
OUTPUT_DIR: str = "output/"
CSV_FILE_PATH: str = "bio_metadata.csv"
NATIVE_FILE_PATH: str = "native_bio_metadata.csv"
NON_NATIVE_FILE_PATH: str = "non_native_bio_metadata.csv"
NATIVE_LANGUAGES: list[str] = ['uk', 'usa', 'canada']
NON_NATIVE_LANGUAGES: list[str] = [
    'australia',
    'new zealand',
    'ireland',    
    'singapore',  
    'south',     
    'africa',   
    'jamaica',    
    'scotland',   
    'islands',
]
DATASET_DIR: str = "data/"
NATIVE_DIR: str = "data/native/"
NATIVE_COMBINED_DIR: str = "data/native_combined/"
NON_NATIVE_DIR: str = "data/non_native/"
AUDIO_DATA_DIR: str = "data/audio/"
AUDIO_FILE_PATH: str = "data/audio/{}.wav"
SILENCE_THRESHOLD: float = .01
RATE: int = 2400
N_MFCC: int = 13
COL_SIZE: int = 30
EPOCHS: int = 250 #35 #50 #250
LEARNING_RATE = 0.001
WAIT: float = 1.2
DEBUG: bool = True

# %%
class XFeatureExtractor:
    """
        Extracts acoustic and prosodic features from audio files.
    """
    
    @staticmethod
    def extract_acoustic_features(file_path, features=('mfcc', 'chroma_stft', 'spectral_centroid')):
        try:
            y, sr = librosa.load(f'data/audio/{file_path}.wav')
            features_dict = {}
            for feature_name in features:
                if feature_name == 'mfcc':
                    features_dict['mfcc'] = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40)
                elif feature_name == 'chroma_stft':
                    features_dict['chroma_stft'] = librosa.feature.chroma_stft(y=y, sr=sr, n_chroma=12)
                elif feature_name == 'spectral_centroid':
                    features_dict['spectral_centroid'] = librosa.feature.spectral_centroid(y=y, sr=sr)
                elif feature_name == 'spectral_bandwidth':
                    features_dict['spectral_bandwidth'] = librosa.feature.spectral_bandwidth(y=y, sr=sr)
                elif feature_name == 'zero_crossing_rate':
                    features_dict['zero_crossing_rate'] = librosa.feature.zero_crossing_rate(
                        y=y, 
                        frame_length=2048,
                        hop_length=512
                    )
                elif feature_name == 'rmse':
                    features_dict['rmse'] = librosa.feature.rms(y=y)
                else:
                    raise ValueError(f"Unsupported feature: {feature_name}")

            return features_dict
        except Exception as e:
            print(f"Error loading file {file_path}: {e}")
            return None  # Or handle error differently

    @staticmethod
    def extract_prosodic_features(file_path, features=('pitch', 'intensity', 'duration')):
        try:
            y, sr = librosa.load(f'data/audio/{file_path}.wav')
            prosodic_features = {}
            for feature_name in features:
                if feature_name == 'pitch':
                    prosodic_features['pitch'] = librosa.yin(y=y, fmin=65, fmax=2093)
                elif feature_name == 'intensity':
                    prosodic_features['intensity'] = librosa.feature.rms(y=y)
                elif feature_name == 'duration':
                    prosodic_features['duration'] = len(y) / sr
                elif feature_name == 'formants':
                    # Implement formant extraction using librosa or a custom solution
                    prosodic_features['formants'] = None  # Placeholder for now
                else:
                    raise ValueError(f"Unsupported feature: {feature_name}")
            return prosodic_features
        except Exception as e:
            print(f"Error loading file {file_path}: {e}")
            return None  # Handle loading errors

    @staticmethod
    def extract_plp(file_path):
        y, sr = librosa.load(f'data/audio/{file_path}.wav')
        plp = librosa.beat.plp(y=y, sr=sr)
        return plp

# %%
class FeatureExtractorUtils:
    """
        Extracts acoustic features from audio files and preprocesses them for language identification.
    """

    def __init__(self):
        pass  # No initialization needed for now
    
    @staticmethod
    def to_categorical(y):
        '''
            Converts list of languages into a binary class matrix
            :param y (list): list of languages
            :return (numpy array): binary class matrix
        '''
        lang_dict = {}
        for index, language in enumerate(set(y)):
            lang_dict[language] = index
        y = list(map(lambda x: lang_dict[x],y))
        return keras.utils.to_categorical(y, len(lang_dict)), lang_dict

    @staticmethod
    def get_wav(filename):
        """
            Loads a wav file from disk and resamples to a target sample rate.

            Args:
                filename (str): Path to the wav file.

            Returns:
                numpy.ndarray: Down-sampled wav file (or None if an error occurs).
        """
        try:
            y, sr = librosa.load(f'./data/native_combined/{filename}.wav')
            return librosa.core.resample(y=y, orig_sr=sr, target_sr=RATE, scale=True)
        except Exception as e:
            print(f"Error loading wav: {filename} - {e}")
            return None  # Or handle error differently

    @staticmethod
    def to_mfcc(wav):
        """
            Converts a wav file to Mel Frequency Ceptral Coefficients (MFCCs).
            Args:
                wav (numpy array): The wav form data.
                sr (int, optional): The sample rate of the audio. Defaults to None (use from data if available).
                n_mfcc (int, optional): The number of MFCC coefficients to extract. Defaults to None (use librosa's default).
            Returns:
                numpy.ndarray: A 2D numpy array containing the MFCC features.
            Raises:
                Exception: If an error occurs during processing.
        """
        try:
            return librosa.feature.mfcc(y=wav, sr=RATE, n_mfcc=N_MFCC)
        except Exception as e:
            print(f"Error converting wav to MFCC: {e}")
            return None  # Or handle error differently

    @staticmethod
    def normalize_mfcc(mfcc):
        '''
            Normalize mfcc
            :param mfcc:
            :return:
        '''
        mms = MinMaxScaler()
        return(mms.fit_transform(np.abs(mfcc)))

    @staticmethod
    def remove_silence(wav, thresh=0.04, chunk=5000):
        '''
            Searches wav form for segments of silence. If wav form values are lower than 'thresh' for 'chunk' samples, the values will be removed
            :param wav (np array): Wav array to be filtered
            :return (np array): Wav array with silence removed
        '''

        tf_list = []
        for x in range(len(wav) / chunk):
            if (np.any(wav[chunk * x:chunk * (x + 1)] >= thresh) or np.any(wav[chunk * x:chunk * (x + 1)] <= -thresh)):
                tf_list.extend([True] * chunk)
            else:
                tf_list.extend([False] * chunk)

        tf_list.extend((len(wav) - len(tf_list)) * [False])
        return(wav[tf_list])

    @staticmethod
    def make_segments(mfccs,labels):
        '''
            Makes segments of mfccs and attaches them to the labels
            :param mfccs: list of mfccs
            :param labels: list of labels
            :return (tuple): Segments with labels
        '''
        segments = []
        seg_labels = []
        for mfcc,label in zip(mfccs,labels):
            for start in range(0, int(mfcc.shape[1] / COL_SIZE)):
                segments.append(mfcc[:, start * COL_SIZE:(start + 1) * COL_SIZE])
                seg_labels.append(label)
        return (segments, seg_labels)

    @staticmethod
    def segment_one(mfcc):
        '''
            Creates segments from on mfcc image. If last segments is not long enough to be length of columns divided by COL_SIZE
            :param mfcc (numpy array): MFCC array
            :return (numpy array): Segmented MFCC array
        '''
        segments = []
        for start in range(0, int(mfcc.shape[1] / COL_SIZE)):
            segments.append(mfcc[:, start * COL_SIZE:(start + 1) * COL_SIZE])
        return(np.array(segments))

    @staticmethod
    def create_segmented_mfccs(X_train):
        '''
            Creates segmented MFCCs from X_train
            :param X_train: list of MFCCs
            :return: segmented mfccs
        '''
        segmented_mfccs = []
        for mfcc in X_train:
            segmented_mfccs.append(FeatureExtractorUtils.segment_one(mfcc))
        return(segmented_mfccs)

    @staticmethod
    def extract_mfcc_lst(audio_segment, sr=22050, n_mfcc=13, mel_filter_bank=20):
        """
            Extracts MFCCs from a given audio segment.
            Args:
                :param audio_segment: A NumPy array of the audio data.
                :param sr: Sampling rate of the audio (default: 22050 Hz).
                :param n_mfcc: Number of MFCC coefficients to extract (default: 13).
                :param mel_filter_bank: Number of mel filters to use (default: 20).
            Returns:
                A NumPy array of MFCC features for the audio segment.
        """
        mel_spectrogram = librosa.feature.melspectrogram(
            audio_segment, sr=sr, n_mels=mel_filter_bank
        )
        mfcc_lst = librosa.feature.mfcc(
            S=librosa.power_to_db(mel_spectrogram), 
            n_mfccs=n_mfcc
        )
        return mfcc_lst.T  # Transpose to have features as columns

    @staticmethod
    def normalize_mfcc_lst(mfcc_lst: np.array, method: str = None) -> np.array:
        """
            Normalizes MFCC features.

            Args:
                :param mfcc_lst: A NumPy array of MFCC features.
                :param method: Normalization method (default: None) -> This will use the MinMaxScaler.
                        Supported methods: 'minmax', 'standard'

            Returns:
                :return: The normalized MFCC features.
        """
        if method == 'minmax':
            return (mfcc_lst - np.min(mfcc_lst)) / (np.max(mfcc_lst) - np.min(mfcc_lst))
        elif method == 'standard':
            return (mfcc_lst - np.mean(mfcc_lst)) / np.std(mfcc_lst)
        else:
            mms = MinMaxScaler()
            return mms.fit_transform(np.abs(mfcc_lst))

    @staticmethod
    def reduce_dimensionality(mfcc_lst: np.array, n_components: int = 10) -> np.array:
        """
            Reduces the dimensionality of MFCC features using PCA.
            The number of principal components to retain is specified by n_components.

            Args:
                :param mfcc_lst: A NumPy array of MFCC features.
                :param n_components: Number of principal components to retain (default: 10).

            Returns:
                :return: The reduced MFCC features.
        """
        pca = PCA(n_components=n_components)
        reduced_mfcc_lst = pca.fit_transform(mfcc_lst)
        return reduced_mfcc_lst

    @staticmethod
    def combine_segments(mfcc_segments: list, method='mean'):
        """
            Combines MFCC features from multiple segments.
            Args:
                :param mfcc_segments: A list of NumPy arrays of MFCC features, one for each segment.
                :param method: Method for combining features (default: 'mean').
                        Supported methods: 'mean', 'concatenate'
            Returns:
                :return: A NumPy array of combined MFCC features.
        """
        if method == 'mean':
            return np.mean(mfcc_segments, axis=0)
        elif method == 'concatenate':
            return np.concatenate(mfcc_segments, axis=1)
        else:
            raise ValueError(f"Invalid combination method: {method}")

    @staticmethod
    def filter_df(dataframe: pd.DataFrame) -> pd.DataFrame:
        """
            Function to filter audio files based on df columns
            df column options: [age,age_of_english_onset,age_sex,birth_place,english_learning_method,
            english_residence,length_of_english_residence,native_language,other_languages,sex]
            :return (DataFrame): Filtered DataFrame
        """

        # if the dataframe['native_language'] has arabic, mandarin, or english then
        arabic = dataframe[dataframe.native_language == 'arabic']
        mandarin = dataframe[dataframe.native_language == 'mandarin']
        english = dataframe[dataframe.native_language == 'english']
        mandarin = mandarin[mandarin.length_of_english_residence < 10]
        arabic = arabic[arabic.length_of_english_residence < 10]
        # use concat to add the dataframes together
        return pd.concat(
            [
                dataframe,
                mandarin,
                arabic,
                english,
            ],
            ignore_index=True
        )

    @staticmethod
    def split_people(dataframe: pd.DataFrame, test_size: float = 0.2, second_column: str = 'english_residence'):
        """
            Create train test split of DataFrame
            Args:
                :param dataframe: DataFrame to be split
                :param test_size: Percentage of total files to be split into test
            Return:
                :return X_train, X_test, y_train, y_test (tuple): Xs are list of
                df['language_num'] and Ys are df['english_residence']
        """
        x_train, x_test, y_train, y_test = train_test_split(
            dataframe['language_num'],
            dataframe[second_column],
            test_size=test_size,
            train_size= 1 - test_size,
            random_state=1234
        )
        return x_train, x_test, y_train, y_test

# %%
class AudioFeatureExtractor:
    def __init__(self, path:str) -> None:
        """
            Initializes the feature extractor with the directory containing audio files of native speakers.
            Args:
                path (str): Directory path containing audio files of the native English speakers.
        """
        self.native_speakers_dir = path
        self.native_speakers_data = self.load_native_speakers_files()

    def load_native_speakers_files(self):
        """
            Loads the file paths of all audio files in the native speakers directory.
            Returns:
                list: A list containing the file paths of the native English speakers' audio files.
        """
        # This will list every file in the directory
        file_paths = [file for file in os.listdir(self.native_speakers_dir) if file.endswith('.wav')]
        return file_paths

    
    def combine_native_speakers(self, file_path, num_samples=1):
        """
            Combines a 1-second voice sample from the specified file with another 1-second sample
            from a randomly selected native speaker's voice to create a 2-second sample.
            Args:
                file_path (str): Path to the primary audio file.
                num_samples (int): Number of 1-second samples to combine with, should be 1 for a 2-second sample.
            Returns:
                np.ndarray: The combined 2-second audio waveform.
        """
        # print(os.path.join(self.native_speakers_dir, file_path))
        try:
            # Load the primary audio file and take a 1-second sample
            primary_y, sr = librosa.load(os.path.join(self.native_speakers_dir, file_path), sr=None)
            # primary_one_second = librosa.util.fix_length(primary_y, sr)[:sr]
            primary_one_second = librosa.util.fix_length(primary_y, size=num_samples)

            # Randomly select another native speaker file and take a 1-second sample
            random_file_path = random.choice(self.native_speakers_data)
            random_y, _ = librosa.load(os.path.join(self.native_speakers_dir, random_file_path), sr=None)
            # random_one_second = librosa.util.fix_length(random_y, sr)[:sr]
            random_one_second = librosa.util.fix_length(random_y, size=num_samples)

            # Concatenate the two 1-second samples to create a 2-second sample
            combined_y = np.concatenate((primary_one_second, random_one_second))
            return combined_y, sr

        except Exception as e:
            print(f"Error combining native speaker samples for {file_path}: {e}")
            return None, None

# %%
# # audio feature extraction instance
# audio_feature_extractor = AudioFeatureExtractor(path=NATIVE_DIR)
# # load native speaker files
# native_speakers_data = audio_feature_extractor.load_native_speakers_files()

# %%
# # # # NB: Only run this cell once to combine all native speakers

# # load all native speakers
# # native_speakers = []
# # native_sr = []
# os.makedirs('./data/native_combined', exist_ok=True)
# for file in native_speakers_data:
#     combined_y, sr = audio_feature_extractor.combine_native_speakers(file_path = file, num_samples = 1)
#     # native_speakers.append(combined_y)
#     # native_sr.append(sr)
#     sf.write(f'./data/native_combined/{file}', combined_y, sr, subtype='PCM_24')
#     # librosa.output.write_wav(f'data/audio/combined/{file}', combined_y, sr)

# %%
# load the native_bio_metadata.csv
native_bio_metadata = pd.read_csv(NATIVE_FILE_PATH)
native_bio_metadata.head()
# Out:
#                                                 href language_num     sex  \
# 0  http://accent.gmu.edu/browse_language.php?func...    mandarin1  female
# 1  http://accent.gmu.edu/browse_language.php?func...    mandarin2  female
# 2  http://accent.gmu.edu/browse_language.php?func...    mandarin3    male
# 3  http://accent.gmu.edu/browse_language.php?func...    mandarin4  female
# 4  http://accent.gmu.edu/browse_language.php?func...    mandarin5  female
#
#               birth_place  native_language  \
# 0    ['shanxi,', 'china']  mandarin\n(cmn)
# 1   ['nanjing,', 'china']  mandarin\n(cmn)
# 2     ['jilin,', 'china']  mandarin\n(cmn)
# 3  ['shanghai,', 'china']  mandarin\n(cmn)
# 4   ['beijing,', 'china']  mandarin\n(cmn)
#
#                        other_languages                age_sex  \
# 0                             ['none']  ['26,', 'female', '']
# 1                     ['japanese', '']  ['38,', 'female', '']
# 2  ['italian', 'german', 'french', '']    ['43,', 'male', '']
# 3                     ['japanese', '']  ['24,', 'female', '']
# 4                             ['none']  ['31,', 'female', '']
#
#    age_of_english_onset english_learning_method english_residence  \
# 0                  13.0                academic               usa
# 1                  14.0                academic               usa
# 2                  10.0                academic               usa
# 3                   6.0                academic               usa
# 4                  12.0                academic               usa
#
#    length_of_english_residence   age
# 0                          2.0  26.0
# 1                          0.8  38.0
# 2                         14.0  43.0
# 3                          1.0  24.0
# 4                          2.0  31.0

# %%
featureExtractorUtils = FeatureExtractorUtils()
xFeatureExtractor = XFeatureExtractor()

# %%
# split the native_combined_df into train and test
X_train, X_test, y_train, y_test = featureExtractorUtils.split_people(native_bio_metadata, test_size=0.2)

# %%
print(X_test.shape, y_test.shape)
# Out:
# (245,) (245,)

# %%
print(X_train.shape, y_train.shape)
# Out:
# (979,) (979,)

# %%
y_test = y_test.apply(lambda x: x.split('\n')[0])
y_train = y_train.apply(lambda x: x.split('\n')[0])

# %%
# Get statistics
train_count = Counter(y_train)
test_count = Counter(y_test)


print(f"Train Count: {train_count}")
print(f"Test Count: {test_count}")
# Out:
# Train Count: Counter({'usa': 824, 'uk': 95, 'canada': 60})
# Test Count: Counter({'usa': 207, 'uk': 20, 'canada': 18})

# %%
# y_train_encoded = LabelEncoder().fit_transform(y_train)
# y_test_encoded = LabelEncoder().fit_transform(y_test)
# y_train_cat = to_categorical(y_train_encoded)
# y_test_cat = to_categorical(y_test_encoded)

y_train_cat, _ = featureExtractorUtils.to_categorical(y_train)
y_test_cat, lang_dict = featureExtractorUtils.to_categorical(y_test)

# %%
lang_dict
# Out:
# {'uk': 0, 'canada': 1, 'usa': 2}

# %% [markdown]
# # Extract Prosodic, Accoustic and PLP features from audio files

# %%
with ThreadPoolExecutor() as pool:
    X_prosodic = pool.map(xFeatureExtractor.extract_prosodic_features, X_train)
    X_acoustic = pool.map(xFeatureExtractor.extract_acoustic_features, X_train)
    X_plp = pool.map(xFeatureExtractor.extract_plp, X_train)

# %%
with ThreadPoolExecutor() as pool:
    X_test_prosodic = pool.map(xFeatureExtractor.extract_prosodic_features, X_test)
    X_test_acoustic = pool.map(xFeatureExtractor.extract_acoustic_features, X_test)
    X_test_plp = pool.map(xFeatureExtractor.extract_plp, X_test)

# %% [markdown]
# # Train on SHARED Features

# %%
X_acoustic_list = list(X_acoustic)
X_prosodic_list = list(X_prosodic)
X_plp_list = list(X_plp)

print("Type of X_acoustic:", type(X_acoustic))
print("Length of X_acoustic:", len(X_acoustic_list))
# Out:
# Type of X_acoustic: <class 'generator'>
# Length of X_acoustic: 979

# %%
X_acoustic_test_list = list(X_test_acoustic)
X_prosodic_test_list = list(X_test_prosodic)
X_plp_test_list = list(X_test_plp)

# %%
def create_feature_model(X_train_np:np.array):
    # Separate Input Channels approach
    input_shape = X_train_np.shape[1:]  # Use the shape of the MFCC arrays
    mfcc_in = keras.layers.Input(shape=input_shape)
    mfcc_x = keras.layers.Conv1D(filters=16, kernel_size=3, activation='relu')(mfcc_in)
    merged = keras.layers.concatenate([mfcc_x])
    # merged = mfcc_in

    # Rest of the model definition (common for both approaches)
    x = keras.layers.MaxPooling1D(pool_size=2)(merged)
    x = keras.layers.Conv1D(filters=8, kernel_size=3, activation='relu')(x)
    x = keras.layers.MaxPooling1D(pool_size=2)(x)
    x = keras.layers.Flatten()(x)
    x = keras.layers.Dense(units=16, activation='relu')(x)
    outputs = keras.layers.Dense(3, activation='softmax')(x)  # 3 for usa, uk, canada classes

    model = keras.Model(
        inputs=[mfcc_in], outputs=outputs
    )
    model.compile(
        loss='categorical_crossentropy', 
        optimizer='adam', 
        metrics=['accuracy']
    )
    return model


def create_multi_feature_model(
    X_mfcc_np:np.array, 
    X_chroma_stft_np:np.array = None,
    X_spectral_centroid_np:np.array = None,
    use_separate_channels:bool = False
):
    if use_separate_channels and ((X_chroma_stft_np is not None) and (X_spectral_centroid_np is not None)):
        # Separate Input Channels approach
        input_shape_mfcc = X_mfcc_np.shape[1:]
        input_shape_chroma_stft = X_chroma_stft_np.shape[1:]
        input_shape_spectral_centroid = X_spectral_centroid_np.shape[1:]

        mfcc_in = keras.layers.Input(shape=input_shape_mfcc)
        chroma_stft_in = keras.layers.Input(shape=input_shape_chroma_stft)
        spectral_centroid_in = keras.layers.Input(shape=input_shape_spectral_centroid)

        mfcc_x = keras.layers.Conv1D(filters=32, kernel_size=3, activation='relu', padding='same')(mfcc_in)
        chroma_stft_x = keras.layers.Conv1D(filters=16, kernel_size=3, activation='relu', padding='same')(chroma_stft_in)
        spectral_centroid_x = keras.layers.Conv1D(filters=8, kernel_size=3, activation='relu', padding='same')(spectral_centroid_in)
        
        # mfcc_x = keras.layers.GlobalAveragePooling1D()(mfcc_x)
        # chroma_stft_x = keras.layers.GlobalAveragePooling1D()(chroma_stft_x)
        # spectral_centroid_x = keras.layers.GlobalAveragePooling1D()(spectral_centroid_x)
        
        merged = keras.layers.concatenate([mfcc_x, chroma_stft_x, spectral_centroid_x])
        
    elif use_separate_channels and (X_chroma_stft_np is not None):
        # Separate Input Channels approach
        input_shape_mfcc = X_mfcc_np.shape[1:]
        input_shape_chroma_stft = X_chroma_stft_np.shape[1:]

        mfcc_in = keras.layers.Input(shape=input_shape_mfcc)
        chroma_stft_in = keras.layers.Input(shape=input_shape_chroma_stft)

        mfcc_x = keras.layers.Conv1D(filters=16, kernel_size=3, activation='relu', padding='same')(mfcc_in)
        chroma_stft_x = keras.layers.Conv1D(filters=8, kernel_size=3, activation='relu', padding='same')(chroma_stft_in)
        
        # Apply global average pooling to reduce the dimensionality
        # mfcc_x = keras.layers.GlobalAveragePooling1D()(mfcc_x)
        # chroma_stft_x = keras.layers.GlobalAveragePooling1D()(chroma_stft_x)
        
        merged = keras.layers.concatenate([mfcc_x, chroma_stft_x])
        
    elif use_separate_channels and (X_spectral_centroid_np is not None):
        # Separate Input Channels approach
        input_shape_mfcc = X_mfcc_np.shape[1:]
        input_shape_spectral_centroid = X_spectral_centroid_np.shape[1:]

        mfcc_in = keras.layers.Input(shape=input_shape_mfcc)
        spectral_centroid_in = keras.layers.Input(shape=input_shape_spectral_centroid)

        mfcc_x = keras.layers.Conv1D(filters=16, kernel_size=3, activation='relu', padding='same')(mfcc_in)
        spectral_centroid_x = keras.layers.Conv1D(filters=8, kernel_size=3, activation='relu', padding='same')(spectral_centroid_in)
        
        # mfcc_x = keras.layers.GlobalAveragePooling1D()(mfcc_x)
        # chroma_stft_x = keras.layers.GlobalAveragePooling1D()(chroma_stft_x)

        merged = keras.layers.concatenate([mfcc_x, spectral_centroid_x])
    else:
        # Concatenation approach (assuming all features have same time-frequency dimensions)
        input_shape = X_mfcc_np.shape[1:]
        mfcc_in = keras.layers.Input(shape=input_shape)
        merged = mfcc_in

    # Rest of the model definition (common for both approaches)
    x = keras.layers.MaxPooling1D(pool_size=2)(merged)
    x = keras.layers.Conv1D(filters=32, kernel_size=3, activation='relu')(x)
    x = keras.layers.MaxPooling1D(pool_size=2)(x)
    x = keras.layers.Flatten()(x)
    x = keras.layers.Dense(units=64, activation='relu')(x)
    outputs = keras.layers.Dense(3, activation='softmax')(x)  # 3 for usa, uk, canada classes

    if use_separate_channels and ((X_chroma_stft_np is not None) and (X_spectral_centroid_np is not None)):
        model = keras.Model(inputs=[mfcc_in, chroma_stft_in, spectral_centroid_in], outputs=outputs)
    elif use_separate_channels and (X_chroma_stft_np is not None):
        model = keras.Model(inputs=[mfcc_in, chroma_stft_in], outputs=outputs)
    elif use_separate_channels and(X_spectral_centroid_np is not None):
        model = keras.Model(inputs=[mfcc_in, spectral_centroid_in], outputs=outputs)
    else:
        model = keras.Model(inputs=mfcc_in, outputs=outputs)

    model.compile(
        loss='categorical_crossentropy',
        optimizer='adam',
        metrics=['accuracy']
    )
    return model

def create_hybrid_model(
    X_mfcc_np:np.array,
    X_chroma_stft_np:np.array = None,
    X_spectral_centroid_np:np.array = None,
    use_separate_channels:bool = False
) -> any:
    if use_separate_channels and ((X_chroma_stft_np is not None) and (X_spectral_centroid_np is not None)):
        # Separate Input Channels approach
        input_shape_mfcc = X_mfcc_np.shape[1:]
        input_shape_chroma_stft = X_chroma_stft_np.shape[1:]
        input_shape_spectral_centroid = X_spectral_centroid_np.shape[1:]

        mfcc_in = keras.layers.Input(shape=input_shape_mfcc)
        chroma_stft_in = keras.layers.Input(shape=input_shape_chroma_stft)
        spectral_centroid_in = keras.layers.Input(shape=input_shape_spectral_centroid)

        mfcc_x = keras.layers.Conv1D(filters=32, kernel_size=3, activation='relu', padding='same')(mfcc_in)
        chroma_stft_x = keras.layers.Conv1D(filters=16, kernel_size=3, activation='relu', padding='same')(chroma_stft_in)
        spectral_centroid_x = keras.layers.Conv1D(filters=8, kernel_size=3, activation='relu', padding='same')(spectral_centroid_in)
        
        # mfcc_x = keras.layers.GlobalAveragePooling1D()(mfcc_x)
        # chroma_stft_x = keras.layers.GlobalAveragePooling1D()(chroma_stft_x)
        # spectral_centroid_x = keras.layers.GlobalAveragePooling1D()(spectral_centroid_x)
        
        merged = keras.layers.concatenate([mfcc_x, chroma_stft_x, spectral_centroid_x])
        
    elif use_separate_channels and (X_chroma_stft_np is not None):
        # Separate Input Channels approach
        input_shape_mfcc = X_mfcc_np.shape[1:]
        input_shape_chroma_stft = X_chroma_stft_np.shape[1:]

        mfcc_in = keras.layers.Input(shape=input_shape_mfcc)
        chroma_stft_in = keras.layers.Input(shape=input_shape_chroma_stft)

        mfcc_x = keras.layers.Conv1D(filters=16, kernel_size=3, activation='relu', padding='same')(mfcc_in)
        chroma_stft_x = keras.layers.Conv1D(filters=8, kernel_size=3, activation='relu', padding='same')(chroma_stft_in)
        
        # Apply global average pooling to reduce the dimensionality
        # mfcc_x = keras.layers.GlobalAveragePooling1D()(mfcc_x)
        # chroma_stft_x = keras.layers.GlobalAveragePooling1D()(chroma_stft_x)
        
        merged = keras.layers.concatenate([mfcc_x, chroma_stft_x])
        
    elif use_separate_channels and (X_spectral_centroid_np is not None):
        # Separate Input Channels approach
        input_shape_mfcc = X_mfcc_np.shape[1:]
        input_shape_spectral_centroid = X_spectral_centroid_np.shape[1:]

        mfcc_in = keras.layers.Input(shape=input_shape_mfcc)
        spectral_centroid_in = keras.layers.Input(shape=input_shape_spectral_centroid)

        mfcc_x = keras.layers.Conv1D(filters=16, kernel_size=3, activation='relu', padding='same')(mfcc_in)
        spectral_centroid_x = keras.layers.Conv1D(filters=8, kernel_size=3, activation='relu', padding='same')(spectral_centroid_in)
        
        # mfcc_x = keras.layers.GlobalAveragePooling1D()(mfcc_x)
        # chroma_stft_x = keras.layers.GlobalAveragePooling1D()(chroma_stft_x)

        merged = keras.layers.concatenate([mfcc_x, spectral_centroid_x])
    else:
        # Concatenation approach (assuming all features have same time-frequency dimensions)
        input_shape = X_mfcc_np.shape[1:]
        mfcc_in = keras.layers.Input(shape=input_shape)
        merged = mfcc_in

    # Rest of the model definition (common for both approaches)
    x = keras.layers.MaxPooling1D(pool_size=2)(merged)
    x = keras.layers.Conv1D(filters=128, kernel_size=3, activation='relu')(x)
    x = keras.layers.MaxPooling1D(pool_size=2)(x)
    # x = keras.layers.Flatten()(x)
    x = keras.layers.LSTM(128, return_sequences=True)(x)
    x = keras.layers.LSTM(128)(x)
    # x = keras.layers.LSTM(128)(x)
    x = keras.layers.Dense(units=64, activation='relu')(x)
    outputs = keras.layers.Dense(3, activation='softmax')(x)  # 3 for usa, uk, canada classes

    if use_separate_channels and ((X_chroma_stft_np is not None) and (X_spectral_centroid_np is not None)):
        model = keras.Model(inputs=[mfcc_in, chroma_stft_in, spectral_centroid_in], outputs=outputs)
    elif use_separate_channels and (X_chroma_stft_np is not None):
        model = keras.Model(inputs=[mfcc_in, chroma_stft_in], outputs=outputs)
    elif use_separate_channels and(X_spectral_centroid_np is not None):
        model = keras.Model(inputs=[mfcc_in, spectral_centroid_in], outputs=outputs)
    else:
        model = keras.Model(inputs=mfcc_in, outputs=outputs)

    model.compile(
        loss='categorical_crossentropy',
        optimizer='adam',
        metrics=['accuracy']
    )
    
    return model

# %% [markdown]
# # for multi-feature model use below cells

# %%
max_length = 2000
chroma_stft_list = []
spectral_centroid_list = []
mfcc_list = []

for sample in X_acoustic_list:
    mfcc_array = np.array(sample['mfcc'])
    chroma_stft_array = np.array(sample['chroma_stft'])
    spectral_centroid_array = np.array(sample['spectral_centroid'])
    
    if mfcc_array.shape[1] < max_length:
        padded_mfcc_array = np.pad(mfcc_array, ((0, 0), (0, max_length - mfcc_array.shape[1])), mode='constant')
    else:
        padded_mfcc_array = mfcc_array[:, :max_length]

    # Pad or truncate arrays to max_length if needed
    if chroma_stft_array.shape[1] < max_length:
        padded_chroma_stft_array = np.pad(chroma_stft_array, ((0, 0), (0, max_length - chroma_stft_array.shape[1])), mode='constant')
    else:
        padded_chroma_stft_array = chroma_stft_array[:, :max_length]

    if spectral_centroid_array.shape[1] < max_length:
        padded_spectral_centroid_array = np.pad(spectral_centroid_array, ((0, 0), (0, max_length - spectral_centroid_array.shape[1])), mode='constant')
    else:
        padded_spectral_centroid_array = spectral_centroid_array[:, :max_length]

    mfcc_list.append(padded_mfcc_array)
    chroma_stft_list.append(padded_chroma_stft_array)
    spectral_centroid_list.append(padded_spectral_centroid_array)

# Convert the lists of processed features into numpy arrays
X_mfcc_stft_np = np.array(mfcc_list)
X_chroma_stft_np = np.array(chroma_stft_list)
X_spectral_centroid_np = np.array(spectral_centroid_list)

# %%
# # # Test values

max_length = 2000
mfcc_test_list = []
chroma_test_stft_list = []
spectral_test_centroid_list = []

for sample in X_acoustic_test_list:
    mfcc_test_array = np.array(sample['mfcc'])
    chroma_test_stft_array = np.array(sample['chroma_stft'])
    spectral_test_centroid_array = np.array(sample['spectral_centroid'])
    
    if mfcc_test_array.shape[1] < max_length:
        padded_mfcc_test_array = np.pad(mfcc_test_array, ((0, 0), (0, max_length - mfcc_test_array.shape[1])), mode='constant')
    else:
        padded_mfcc_test_array = mfcc_test_array[:, :max_length]

    # Pad or truncate arrays to max_length if needed
    if chroma_test_stft_array.shape[1] < max_length:
        padded_chroma_test_stft_array = np.pad(chroma_test_stft_array, ((0, 0), (0, max_length - chroma_test_stft_array.shape[1])), mode='constant')
    else:
        padded_chroma_test_stft_array = chroma_test_stft_array[:, :max_length]

    if spectral_test_centroid_array.shape[1] < max_length:
        padded_spectral_test_centroid_array = np.pad(spectral_test_centroid_array, ((0, 0), (0, max_length - spectral_test_centroid_array.shape[1])), mode='constant')
    else:
        padded_spectral_test_centroid_array = spectral_test_centroid_array[:, :max_length]

    mfcc_test_list.append(padded_mfcc_test_array)
    chroma_test_stft_list.append(padded_chroma_test_stft_array)
    spectral_test_centroid_list.append(padded_spectral_test_centroid_array)

# Convert the lists of processed features into numpy arrays
X_mfcc_stft_test_np = np.array(mfcc_test_list)
X_chroma_stft_test_np = np.array(chroma_test_stft_list)
X_spectral_centroid_test_np = np.array(spectral_test_centroid_list)

# %%
# Pad or truncate the arrays to ensure they have the same shape along the concatenation axis
max_length = max(X_mfcc_stft_np.shape[1], X_chroma_stft_np.shape[1])
X_mfcc_np_padded = np.pad(
    X_mfcc_stft_np, 
    ((0, 0), (0, max_length - X_mfcc_stft_np.shape[1]), (0, 0)), 
    mode='constant'
)
X_chroma_stft_np_padded = np.pad(
    X_chroma_stft_np, 
    ((0, 0), (0, max_length - X_chroma_stft_np.shape[1]), (0, 0)), 
    mode='constant'
)

# %%
# Pad or truncate the arrays to ensure they have the same shape along the concatenation axis
max_length_test = max(X_mfcc_stft_test_np.shape[1], X_chroma_stft_test_np.shape[1])
X_mfcc_test_np_padded = np.pad(X_mfcc_stft_test_np, ((0, 0), (0, max_length_test - X_mfcc_stft_test_np.shape[1]), (0, 0)), mode='constant')
X_chroma_test_stft_np_padded = np.pad(X_chroma_stft_test_np, ((0, 0), (0, max_length_test - X_chroma_stft_test_np.shape[1]), (0, 0)), mode='constant')

# %%
# Choose the approach (concatenation or separate channels)
use_separate_channels = True

# Create CNN architecture
multi_model = create_multi_feature_model(
    X_mfcc_np=X_mfcc_np_padded,
    X_chroma_stft_np=X_chroma_stft_np_padded,
    # X_spectral_centroid_np=X_spectral_centroid_np,
    use_separate_channels=use_separate_channels
)
# Out:
# WARNING:tensorflow:From c:\Users\musah\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\Users\musah\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:6642: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From c:\Users\musah\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# model summary
multi_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 40, 2000)]           0         []
#
#  input_2 (InputLayer)        [(None, 40, 2000)]           0         []
#
#  conv1d (Conv1D)             (None, 40, 16)               96016     ['input_1[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 40, 8)                48008     ['input_2[0][0]']
#
#  concatenate (Concatenate)   (None, 40, 24)               0         ['conv1d[0][0]',
#                                                                      'conv1d_1[0][0]']
#
#  max_pooling1d (MaxPooling1  (None, 20, 24)               0         ['concatenate[0][0]']
#  D)
#
#  conv1d_2 (Conv1D)           (None, 18, 32)               2336      ['max_pooling1d[0][0]']
#
#  max_pooling1d_1 (MaxPoolin  (None, 9, 32)                0         ['conv1d_2[0][0]']
#  g1D)
#
#  flatten (Flatten)           (None, 288)                  0         ['max_pooling1d_1[0][0]']
#
#  dense (Dense)               (None, 64)                   18496     ['flatten[0][0]']
#
#  dense_1 (Dense)             (None, 3)                    195       ['dense[0][0]']
#
# ==================================================================================================
# Total params: 165051 (644.73 KB)
# Trainable params: 165051 (644.73 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
os.makedirs("files", exist_ok=True)

# %%
# plot the model
keras.utils.plot_model(multi_model, to_file='files/multi_feature_model.png', show_shapes=False)

# %%
history = multi_model.fit(
    [X_mfcc_np_padded, X_chroma_stft_np_padded], 
    y_train_cat,
    epochs=EPOCHS,
    validation_data=([X_mfcc_test_np_padded, X_chroma_test_stft_np_padded], y_test_cat)
)
# Out:
# Epoch 1/250
# WARNING:tensorflow:From c:\Users\musah\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\musah\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
#
# 31/31 [==============================] - 1s 28ms/step - loss: 0.0801 - accuracy: 0.9418 - val_loss: 1.4469 - val_accuracy: 0.7878
# Epoch 249/250
# 31/31 [==============================] - 1s 32ms/step - loss: 0.0720 - accuracy: 0.9459 - val_loss: 1.6755 - val_accuracy: 0.8122
# Epoch 250/250
# 31/31 [==============================] - 1s 31ms/step - loss: 0.0723 - accuracy: 0.9418 - val_loss: 1.7280 - val_accuracy: 0.8000

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# save the model
multi_model.save('./files/multi_feature_model.keras')

# %%
# Evaluate model
loss, accuracy = multi_model.evaluate([
        X_mfcc_test_np_padded, 
        X_chroma_test_stft_np_padded
    ],
    y_test_cat
)
print("Test Loss:", loss, "Test Accuracy:", accuracy)
# Out:
# 8/8 [==============================] - 0s 13ms/step - loss: 1.7280 - accuracy: 0.8000
# Test Loss: 1.7279785871505737 Test Accuracy: 0.800000011920929

# %%
# Make predictions on new data
multi_predictions = multi_model.predict([
    X_mfcc_test_np_padded, 
    X_chroma_test_stft_np_padded
])

# The predictions will be probabilities for each class
# You can convert these probabilities to class labels
multi_predicted_labels = np.argmax(multi_predictions, axis=1)

# Example of using the predicted labels
print(multi_predicted_labels)
# Out:
# 8/8 [==============================] - 0s 8ms/step
# [2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 0 2 2 2 2 2 2 2 0 2 2 2 2 2 2 2 2 2 2 2 2 0
#  2 2 2 2 0 2 2 2 2 2 2 2 2 2 2 2 2 1 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2
#  2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2
#  2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2
#  2 2 0 2 2 2 0 2 2 2 2 2 2 2 2 2 0 2 0 2 2 2 2 2 2 2 2 2 0 2 2 2 2 2 2 2 2
#  0 2 2 2 2 2 2 2 2 2 2 2 1 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2
#  2 2 0 2 0 2 2 2 2 2 2 2 0 2 2 2 2 2 2 2 2 1 2]

# %%
lang_dict
# Out:
# {'uk': 0, 'canada': 1, 'usa': 2}

# %%
kyes = list(lang_dict.keys())
values = list(lang_dict.values())

# create index to label with the language_dict values and keys
class_index_to_label = {values[i]: kyes[i] for i in range(len(kyes))}
class_index_to_label
# Out:
# {0: 'uk', 1: 'canada', 2: 'usa'}

# %%
# Convert numeric predictions to label names
predicted_labels_names = [class_index_to_label[idx] for idx in np.argmax(multi_predictions, axis=1)]

predicted_labels_names
# Out:
# ['usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'uk',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'uk',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'uk',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'uk',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'canada',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'uk',
#  'usa',
#  'usa',
#  'usa',
#  'uk',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'uk',
#  'usa',
#  'uk',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'uk',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'uk',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'canada',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'uk',
#  'usa',
#  'uk',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'uk',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'canada',
#  'usa']

# %%
# Convert predicted class indices to one-hot encoded format
label_binarizer = LabelBinarizer()
predicted_labels_one_hot = label_binarizer.fit_transform(multi_predicted_labels)

# Calculate confusion matrix
cm = confusion_matrix(y_test_cat.argmax(axis=1), predicted_labels_one_hot.argmax(axis=1))

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(
    cm, 
    annot=True, 
    cmap='Blues', 
    fmt='g', 
    xticklabels=class_index_to_label.values(), 
    yticklabels=class_index_to_label.values()
)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.savefig('./files/multi_feature_confusion_matrix.png')
plt.show()

# %% [markdown]
# # for single feature model - use below cells

# %%
# X_train_acoustic is a list of dictionaries with 'mfcc' as one of the features
max_length = 2000  # Define the maximum length you want to pad/truncate to
X_train_acoustic_processed = []
for sample in X_acoustic_list:
    mfcc_array = np.array(sample['mfcc'])
    current_length = mfcc_array.shape[1]
    # Pad or truncate the array to max_length
    if current_length < max_length:
        padded_mfcc_array = np.pad(mfcc_array, ((0, 0), (0, max_length - current_length)), mode='constant')
    else:
        padded_mfcc_array = mfcc_array[:, :max_length]
    X_train_acoustic_processed.append(padded_mfcc_array)

# Convert the list of processed features into a numpy array
X_train_np = np.array(X_train_acoustic_processed)

# %%
# Assuming X_train_acoustic is a list of dictionaries with 'mfcc' as one of the features
max_length = 2000  # Define the maximum length you want to pad/truncate to
X_test_acoustic_processed = []
for sample in X_acoustic_test_list:
    mfcc_array = np.array(sample['mfcc'])
    current_length = mfcc_array.shape[1]
    # Pad or truncate the array to max_length
    if current_length < max_length:
        padded_mfcc_array = np.pad(mfcc_array, ((0, 0), (0, max_length - current_length)), mode='constant')
    else:
        padded_mfcc_array = mfcc_array[:, :max_length]
    X_test_acoustic_processed.append(padded_mfcc_array)

# Convert the list of processed features into a numpy array
X_test_np = np.array(X_test_acoustic_processed)

# %%
single_model = create_feature_model(X_train_np)

# %%
# model summary
single_model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 40, 2000)]        0
#
#  conv1d_3 (Conv1D)           (None, 38, 16)            96016
#
#  concatenate_1 (Concatenate  (None, 38, 16)            0
#  )
#
#  max_pooling1d_2 (MaxPoolin  (None, 19, 16)            0
#  g1D)
#
#  conv1d_4 (Conv1D)           (None, 17, 8)             392
#
#  max_pooling1d_3 (MaxPoolin  (None, 8, 8)              0
#  g1D)
#
#  flatten_1 (Flatten)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 16)                1040
#
#  dense_3 (Dense)             (None, 3)                 51
#
# =================================================================
# Total params: 97499 (380.86 KB)
# Trainable params: 97499 (380.86 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
os.makedirs("files", exist_ok=True)

# %%
# plot the model
keras.utils.plot_model(single_model, to_file='files/feature_model.png', show_shapes=False)

# %%
# X_train_np

# %%
# train the model
single_history = single_model.fit(
    X_train_np, 
    y_train_cat, 
    epochs=EPOCHS, 
    validation_data=(X_test_np, y_test_cat)
)
# Out:
# Epoch 1/250
# 31/31 [==============================] - 12s 57ms/step - loss: 5.9778 - accuracy: 0.7068 - val_loss: 4.7861 - val_accuracy: 0.6857
# Epoch 2/250
# 31/31 [==============================] - 1s 25ms/step - loss: 2.8835 - accuracy: 0.7722 - val_loss: 3.5718 - val_accuracy: 0.7714
# Epoch 3/250
# 31/31 [==============================] - 1s 24ms/step - loss: 1.2221 - accuracy: 0.8294 - val_loss: 3.0827 - val_accuracy: 0.6816
# Epoch 4/250
# 31/31 [==============================] - 1s 23ms/step - loss: 0.7492 - accuracy: 0.8876 - val_loss: 3.0618 - val_accuracy: 0.7102
# Epoch 5/250
# 31/31 [==============================] - 1s 26ms/step - loss: 0.4691 - accuracy: 0.9091 - val_loss: 2.8653 - val_accuracy: 0.7551
# Epoch 6/250
# 31/31 [==============================] - 1s 24ms/step - loss: 0.4749 - accuracy: 0.9152 - val_loss: 2.8565 - val_accuracy: 0.7306
# Epoch 7/250
# 31/31 [==============================] - 1s 25ms/step - loss: 0.4385 - accuracy: 0.9234 - val_loss: 2.9400 - val_accuracy: 0.7388
# Epoch 8/250
# 31/31 [==============================] - 1s 23ms/step - loss: 0.4009 - accuracy: 0.9285 - val_loss: 2.5336 - val_accuracy: 0.7347
# Epoch 9/250
# 31/31 [==============================] - 1s 34ms/step - loss: 0.3415 - accuracy: 0.9346 - val_loss: 2.8322 - val_accuracy: 0.6980
# Epoch 10/250
# 31/31 [==============================] - 1s 27ms/step - loss: 0.4102 - accuracy: 0.9265 - val_loss: 2.2625 - val_accuracy: 0.6816
# Epoch 11/250
# 31/31 [==============================] - 1s 25ms/step - loss: 0
# 31/31 [==============================] - 1s 20ms/step - loss: 0.1466 - accuracy: 0.9428 - val_loss: 1.2095 - val_accuracy: 0.7796
# Epoch 38/250
# 31/31 [==============================] - 1s 21ms/step - loss: 0.1613 - accuracy: 0.9459 - val_loss: 1.2894 - val_accuracy: 0.7837
# Epoch 39/250
# 31/31 [==============================] - 1s 27ms/step - loss: 0.1219 - accuracy: 0.9489 - val_loss: 1.3183 - val_accuracy: 0.7388
# Epoch 40/250
# 31/31 [==============================] - 1s 31ms/step - loss: 0.1497 - accuracy: 0.9346 - val_loss: 1.3241 - val_accuracy: 0.7592
# Epoch 41/250
# 31/31 [==============================] - 1s 25ms/step - loss: 0.1682 - accuracy: 0.9397 - val_loss: 1.3031 - val_accuracy: 0.7714
# Epoch 42/250
# 31/31 [==============================] - 1s 47ms/step - loss: 0.1567 - accuracy: 0.9377 - val_loss: 1.1927 - val_accuracy: 0.7510
# Epoch 43/250
# 31/31 [==============================] - 1s 40ms/step - loss: 0.1458 - accuracy: 0.9408 - val_loss: 1.2080 - val_accuracy: 0.7755
# Epoch 44/250
# 31/31 [==============================] - 1s 18ms/step - loss: 0.1184 - accuracy: 0.9448 - val_loss: 1.2378 - val_accuracy: 0.7551
# Epoch 45/250
# 31/31 [==============================] - 1s 23ms/step - loss: 0.1380 - accuracy: 0.9418 - val_loss: 1.3193 - val_accuracy: 0.7102
# Epoch 46/250
# 31/31 [==============================] - 0s 14ms/step - loss: 0.1250 - accuracy: 0.9408 - val_loss: 1.1936 - val_accuracy: 0.7755
# Epoch 47/250
# 31/31 [==============================] - 0s 13ms/step - loss: 0.1298 - accuracy: 0.9418 - val_loss: 1.1853 - val_accuracy: 0.8082
# Epoch 48/250
# 31/31 [==============================] - 1s 17ms/step - loss: 0.1152 - accuracy: 0.9510 - val_loss: 1.2915 - val_accuracy: 0.7265
# Epoch 49/250
# 31/31 [==============================] - 1s 16ms/step - loss: 0.1126 - accuracy: 0.9510 - val_loss: 1.2653 - val_accuracy: 0.8163
# Epoch 50/250
# 31/31 [==============================] - 1s 18ms/step - loss: 0.1361 - accuracy: 0.9408 - val_loss: 1.2942 - val_accuracy: 0.8000
# Epoch 51/250
# 31/31 [==============================] - 1s 21ms/step - loss: 0.1205 - accuracy: 0.9428 - val_loss: 1.1651 - val_accuracy: 0.7551
# Epoch 52/250
# 31/31 [==============================] - 1s 19ms/step - loss: 0.1132 - accuracy: 0.9377 - val_loss: 1.1718 - val_accuracy: 0.7469
# Epoch 53/250
# 31/31 [==============================] - 1s 33ms/step - loss: 0.1452 - accuracy: 0.9499 - val_loss: 1.2219 - val_accuracy: 0.8000
# Epoch 54/250
# 31/31 [==============================] - 1s 20ms/step - loss: 0.1262 - accuracy: 0.9418 - val_loss: 1.2754 - val_accuracy: 0.7102
# Epoch 55/250
# 31/31 [==============================] - 1s 21ms/step - loss: 0.1321 - accuracy: 0.9438 - val_loss: 1.3621 - val_accuracy: 0.7143
# Epoch 56/250
# 31/31 [==============================] - 1s 30ms/step - loss: 0.1574 - accuracy: 0.9356 - val_loss: 1.4106 - val_accuracy: 0.6857
# Epoch 57/250
# 31/31 [==============================] - 1s 26ms/step - loss: 0.1460 - accuracy: 0.9459 - val_loss: 1.3673 - val_accuracy: 0.7714
# Epoch 58/250
# 31/31 [==============================] - 1s 21ms/step - loss: 0.1324 - accuracy: 0.9408 - val_loss: 1.2286 - val_accuracy: 0.7755
# Epoch 59/250
# 31/31 [==============================] - 1s 21ms/step - loss: 0.1532 - accuracy: 0.9367 - val_loss: 1.2835 - val_accuracy: 0.7633
# Epoch 60/250
# 31/31 [==============================] - 0s 14ms/step - loss: 0.1162 - accuracy: 0.9418 - val_loss: 1.2390 - val_accuracy: 0.7020
# Epoch 61/250
# 31/31 [==============================] - 0s 12ms/step - loss: 0.1163 - accuracy: 0.9428 - val_loss: 1.3072 - val_accuracy: 0.7959
# Epoch 62/250
# 31/31 [==============================] - 0s 13ms/step - loss: 0.1222 - accuracy: 0.9397 - val_loss: 1.1564 - val_accuracy: 0.7755
# Epoch 63/250
# 31/31 [==============================] - 0s 16ms/step - loss: 0.1209 - accuracy: 0.9499 - val_loss: 1.2453 - val_accuracy: 0.8082
# Epoch 64/250
# 31/31 [==============================] - 0s 16ms/step - loss: 0.1210 - accuracy: 0.9377 - val_loss: 1.3023 - val_accuracy: 0.7837
# Epoch 65/250
# 31/31 [==============================] - 0s 16ms/step - loss: 0.1189 - accuracy: 0.9397 - val_loss: 1.3413 - val_accuracy: 0.7796
# Epoch 66/250
# 31/31 [==============================] - 0s 14ms/step - loss: 0.1266 - accuracy: 0.9418 - val_loss: 1.2415 - val_accuracy: 0.7551
# Epoch 67/250
# 31/31 [==============================] - 0s 15ms/step - loss: 0.1063 - accuracy: 0.9448 - val_loss: 1.2098 - val_accuracy: 0.8082
# Epoch 68/250
# 31/31 [==============================] - 1s 22ms/step - loss: 0.1110 - accuracy: 0.9448 - val_loss: 1.1932 - val_accuracy: 0.7959
# Epoch 69/250
# 31/31 [==============================] - 1s 18ms/step - loss: 0.1138 - accuracy: 0.9408 - val_loss: 1.2187 - val_accuracy: 0.7633
# Epoch 70/250
# 31/31 [==============================] - 1s 21ms/step - loss: 0.1019 - accuracy: 0.9387 - val_loss: 1.2035 - val_accuracy: 0.7510
# Epoch 71/250
# 31/31 [==============================] - 1s 30ms/step - loss: 0.1005 - accuracy: 0.9510 - val_loss: 1.3035 - val_accuracy: 0.8204
# Epoch 72/250
# 31/31 [==============================] - 1s 28ms/step - loss: 0.1005 - accuracy: 0.9428 - val_loss: 1.1954 - val_accuracy: 0.7837
# Epoch 73/250
# 31/31 [==============================] - 1s 34ms/step - loss: 0.1598 - accuracy: 0.9397 - val_loss: 1.1909 - val_accuracy: 0.7469
# Epoch 74/250
# 31/31 [==============================] - 1s 22ms/step - loss: 0.1106 - accuracy: 0.9448 - val_loss: 1.0593 - val_accuracy: 0.7918
# Epoch 75/250
# 31/31 [==============================] - 1s 25ms/step - loss: 0.1398 - accuracy: 0.9418 - val_loss: 1.5383 - val_accuracy: 0.7796
# Epoch 76/250
# 31/31 [==============================] - 1s 23ms/step - loss: 0.2147 - accuracy: 0.9346 - val_loss: 1.1295 - val_accuracy: 0.7102
# Epoch 77/250
# 31/31 [==============================] - 1s 17ms/step - loss: 0.1767 - accuracy: 0.9346 - val_loss: 1.0916 - val_accuracy: 0.7959
# Epoch 78/250
# 31/31 [==============================] - 1s 19ms/step - loss: 0.1290 - accuracy: 0.9418 - val_loss: 1.0935 - val_accuracy: 0.7878
# Epoch 79/250
# 31/31 [==============================] - 0s 16ms/step - loss: 0.1284 - accuracy: 0.9367 - val_loss: 1.1868 - val_accuracy: 0.7429
# Epoch 80/250
# 31/31 [==============================] - 1s 21ms/step - loss: 0.1261 - accuracy: 0.9397 - val_loss: 1.2146 - val_accuracy: 0.7918
# Epoch 81/250
# 31/31 [==============================] - 1s 22ms/step - loss: 0.1280 - accuracy: 0.9428 - val_loss: 1.1804 - val_accuracy: 0.7469
# Epoch 82/250
# 31/31 [==============================] - 1s 23ms/step - loss: 0.1107 - accuracy: 0.9428 - val_loss: 1.1401 - val_accuracy: 0.7959
# Epoch 83/250
# 31/31 [==============================] - 1s 22ms/step - loss: 0.1043 - accuracy: 0.9459 - val_loss: 1.2047 - val_accuracy: 0.8163
# Epoch 84/250
# 31/31 [==============================] - 1s 26ms/step - loss: 0.1150 - accuracy: 0.9489 - val_loss: 1.1673 - val_accuracy: 0.7469
# Epoch 85/250
# 31/31 [==============================] - 1s 23ms/step - loss: 0.1458 - accuracy: 0.9459 - val_loss: 1.3102 - val_accuracy: 0.7673
# Epoch 86/250
# 31/31 [==============================] - 1s 22ms/step - loss: 0.1456 - accuracy: 0.9459 - val_loss: 1.2064 - val_accuracy: 0.8041
# Epoch 87/250
# 31/31 [==============================] - 1s 18ms/step - loss: 0.1518 - accuracy: 0.9438 - val_loss: 1.3606 - val_accuracy: 0.8122
# Epoch 88/250
# 31/31 [==============================] - 1s 22ms/step - loss: 0.1552 - accuracy: 0.9489 - val_loss: 1.1566 - val_accuracy: 0.7878
# Epoch 89/250
# 31/31 [==============================] - 1s 23ms/step - loss: 0.1384 - accuracy: 0.9305 - val_loss: 1.0661 - val_accuracy: 0.7510
# Epoch 90/250
# 31/31 [==============================] - 1s 19ms/step - loss: 0.1042 - accuracy: 0.9438 - val_loss: 1.1439 - val_accuracy: 0.8082
# Epoch 91/250
# 31/31 [==============================] - 1s 20ms/step - loss: 0.1218 - accuracy: 0.9479 - val_loss: 1.2888 - val_accuracy: 0.7347
# Epoch 92/250
# 31/31 [==============================] - 0s 16ms/step - loss: 0.1280 - accuracy: 0.9408 - val_loss: 1.2168 - val_accuracy: 0.7551
# Epoch 93/250
# 31/31 [==============================] - 1s 17ms/step - loss: 0.1282 - accuracy: 0.9428 - val_loss: 1.3863 - val_accuracy: 0.8204
# Epoch 94/250
# 31/31 [==============================] - 0s 14ms/step - loss: 0.1312 - accuracy: 0.9459 - val_loss: 1.2174 - val_accuracy: 0.7755
# Epoch 95/250
# 31/31 [==============================] - 0s 14ms/step - loss: 0.1379 - accuracy: 0.9459 - val_loss: 1.1439 - val_accuracy: 0.7673
# Epoch 96/250
# 31/31 [==============================] - 0s 14ms/step - loss: 0.1079 - accuracy: 0.9530 - val_loss: 1.1645 - val_accuracy: 0.8000
# Epoch 97/250
# 31/31 [==============================] - 0s 13ms/step - loss: 0.1337 - accuracy: 0.9418 - val_loss: 1.1265 - val_accuracy: 0.7918
# Epoch 98/250
# 31/31 [==============================] - 0s 13ms/step - loss: 0.1103 - accuracy: 0.9448 - val_loss: 1.2261 - val_accuracy: 0.7306
# Epoch 99/250
# 31/31 [==============================] - 0s 14ms/step - loss: 0.1234 - accuracy: 0.9459 - val_loss: 1.3078 - val_accuracy: 0.7755
# Epoch 100/250
# 31/31 [==============================] - 0s 14ms/step - loss: 0.1247 - accuracy: 0.9428 - val_loss: 1.1490 - val_accuracy: 0.7878
# Epoch 101/250
# 31/31 [==============================] - 0s 14ms/step - loss: 0.1275 - accuracy: 0.9448 - val_loss: 1.2497 - val_accuracy: 0.8204
# Epoch 102/250
# 31/31 [==============================] - 0s 13ms/step - loss: 0.1267 - accuracy: 0.9418 - val_loss: 1.1917 - val_accuracy: 0.7469
# Epoch 103/250
# 31/31 [==============================] - 0s 14ms/step - loss: 0.1152 - accuracy: 0.9397 - val_loss: 1.2521 - val_accuracy: 0.7959
# Epoch 104/250
# 31/31 [==============================] - 1s 16ms/step - loss: 0.1027 - accuracy: 0.9448 - val_loss: 1.2399 - val_accuracy: 0.7918
# Epoch 105/250
# 31/31 [==============================] - 1s 18ms/step - loss: 0.1020 - accuracy: 0.9418 - val_loss: 1.2090 - val_accuracy: 0.8000
# Epoch 106/250
# 31/31 [==============================] - 1s 20ms/step - loss: 0.0945 - accuracy: 0.9408 - val_loss: 1.2033 - val_accuracy: 0.8082
# Epoch 107/250
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0986 - accuracy: 0.9346 - val_loss: 1.2194 - val_accuracy: 0.8122
# Epoch 108/250
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0936 - accuracy: 0.9499 - val_loss: 1.2567 - val_accuracy: 0.7184
# Epoch 109/250
# 31/31 [==============================] - 1s 17ms/step - loss: 0.3357 - accuracy: 0.9254 - val_loss: 1.3349 - val_accuracy: 0.7143
# Epoch 110/250
# 31/31 [==============================] - 1s 17ms/step - loss: 0.2494 - accuracy: 0.9162 - val_loss: 1.3304 - val_accuracy: 0.7673
# Epoch 111/250
# 31/31 [==============================] - 1s 19ms/step - loss: 0.1541 - accuracy: 0.9387 - val_loss: 1.2760 - val_accuracy: 0.7388
# Epoch 112/250
# 31/31 [==============================] - 1s 23ms/step - loss: 0.1316 - accuracy: 0.9448 - val_loss: 1.3554 - val_accuracy: 0.7837
# Epoch 113/250
# 31/31 [==============================] - 0s 14ms/step - loss: 0.1294 - accuracy: 0.9397 - val_loss: 1.2598 - val_accuracy: 0.7837
# Epoch 114/250
# 31/31 [==============================] - 0s 15ms/step - loss: 0.1742 - accuracy: 0.9377 - val_loss: 1.4226 - val_accuracy: 0.7714
# Epoch 115/250
# 31/31 [==============================] - 1s 16ms/step - loss: 0.2366 - accuracy: 0.9326 - val_loss: 1.2719 - val_accuracy: 0.7102
# Epoch 116/250
# 31/31 [==============================] - 0s 14ms/step - loss: 0.1758 - accuracy: 0.9356 - val_loss: 1.1573 - val_accuracy: 0.7837
# Epoch 117/250
# 31/31 [==============================] - 0s 14ms/step - loss: 0.1373 - accuracy: 0.9448 - val_loss: 1.4985 - val_accuracy: 0.7429
# Epoch 118/250
# 31/31 [==============================] - 0s 14ms/step - loss: 0.1494 - accuracy: 0.9408 - val_loss: 1.1602 - val_accuracy: 0.7673
# Epoch 119/250
# 31/31 [==============================] - 0s 14ms/step - loss: 0.1360 - accuracy: 0.9428 - val_loss: 1.2076 - val_accuracy: 0.7633
# Epoch 120/250
# 31/31 [==============================] - 0s 15ms/step - loss: 0.1124 - accuracy: 0.9459 - val_loss: 1.1707 - val_accuracy: 0.7673
# Epoch 121/250
# 31/31 [==============================] - 0s 16ms/step - loss: 0.1099 - accuracy: 0.9387 - val_loss: 1.1544 - val_accuracy: 0.7469
# Epoch 122/250
# 31/31 [==============================] - 0s 15ms/step - loss: 0.1058 - accuracy: 0.9438 - val_loss: 1.1959 - val_accuracy: 0.7714
# Epoch 123/250
# 31/31 [==============================] - 0s 15ms/step - loss: 0.0991 - accuracy: 0.9428 - val_loss: 1.2279 - val_accuracy: 0.7592
# Epoch 124/250
# 31/31 [==============================] - 1s 18ms/step - loss: 0.0919 - accuracy: 0.9469 - val_loss: 1.2468 - val_accuracy: 0.8041
# Epoch 125/250
# 31/31 [==============================] - 1s 25ms/step - loss: 0.0915 - accuracy: 0.9459 - val_loss: 1.2304 - val_accuracy: 0.7918
# Epoch 126/250
# 31/31 [==============================] - 1s 25ms/step - loss: 0.1189 - accuracy: 0.9459 - val_loss: 1.1370 - val_accuracy: 0.7918
# Epoch 127/250
# 31/31 [==============================] - 1s 18ms/step - loss: 0.0974 - accuracy: 0.9438 - val_loss: 1.1786 - val_accuracy: 0.7837
# Epoch 128/250
# 31/31 [==============================] - 1s 18ms/step - loss: 0.0941 - accuracy: 0.9469 - val_loss: 1.2405 - val_accuracy: 0.8000
# Epoch 129/250
# 31/31 [==============================] - 1s 18ms/step - loss: 0.0887 - accuracy: 0.9448 - val_loss: 1.2098 - val_accuracy: 0.7633
# Epoch 130/250
# 31/31 [==============================] - 1s 18ms/step - loss: 0.0885 - accuracy: 0.9438 - val_loss: 1.2631 - val_accuracy: 0.8082
# Epoch 131/250
# 31/31 [==============================] - 1s 19ms/step - loss: 0.0846 - accuracy: 0.9367 - val_loss: 1.2580 - val_accuracy: 0.8122
# Epoch 132/250
# 31/31 [==============================] - 1s 16ms/step - loss: 0.0838 - accuracy: 0.9438 - val_loss: 1.2373 - val_accuracy: 0.7714
# Epoch 133/250
# 31/31 [==============================] - 0s 15ms/step - loss: 0.0879 - accuracy: 0.9408 - val_loss: 1.2900 - val_accuracy: 0.8041
# Epoch 134/250
# 31/31 [==============================] - 0s 15ms/step - loss: 0.0851 - accuracy: 0.9387 - val_loss: 1.2909 - val_accuracy: 0.8041
# Epoch 135/250
# 31/31 [==============================] - 0s 15ms/step - loss: 0.0889 - accuracy: 0.9428 - val_loss: 1.2357 - val_accuracy: 0.7755
# Epoch 136/250
# 31/31 [==============================] - 1s 19ms/step - loss: 0.0871 - accuracy: 0.9387 - val_loss: 1.3866 - val_accuracy: 0.7959
# Epoch 137/250
# 31/31 [==============================] - 1s 18ms/step - loss: 0.0959 - accuracy: 0.9438 - val_loss: 1.2958 - val_accuracy: 0.7878
# Epoch 138/250
# 31/31 [==============================] - 1s 23ms/step - loss: 0.0916 - accuracy: 0.9459 - val_loss: 1.2743 - val_accuracy: 0.7837
# Epoch 139/250
# 31/31 [==============================] - 1s 21ms/step - loss: 0.0967 - accuracy: 0.9469 - val_loss: 1.3617 - val_accuracy: 0.8041
# Epoch 140/250
# 31/31 [==============================] - 0s 14ms/step - loss: 0.0876 - accuracy: 0.9418 - val_loss: 1.3795 - val_accuracy: 0.7673
# Epoch 141/250
# 31/31 [==============================] - 0s 16ms/step - loss: 0.1094 - accuracy: 0.9408 - val_loss: 1.1364 - val_accuracy: 0.7755
# Epoch 142/250
# 31/31 [==============================] - 1s 25ms/step - loss: 0.0920 - accuracy: 0.9418 - val_loss: 1.1885 - val_accuracy: 0.8041
# Epoch 143/250
# 31/31 [==============================] - 1s 19ms/step - loss: 0.0909 - accuracy: 0.9428 - val_loss: 1.2939 - val_accuracy: 0.7673
# Epoch 144/250
# 31/31 [==============================] - 1s 25ms/step - loss: 0.0970 - accuracy: 0.9418 - val_loss: 1.4119 - val_accuracy: 0.7959
# Epoch 145/250
# 31/31 [==============================] - 1s 29ms/step - loss: 0.1060 - accuracy: 0.9469 - val_loss: 1.1942 - val_accuracy: 0.7959
# Epoch 146/250
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0868 - accuracy: 0.9448 - val_loss: 1.2413 - val_accuracy: 0.8082
# Epoch 147/250
# 31/31 [==============================] - 1s 40ms/step - loss: 0.1000 - accuracy: 0.9520 - val_loss: 1.1840 - val_accuracy: 0.8000
# Epoch 148/250
# 31/31 [==============================] - 1s 22ms/step - loss: 0.0961 - accuracy: 0.9367 - val_loss: 1.1965 - val_accuracy: 0.8041
# Epoch 149/250
# 31/31 [==============================] - 0s 13ms/step - loss: 0.0877 - accuracy: 0.9479 - val_loss: 1.2313 - val_accuracy: 0.7755
# Epoch 150/250
# 31/31 [==============================] - 0s 16ms/step - loss: 0.1009 - accuracy: 0.9428 - val_loss: 1.3634 - val_accuracy: 0.8082
# Epoch 151/250
# 31/31 [==============================] - 0s 14ms/step - loss: 0.0963 - accuracy: 0.9428 - val_loss: 1.1428 - val_accuracy: 0.8082
# Epoch 152/250
# 31/31 [==============================] - 0s 14ms/step - loss: 0.0828 - accuracy: 0.9479 - val_loss: 1.2110 - val_accuracy: 0.7878
# Epoch 153/250
# 31/31 [==============================] - 0s 13ms/step - loss: 0.0862 - accuracy: 0.9428 - val_loss: 1.2789 - val_accuracy: 0.7959
# Epoch 154/250
# 31/31 [==============================] - 0s 13ms/step - loss: 0.0857 - accuracy: 0.9459 - val_loss: 1.2386 - val_accuracy: 0.7796
# Epoch 155/250
# 31/31 [==============================] - 1s 19ms/step - loss: 0.0823 - accuracy: 0.9459 - val_loss: 1.1617 - val_accuracy: 0.7959
# Epoch 156/250
# 31/31 [==============================] - 1s 19ms/step - loss: 0.0764 - accuracy: 0.9459 - val_loss: 1.2872 - val_accuracy: 0.8000
# Epoch 157/250
# 31/31 [==============================] - 1s 18ms/step - loss: 0.0796 - accuracy: 0.9377 - val_loss: 1.2483 - val_accuracy: 0.7837
# Epoch 158/250
# 31/31 [==============================] - 1s 26ms/step - loss: 0.0850 - accuracy: 0.9408 - val_loss: 1.2805 - val_accuracy: 0.7755
# Epoch 159/250
# 31/31 [==============================] - 1s 35ms/step - loss: 0.0789 - accuracy: 0.9387 - val_loss: 1.3048 - val_accuracy: 0.8000
# Epoch 160/250
# 31/31 [==============================] - 1s 26ms/step - loss: 0.0788 - accuracy: 0.9428 - val_loss: 1.2004 - val_accuracy: 0.7918
# Epoch 161/250
# 31/31 [==============================] - 1s 31ms/step - loss: 0.0816 - accuracy: 0.9418 - val_loss: 1.2515 - val_accuracy: 0.7918
# Epoch 162/250
# 31/31 [==============================] - 1s 21ms/step - loss: 0.0801 - accuracy: 0.9367 - val_loss: 1.2729 - val_accuracy: 0.7796
# Epoch 163/250
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0760 - accuracy: 0.9448 - val_loss: 1.2782 - val_accuracy: 0.8204
# Epoch 164/250
# 31/31 [==============================] - 1s 24ms/step - loss: 0.0751 - accuracy: 0.9459 - val_loss: 1.3352 - val_accuracy: 0.8000
# Epoch 165/250
# 31/31 [==============================] - 1s 23ms/step - loss: 0.0821 - accuracy: 0.9408 - val_loss: 1.3032 - val_accuracy: 0.7878
# Epoch 166/250
# 31/31 [==============================] - 1s 26ms/step - loss: 0.0763 - accuracy: 0.9479 - val_loss: 1.2543 - val_accuracy: 0.7918
# Epoch 167/250
# 31/31 [==============================] - 1s 27ms/step - loss: 0.0816 - accuracy: 0.9418 - val_loss: 1.2587 - val_accuracy: 0.7918
# Epoch 168/250
# 31/31 [==============================] - 1s 20ms/step - loss: 0.0805 - accuracy: 0.9397 - val_loss: 1.2860 - val_accuracy: 0.8000
# Epoch 169/250
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0816 - accuracy: 0.9428 - val_loss: 1.2477 - val_accuracy: 0.8041
# Epoch 170/250
# 31/31 [==============================] - 1s 21ms/step - loss: 0.0826 - accuracy: 0.9367 - val_loss: 1.3010 - val_accuracy: 0.7918
# Epoch 171/250
# 31/31 [==============================] - 1s 24ms/step - loss: 0.0786 - accuracy: 0.9479 - val_loss: 1.3715 - val_accuracy: 0.7918
# Epoch 172/250
# 31/31 [==============================] - 1s 26ms/step - loss: 0.0843 - accuracy: 0.9499 - val_loss: 1.2755 - val_accuracy: 0.7633
# Epoch 173/250
# 31/31 [==============================] - 1s 24ms/step - loss: 0.0915 - accuracy: 0.9346 - val_loss: 1.3773 - val_accuracy: 0.8122
# Epoch 174/250
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0904 - accuracy: 0.9489 - val_loss: 1.2137 - val_accuracy: 0.7959
# Epoch 175/250
# 31/31 [==============================] - 1s 25ms/step - loss: 0.0825 - accuracy: 0.9428 - val_loss: 1.2313 - val_accuracy: 0.7714
# Epoch 176/250
# 31/31 [==============================] - 1s 39ms/step - loss: 0.0827 - accuracy: 0.9408 - val_loss: 1.3332 - val_accuracy: 0.8041
# Epoch 177/250
# 31/31 [==============================] - 1s 25ms/step - loss: 0.0843 - accuracy: 0.9448 - val_loss: 1.2252 - val_accuracy: 0.7878
# Epoch 178/250
# 31/31 [==============================] - 1s 26ms/step - loss: 0.0814 - accuracy: 0.9418 - val_loss: 1.2747 - val_accuracy: 0.7918
# Epoch 179/250
# 31/31 [==============================] - 1s 21ms/step - loss: 0.0836 - accuracy: 0.9489 - val_loss: 1.1351 - val_accuracy: 0.8082
# Epoch 180/250
# 31/31 [==============================] - 1s 19ms/step - loss: 0.0759 - accuracy: 0.9479 - val_loss: 1.2891 - val_accuracy: 0.7469
# Epoch 181/250
# 31/31 [==============================] - 1s 16ms/step - loss: 0.1052 - accuracy: 0.9397 - val_loss: 1.3303 - val_accuracy: 0.7714
# Epoch 182/250
# 31/31 [==============================] - 0s 15ms/step - loss: 0.1730 - accuracy: 0.9285 - val_loss: 1.5420 - val_accuracy: 0.7592
# Epoch 183/250
# 31/31 [==============================] - 1s 17ms/step - loss: 0.1754 - accuracy: 0.9295 - val_loss: 1.6513 - val_accuracy: 0.6980
# Epoch 184/250
# 31/31 [==============================] - 1s 18ms/step - loss: 0.1530 - accuracy: 0.9387 - val_loss: 1.4087 - val_accuracy: 0.7878
# Epoch 185/250
# 31/31 [==============================] - 0s 13ms/step - loss: 0.2463 - accuracy: 0.9224 - val_loss: 1.8594 - val_accuracy: 0.6653
# Epoch 186/250
# 31/31 [==============================] - 1s 16ms/step - loss: 0.2700 - accuracy: 0.9070 - val_loss: 1.8253 - val_accuracy: 0.7837
# Epoch 187/250
# 31/31 [==============================] - 1s 17ms/step - loss: 0.2239 - accuracy: 0.9173 - val_loss: 1.5290 - val_accuracy: 0.7837
# Epoch 188/250
# 31/31 [==============================] - 1s 17ms/step - loss: 0.1560 - accuracy: 0.9336 - val_loss: 1.3855 - val_accuracy: 0.7714
# Epoch 189/250
# 31/31 [==============================] - 1s 17ms/step - loss: 0.1337 - accuracy: 0.9448 - val_loss: 1.4608 - val_accuracy: 0.7633
# Epoch 190/250
# 31/31 [==============================] - 1s 17ms/step - loss: 0.1331 - accuracy: 0.9459 - val_loss: 1.5139 - val_accuracy: 0.6898
# Epoch 191/250
# 31/31 [==============================] - 1s 19ms/step - loss: 0.2395 - accuracy: 0.9316 - val_loss: 1.5082 - val_accuracy: 0.7551
# Epoch 192/250
# 31/31 [==============================] - 1s 19ms/step - loss: 0.1694 - accuracy: 0.9265 - val_loss: 1.4060 - val_accuracy: 0.7714
# Epoch 193/250
# 31/31 [==============================] - 1s 23ms/step - loss: 0.1434 - accuracy: 0.9438 - val_loss: 1.3373 - val_accuracy: 0.7306
# Epoch 194/250
# 31/31 [==============================] - 1s 20ms/step - loss: 0.1119 - accuracy: 0.9438 - val_loss: 1.3479 - val_accuracy: 0.7837
# Epoch 195/250
# 31/31 [==============================] - 1s 20ms/step - loss: 0.0975 - accuracy: 0.9418 - val_loss: 1.3090 - val_accuracy: 0.7714
# Epoch 196/250
# 31/31 [==============================] - 1s 16ms/step - loss: 0.0896 - accuracy: 0.9387 - val_loss: 1.3404 - val_accuracy: 0.7837
# Epoch 197/250
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0867 - accuracy: 0.9397 - val_loss: 1.3840 - val_accuracy: 0.7878
# Epoch 198/250
# 31/31 [==============================] - 0s 16ms/step - loss: 0.0850 - accuracy: 0.9448 - val_loss: 1.4055 - val_accuracy: 0.7959
# Epoch 199/250
# 31/31 [==============================] - 0s 16ms/step - loss: 0.0867 - accuracy: 0.9408 - val_loss: 1.4223 - val_accuracy: 0.7837
# Epoch 200/250
# 31/31 [==============================] - 0s 15ms/step - loss: 0.0844 - accuracy: 0.9408 - val_loss: 1.3520 - val_accuracy: 0.7918
# Epoch 201/250
# 31/31 [==============================] - 0s 13ms/step - loss: 0.0786 - accuracy: 0.9428 - val_loss: 1.4083 - val_accuracy: 0.7837
# Epoch 202/250
# 31/31 [==============================] - 0s 13ms/step - loss: 0.0777 - accuracy: 0.9377 - val_loss: 1.4157 - val_accuracy: 0.7918
# Epoch 203/250
# 31/31 [==============================] - 0s 13ms/step - loss: 0.0783 - accuracy: 0.9356 - val_loss: 1.4204 - val_accuracy: 0.7918
# Epoch 204/250
# 31/31 [==============================] - 0s 13ms/step - loss: 0.0768 - accuracy: 0.9387 - val_loss: 1.4363 - val_accuracy: 0.7918
# Epoch 205/250
# 31/31 [==============================] - 0s 12ms/step - loss: 0.0751 - accuracy: 0.9469 - val_loss: 1.4395 - val_accuracy: 0.7796
# Epoch 206/250
# 31/31 [==============================] - 0s 15ms/step - loss: 0.0779 - accuracy: 0.9408 - val_loss: 1.4503 - val_accuracy: 0.7959
# Epoch 207/250
# 31/31 [==============================] - 0s 16ms/step - loss: 0.0769 - accuracy: 0.9387 - val_loss: 1.4221 - val_accuracy: 0.7878
# Epoch 208/250
# 31/31 [==============================] - 1s 19ms/step - loss: 0.0753 - accuracy: 0.9397 - val_loss: 1.4610 - val_accuracy: 0.7918
# Epoch 209/250
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0766 - accuracy: 0.9438 - val_loss: 1.4899 - val_accuracy: 0.8000
# Epoch 210/250
# 31/31 [==============================] - 0s 16ms/step - loss: 0.0784 - accuracy: 0.9387 - val_loss: 1.4220 - val_accuracy: 0.7918
# Epoch 211/250
# 31/31 [==============================] - 0s 16ms/step - loss: 0.0780 - accuracy: 0.9387 - val_loss: 1.4620 - val_accuracy: 0.7918
# Epoch 212/250
# 31/31 [==============================] - 1s 18ms/step - loss: 0.0798 - accuracy: 0.9438 - val_loss: 1.4601 - val_accuracy: 0.8041
# Epoch 213/250
# 31/31 [==============================] - 1s 16ms/step - loss: 0.0772 - accuracy: 0.9356 - val_loss: 1.3799 - val_accuracy: 0.7837
# Epoch 214/250
# 31/31 [==============================] - 0s 16ms/step - loss: 0.0745 - accuracy: 0.9408 - val_loss: 1.4807 - val_accuracy: 0.8000
# Epoch 215/250
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0754 - accuracy: 0.9387 - val_loss: 1.4414 - val_accuracy: 0.7918
# Epoch 216/250
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0753 - accuracy: 0.9499 - val_loss: 1.4438 - val_accuracy: 0.7959
# Epoch 217/250
# 31/31 [==============================] - 0s 13ms/step - loss: 0.0767 - accuracy: 0.9397 - val_loss: 1.4605 - val_accuracy: 0.7959
# Epoch 218/250
# 31/31 [==============================] - 0s 13ms/step - loss: 0.0761 - accuracy: 0.9448 - val_loss: 1.4367 - val_accuracy: 0.7959
# Epoch 219/250
# 31/31 [==============================] - 0s 13ms/step - loss: 0.0807 - accuracy: 0.9479 - val_loss: 1.4088 - val_accuracy: 0.7755
# Epoch 220/250
# 31/31 [==============================] - 0s 14ms/step - loss: 0.0817 - accuracy: 0.9418 - val_loss: 1.5561 - val_accuracy: 0.7918
# Epoch 221/250
# 31/31 [==============================] - 0s 15ms/step - loss: 0.0974 - accuracy: 0.9428 - val_loss: 1.3209 - val_accuracy: 0.7755
# Epoch 222/250
# 31/31 [==============================] - 0s 16ms/step - loss: 0.0893 - accuracy: 0.9418 - val_loss: 1.4096 - val_accuracy: 0.7796
# Epoch 223/250
# 31/31 [==============================] - 0s 13ms/step - loss: 0.0797 - accuracy: 0.9428 - val_loss: 1.4161 - val_accuracy: 0.7837
# Epoch 224/250
# 31/31 [==============================] - 0s 13ms/step - loss: 0.0797 - accuracy: 0.9418 - val_loss: 1.3687 - val_accuracy: 0.7796
# Epoch 225/250
# 31/31 [==============================] - 0s 16ms/step - loss: 0.0821 - accuracy: 0.9397 - val_loss: 1.3986 - val_accuracy: 0.7837
# Epoch 226/250
# 31/31 [==============================] - 0s 13ms/step - loss: 0.0796 - accuracy: 0.9408 - val_loss: 1.4327 - val_accuracy: 0.7796
# Epoch 227/250
# 31/31 [==============================] - 0s 14ms/step - loss: 0.0792 - accuracy: 0.9469 - val_loss: 1.3678 - val_accuracy: 0.7878
# Epoch 228/250
# 31/31 [==============================] - 1s 20ms/step - loss: 0.0773 - accuracy: 0.9438 - val_loss: 1.4323 - val_accuracy: 0.7837
# Epoch 229/250
# 31/31 [==============================] - 1s 20ms/step - loss: 0.0764 - accuracy: 0.9387 - val_loss: 1.3988 - val_accuracy: 0.7796
# Epoch 230/250
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0802 - accuracy: 0.9377 - val_loss: 1.4309 - val_accuracy: 0.7878
# Epoch 231/250
# 31/31 [==============================] - 1s 16ms/step - loss: 0.0770 - accuracy: 0.9459 - val_loss: 1.5431 - val_accuracy: 0.8082
# Epoch 232/250
# 31/31 [==============================] - 0s 16ms/step - loss: 0.0789 - accuracy: 0.9387 - val_loss: 1.3727 - val_accuracy: 0.7796
# Epoch 233/250
# 31/31 [==============================] - 1s 19ms/step - loss: 0.0771 - accuracy: 0.9367 - val_loss: 1.3963 - val_accuracy: 0.7878
# Epoch 234/250
# 31/31 [==============================] - 0s 16ms/step - loss: 0.0771 - accuracy: 0.9418 - val_loss: 1.4297 - val_accuracy: 0.7959
# Epoch 235/250
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0725 - accuracy: 0.9397 - val_loss: 1.4868 - val_accuracy: 0.7918
# Epoch 236/250
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0740 - accuracy: 0.9387 - val_loss: 1.4854 - val_accuracy: 0.7878
# Epoch 237/250
# 31/31 [==============================] - 0s 14ms/step - loss: 0.0713 - accuracy: 0.9459 - val_loss: 1.4878 - val_accuracy: 0.7878
# Epoch 238/250
# 31/31 [==============================] - 0s 13ms/step - loss: 0.0727 - accuracy: 0.9418 - val_loss: 1.4669 - val_accuracy: 0.7918
# Epoch 239/250
# 31/31 [==============================] - 0s 12ms/step - loss: 0.0714 - accuracy: 0.9397 - val_loss: 1.4561 - val_accuracy: 0.7918
# Epoch 240/250
# 31/31 [==============================] - 0s 15ms/step - loss: 0.0752 - accuracy: 0.9387 - val_loss: 1.4204 - val_accuracy: 0.7878
# Epoch 241/250
# 31/31 [==============================] - 0s 14ms/step - loss: 0.0739 - accuracy: 0.9459 - val_loss: 1.4336 - val_accuracy: 0.7878
# Epoch 242/250
# 31/31 [==============================] - 0s 13ms/step - loss: 0.0711 - accuracy: 0.9428 - val_loss: 1.4524 - val_accuracy: 0.7878
# Epoch 243/250
# 31/31 [==============================] - 0s 13ms/step - loss: 0.0726 - accuracy: 0.9418 - val_loss: 1.4714 - val_accuracy: 0.7918
# Epoch 244/250
# 31/31 [==============================] - 1s 18ms/step - loss: 0.0740 - accuracy: 0.9499 - val_loss: 1.4864 - val_accuracy: 0.8041
# Epoch 245/250
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0769 - accuracy: 0.9469 - val_loss: 1.6643 - val_accuracy: 0.7429
# Epoch 246/250
# 31/31 [==============================] - 1s 17ms/step - loss: 0.2022 - accuracy: 0.9183 - val_loss: 1.4170 - val_accuracy: 0.7755
# Epoch 247/250
# 31/31 [==============================] - 1s 17ms/step - loss: 0.1558 - accuracy: 0.9397 - val_loss: 1.4166 - val_accuracy: 0.7592
# Epoch 248/250
# 31/31 [==============================] - 1s 25ms/step - loss: 0.1575 - accuracy: 0.9346 - val_loss: 1.3129 - val_accuracy: 0.7673
# Epoch 249/250
# 31/31 [==============================] - 1s 32ms/step - loss: 0.1125 - accuracy: 0.9418 - val_loss: 1.5043 - val_accuracy: 0.7714
# Epoch 250/250
# 31/31 [==============================] - 1s 33ms/step - loss: 0.1311 - accuracy: 0.9479 - val_loss: 1.5201 - val_accuracy: 0.7918

# %%
# Plot training & validation accuracy values
plt.plot(single_history.history['accuracy'])
plt.plot(single_history.history['val_accuracy'])
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# Plot training & validation loss values
plt.plot(single_history.history['loss'])
plt.plot(single_history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# save the model
single_model.save('./files/feature_model.keras')

# %%
# Evaluate model
loss, accuracy = single_model.evaluate(X_test_np, y_test_cat)
print("Test Loss:", loss, "Test Accuracy:", accuracy)
# Out:
# 8/8 [==============================] - 0s 6ms/step - loss: 1.5201 - accuracy: 0.7918
# Test Loss: 1.5200566053390503 Test Accuracy: 0.7918367385864258

# %%
# # Make predictions on new data
predictions = single_model.predict(X_test_np)

# The predictions will be probabilities for each class
# You can convert these probabilities to class labels
predicted_labels = np.argmax(predictions, axis=1)

# Example of using the predicted labels
print(predicted_labels)
# Out:
# 8/8 [==============================] - 0s 9ms/step
# [2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 0 0 2 2 2 2 2 2 2 2 0 2 2 2 2 0
#  2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 0 2 2 2 2 2 2 2
#  2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 0 2 2 2 2 2 2 0 2 2 2
#  2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 0 2 2 2 0 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2
#  2 2 2 2 2 2 0 2 1 2 2 2 2 2 2 2 2 2 0 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2
#  0 2 2 2 2 2 2 2 2 2 2 2 1 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2
#  2 2 2 2 0 2 0 2 2 2 0 2 0 2 2 2 2 2 2 2 2 1 2]

# %%
# Convert numeric predictions to label names
predicted_labels_names = [class_index_to_label[idx] for idx in np.argmax(multi_predictions, axis=1)]

predicted_labels_names
# Out:
# ['usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'uk',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'uk',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'uk',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'uk',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'canada',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'uk',
#  'usa',
#  'usa',
#  'usa',
#  'uk',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'uk',
#  'usa',
#  'uk',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'uk',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'uk',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'canada',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'uk',
#  'usa',
#  'uk',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'uk',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'canada',
#  'usa']

# %%
# Convert predicted class indices to one-hot encoded format
label_binarizer = LabelBinarizer()
labels_one_hot = label_binarizer.fit_transform(predicted_labels)

# Calculate confusion matrix
cm = confusion_matrix(y_test_cat.argmax(axis=1), labels_one_hot.argmax(axis=1))

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(
    cm, 
    annot=True, 
    cmap='Blues', 
    fmt='g', 
    xticklabels=class_index_to_label.values(), 
    yticklabels=class_index_to_label.values()
)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.savefig('./files/feature_confusion_matrix.png')
plt.show()

# %% [markdown]
# # For Hybrid CNN-LSTM Model

# %% [markdown]
# # Choose the approach (concatenation or separate channels)

# %%
use_separate_channels = True

# Create CNN-LSTM architecture
hybrid_model = create_hybrid_model(
    X_mfcc_np=X_mfcc_np_padded,
    X_chroma_stft_np=X_chroma_stft_np_padded,
    # X_spectral_centroid_np=X_spectral_centroid_np,
    use_separate_channels=use_separate_channels
)

# %%
# model summary
hybrid_model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_4 (InputLayer)        [(None, 40, 2000)]           0         []
#
#  input_5 (InputLayer)        [(None, 40, 2000)]           0         []
#
#  conv1d_5 (Conv1D)           (None, 40, 16)               96016     ['input_4[0][0]']
#
#  conv1d_6 (Conv1D)           (None, 40, 8)                48008     ['input_5[0][0]']
#
#  concatenate_2 (Concatenate  (None, 40, 24)               0         ['conv1d_5[0][0]',
#  )                                                                   'conv1d_6[0][0]']
#
#  max_pooling1d_4 (MaxPoolin  (None, 20, 24)               0         ['concatenate_2[0][0]']
#  g1D)
#
#  conv1d_7 (Conv1D)           (None, 18, 128)              9344      ['max_pooling1d_4[0][0]']
#
#  max_pooling1d_5 (MaxPoolin  (None, 9, 128)               0         ['conv1d_7[0][0]']
#  g1D)
#
#  lstm (LSTM)                 (None, 9, 128)               131584    ['max_pooling1d_5[0][0]']
#
#  lstm_1 (LSTM)               (None, 128)                  131584    ['lstm[0][0]']
#
#  dense_4 (Dense)             (None, 64)                   8256      ['lstm_1[0][0]']
#
#  dense_5 (Dense)             (None, 3)                    195       ['dense_4[0][0]']
#
# ==================================================================================================
# Total params: 424987 (1.62 MB)
# Trainable params: 424987 (1.62 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
# plot model
keras.utils.plot_model(hybrid_model, to_file='files/hybrid_feature_model.png', show_shapes=False)

# %%
history = hybrid_model.fit(
    [X_mfcc_np_padded, X_chroma_stft_np_padded],
    y_train_cat,
    epochs=10, # EPOCHS
    validation_data=([X_mfcc_test_np_padded, X_chroma_test_stft_np_padded], y_test_cat)
)
# Out:
# Epoch 1/10
# 31/31 [==============================] - 17s 134ms/step - loss: 0.5613 - accuracy: 0.8223 - val_loss: 0.5577 - val_accuracy: 0.8449
# Epoch 2/10
# 31/31 [==============================] - 1s 38ms/step - loss: 0.5199 - accuracy: 0.8417 - val_loss: 0.5696 - val_accuracy: 0.8449
# Epoch 3/10
# 31/31 [==============================] - 1s 41ms/step - loss: 0.4985 - accuracy: 0.8417 - val_loss: 0.5514 - val_accuracy: 0.8449
# Epoch 4/10
# 31/31 [==============================] - 1s 39ms/step - loss: 0.4675 - accuracy: 0.8447 - val_loss: 0.5869 - val_accuracy: 0.8449
# Epoch 5/10
# 31/31 [==============================] - 1s 48ms/step - loss: 0.4472 - accuracy: 0.8478 - val_loss: 0.5601 - val_accuracy: 0.8408
# Epoch 6/10
# 31/31 [==============================] - 3s 86ms/step - loss: 0.3835 - accuracy: 0.8631 - val_loss: 0.6238 - val_accuracy: 0.8449
# Epoch 7/10
# 31/31 [==============================] - 3s 87ms/step - loss: 0.3583 - accuracy: 0.8693 - val_loss: 0.6115 - val_accuracy: 0.8245
# Epoch 8/10
# 31/31 [==============================] - 2s 64ms/step - loss: 0.3073 - accuracy: 0.8805 - val_loss: 0.7207 - val_accuracy: 0.8204
# Epoch 9/10
# 31/31 [==============================] - 2s 49ms/step - loss: 0.3208 - accuracy: 0.8754 - val_loss: 0.6970 - val_accuracy: 0.8449
# Epoch 10/10
# 31/31 [==============================] - 2s 68ms/step - loss: 0.2973 - accuracy: 0.8774 - val_loss: 0.7916 - val_accuracy: 0.8245

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# save the model
hybrid_model.save('./files/hybrid_feature_model.keras')

# %%
# Evaluate model
loss, accuracy = hybrid_model.evaluate([
        X_mfcc_test_np_padded, 
        X_chroma_test_stft_np_padded
    ],
    y_test_cat
)
print("Test Loss:", loss, "Test Accuracy:", accuracy)
# Out:
# 8/8 [==============================] - 0s 18ms/step - loss: 0.7916 - accuracy: 0.8245
# Test Loss: 0.7915979623794556 Test Accuracy: 0.8244897723197937

# %%
# Make predictions on new data
hybrid_predictions = hybrid_model.predict([
    X_mfcc_test_np_padded, 
    X_chroma_test_stft_np_padded
])

# The predictions will be probabilities for each class
# You can convert these probabilities to class labels
hybrid_predicted_labels = np.argmax(hybrid_predictions, axis=1)

# Example of using the predicted labels
print(multi_predicted_labels)
# Out:
# 8/8 [==============================] - 2s 14ms/step
# [2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 0 2 2 2 2 2 2 2 0 2 2 2 2 2 2 2 2 2 2 2 2 0
#  2 2 2 2 0 2 2 2 2 2 2 2 2 2 2 2 2 1 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2
#  2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2
#  2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2
#  2 2 0 2 2 2 0 2 2 2 2 2 2 2 2 2 0 2 0 2 2 2 2 2 2 2 2 2 0 2 2 2 2 2 2 2 2
#  0 2 2 2 2 2 2 2 2 2 2 2 1 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2
#  2 2 0 2 0 2 2 2 2 2 2 2 0 2 2 2 2 2 2 2 2 1 2]

# %%
# Convert numeric predictions to label names
predicted_labels_names = [class_index_to_label[idx] for idx in np.argmax(hybrid_predictions, axis=1)]

predicted_labels_names
# Out:
# ['usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'uk',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'uk',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'uk',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'uk',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'canada',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'uk',
#  'uk',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa',
#  'usa']

# %%
# Convert predicted class indices to one-hot encoded format
label_binarizer = LabelBinarizer()
predicted_labels_one_hot = label_binarizer.fit_transform(hybrid_predicted_labels)

# Calculate confusion matrix
cm = confusion_matrix(y_test_cat.argmax(axis=1), predicted_labels_one_hot.argmax(axis=1))

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(
    cm, 
    annot=True, 
    cmap='Blues', 
    fmt='g', 
    xticklabels=class_index_to_label.values(), 
    yticklabels=class_index_to_label.values()
)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.savefig('./files/hybrid_feature_confusion_matrix.png')
plt.show()
